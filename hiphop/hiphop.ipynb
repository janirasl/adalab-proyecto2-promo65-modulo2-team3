# %%
import json
import requests
import pandas as pd

# %%
with open ("../archivos_json/definitivo.json", "r") as fichero:
    definitivo = json.load(fichero)

def extraer_por_genero(canciones, genero):
    lista_hiphop = []

    for item in canciones:
        año = item.get("year")

        if item.get("genre") == genero and 2016 <= año <= 2019:
            info = {
                "Artista": item.get("artist_name"),
                "Género": item.get("genre"),
                "Nombre de la Canción": item.get("track_name"),
                "Año de lanzamiento": año
            }

            lista_hiphop.append(info)

    print(len(lista_hiphop))
    return lista_hiphop

lista_hiphop = extraer_por_genero(definitivo, "hip-hop")
print(lista_hiphop[0:5])
# Out:
# 2887
# [{'Artista': 'MHD', 'Género': 'hip-hop', 'Nombre de la Canción': 'Afro Trap Pt. 3 (Champions League)', 'Año de lanzamiento': 2016}, {'Artista': 'Post Malone', 'Género': 'hip-hop', 'Nombre de la Canción': 'Congratulations', 'Año de lanzamiento': 2016}, {'Artista': 'Quavo', 'Género': 'hip-hop', 'Nombre de la Canción': 'Congratulations', 'Año de lanzamiento': 2016}, {'Artista': 'Maikel Delacalle', 'Género': 'hip-hop', 'Nombre de la Canción': 'Ganas', 'Año de lanzamiento': 2016}, {'Artista': 'Kase.O', 'Género': 'hip-hop', 'Nombre de la Canción': 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 'Año de lanzamiento': 2016}]

# %%
artistas_hiphop = set()
for artista in lista_hiphop:
    artistas_hiphop.add(artista["Artista"])
print(f" {len(artistas_hiphop)}")
# Out:
#  1402

# %%
len(artistas_hiphop)
# Out:
# 1402

# %%
with open ("lista_hiphop.json", "w", encoding="utf-8") as fichero:
    json.dump(lista_hiphop, fichero, ensure_ascii=False, indent=4)

# %%
type(artistas_hiphop)
# Out:
# set

# %%
with open("../archivos_json/definitivo.json", "r", encoding="utf-8") as fichero:  # Ruta al json
    definitivo = json.load(fichero)  # Abrimos el fichero


def extraer_por_genero(canciones, genero):
    # Creamos la funcion
    lista_hiphop = []  # lista vacia para almacenar los datos extraidos

    for item in canciones:  # iteramos por la lista
        año = item.get("year")

        # Normalizamos el género por si viene como "Hip-Hop", "hip-hop", etc.
        genero_item = (item.get("genre") or "").strip().lower().replace("-", " ")
        genero_objetivo = genero.strip().lower().replace("-", " ")

        if genero_item == genero_objetivo and isinstance(año, int) and 2016 <= año <= 2019:
            info = (
                item.get("artist_name"),
                item.get("genre"),
                item.get("track_name"),
                año
            )
            lista_hiphop.append(info)

    return lista_hiphop


lista_hiphop = extraer_por_genero(definitivo, "hip hop")
print(f"La longitud de la lista es --> {len(lista_hiphop)} canciones de Hip Hop")
print(f"{'-' * 100}\n{lista_hiphop}")
# Out:
# La longitud de la lista es --> 2887 canciones de Hip Hop
# ----------------------------------------------------------------------------------------------------
# [('MHD', 'hip-hop', 'Afro Trap Pt. 3 (Champions League)', 2016), ('Post Malone', 'hip-hop', 'Congratulations', 2016), ('Quavo', 'hip-hop', 'Congratulations', 2016), ('Maikel Delacalle', 'hip-hop', 'Ganas', 2016), ('Kase.O', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('Hermano L', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('Shabu One Shant', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('McKlopedia', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('Dvice', 'hip-hop', 'Hablame 2', 2016), ('Alex Kyza', 'hip-hop', 'Hablame 2', 2016), ('Darkiel', 'hip-hop', 'Hablame 2', 2016), ('Ñengo Flow', 'hip-hop', 'Hablame 2', 2016), ('Anuel AA', 'hip-hop', 'Hablame 2', 2016), ('Bryant Myers', 'hip-hop', 'Hablame 2', 2016), ('Lary Over', 'hip-hop', 'Hablame 2', 2016), ('Almighty', 'hip-hop', 'Hablame 2', 2016), ('Juanka', 'hip-hop', 'Hablame 2', 2016), ('Kase.O', 'hip-hop', 'Yemen', 2016), ('Kase.O', 'hip-hop', 'Esto No Para', 2016), ('Rels B', 'hip-hop', 'Baila Más', 2016), ('Javier Simon', 'hip-hop', 'Baila Más', 2016), ('Natos y Waor', 'hip-hop', 'Por ti', 2016), ('Anuel AA', 'hip-hop', 'Check', 2016), ('PNL', 'hip-hop', 'Uranus', 2016), ('Arcángel', 'hip-hop', 'Me Llamas', 2016), ('Mark B.', 'hip-hop', 'Me Llamas', 2016), ('De La Ghetto', 'hip-hop', 'Me Llamas', 2016), ('Bad Bunny', 'hip-hop', 'Me Llamas', 2016), ('Amenazzy', 'hip-hop', 'Me Llamas', 2016), ('Kase.O', 'hip-hop', 'Mitad y Mitad (con Najwa)', 2016), ('Najwa', 'hip-hop', 'Mitad y Mitad (con Najwa)', 2016), ('Drake', 'hip-hop', 'Too Good', 2016), ('Rihanna', 'hip-hop', 'Too Good', 2016), ('Kaze', 'hip-hop', 'Obsceno', 2016), ('Kase.O', 'hip-hop', 'Mazas y Catapultas', 2016), ('Drake', 'hip-hop', '9', 2016), ('Kase.O', 'hip-hop', 'Outro', 2016), ('Rvssian', 'hip-hop', 'Privado', 2016), ('Nicky Jam', 'hip-hop', 'Privado', 2016), ('Farruko', 'hip-hop', 'Privado', 2016), ('Arcángel', 'hip-hop', 'Privado', 2016), ('Konshens', 'hip-hop', 'Privado', 2016), ('Arce', 'hip-hop', 'T.H.C.', 2016), ('ieathumns', 'hip-hop', 'Made In Taiwan', 2016), ('Anuel AA', 'hip-hop', 'Nunca Sapo', 2016), ('Yomo', 'hip-hop', 'Juguetona - Remix', 2016), ('Wisin', 'hip-hop', 'Juguetona - Remix', 2016), ('Farruko', 'hip-hop', 'Juguetona - Remix', 2016), ('Tito "El Bambino"', 'hip-hop', 'Juguetona - Remix', 2016), ('Darell', 'hip-hop', 'Ninguno Se Monta', 2016), ('Anuel AA', 'hip-hop', 'Ninguno Se Monta', 2016), ('Tempo', 'hip-hop', 'Ninguno Se Monta', 2016), ('Juanka', 'hip-hop', 'Ninguno Se Monta', 2016), ('Lito Kirino', 'hip-hop', 'Ninguno Se Monta', 2016), ('Bryant Myers', 'hip-hop', 'Ninguno Se Monta', 2016), ('Kanye West', 'hip-hop', 'Saint Pablo', 2016), ('Cosculluela', 'hip-hop', 'Black Ops', 2016), ('Kaze', 'hip-hop', 'Venga Lo Que Venga', 2016), ('LFAM', 'hip-hop', 'Gang Banger', 2016), ('Dudu', 'hip-hop', 'Gang Banger', 2016), ('Charflex', 'hip-hop', 'Gang Banger', 2016), ('Kase.O', 'hip-hop', 'Amor Sin Cláusulas', 2016), ('Natos y Waor', 'hip-hop', 'Rara Avis', 2016), ('Canserbero', 'hip-hop', 'Buenas Noches', 2016), ('NicoJP', 'hip-hop', 'Buenas Noches', 2016), ('Drake', 'hip-hop', 'Feel No Ways', 2016), ('Meek Mill', 'hip-hop', 'Blue Notes', 2016), ('Kase.O', 'hip-hop', 'Repartiendo Arte', 2016), ('Soge', 'hip-hop', 'Entra', 2016), ('Arce', 'hip-hop', 'Freya', 2016), ('Denom', 'hip-hop', 'Freya', 2016), ('Brytiago', 'hip-hop', 'Punto G', 2016), ('Darell', 'hip-hop', 'Punto G', 2016), ('Kaze', 'hip-hop', 'Rap', 2016), ('Natos y Waor', 'hip-hop', 'Elegante (feat. Ivan Cano)', 2016), ('Ivan Cano', 'hip-hop', 'Elegante (feat. Ivan Cano)', 2016), ('Liana Malva', 'hip-hop', 'Te quiero', 2016), ('Canserbero', 'hip-hop', 'Te quiero', 2016), ('Solo Soul', 'hip-hop', 'Te quiero', 2016), ('Farruko', 'hip-hop', 'Así Crecí', 2016), ('Young Thug', 'hip-hop', 'Digits', 2016), ('Travis Scott', 'hip-hop', 'coordinate', 2016), ('Myke Towers', 'hip-hop', 'Día de Cobro', 20 ...

# %%
with open("artistas_hiphop.json", "w", encoding="utf-8") as fichero:
    json.dump(
        sorted(artistas_hiphop),
        fichero,
        ensure_ascii=False,
        indent=4
    )

# %%
artistas_hiphop = set()  # Creamos un set para no repetir artistas

for dato in lista_hiphop:  # Iteramos por la lista
    artistas_hiphop.add(dato[0])  # artista está en la posición 0

print(
    f"La longitud de los artistas es --> {len(artistas_hiphop)} artistas\n"
    f"{'-' * 100}\n"
    f"Los artistas son --> {artistas_hiphop}"
)
# Out:
# La longitud de los artistas es --> 1402 artistas
# ----------------------------------------------------------------------------------------------------
# Los artistas son --> {'Raj Mahal', 'Quimico Ultra Mega', 'Fly Anakin', 'Sherry-ou', 'Assim', 'InfaRed', 'El Jincho', 'B.I.G', 'Icee', 'Maffy', 'Rich Vagos', 'Mrs M', 'Tyga', 'Lil Juu Widdaus', 'A Boogie Wit da Hoodie', 'MTM', 'Quality Control', 'PNL', 'Baby Gas', 'Bonez MC', 'Rogachev', 'Ayax y Prok', 'Anuel AA', 'Cilvaringz', 'Jay Romero', 'Biggie Paul', 'Gravy', 'Residente', 'ST!llness', 'SCH', 'Lord Apex', 'Desi Arnez', 'Vaze Haze', 'River', 'Kwasi', 'Carlytos Vela', 'Lui-G 21+', 'Loyle Carner', 'Alexis y Fido', 'Blizz', 'MicrowaveMan', 'Makassy', 'Carla Barnes', 'Mase', 'Cosculluela', 'Relle Caine', 'Edoby', 'Kaele Bigger', 'Mr Ammo', 'Rich Kidd', 'Venom', 'Ghali', 'Mr Noon', 'Xtacy', 'The Essence', 'Koba LaD', 'Risskant', 'Grind', 'Sleazy F Baby', 'Ironik', 'TBF', 'Ben Whale', 'SiR', 'Lil P', 'Anetta', 'Big M.I.C', 'Daddy Yankee', 'BSTFRND', 'Tom Misch', 'Tr1ckmusic', 'Ghetto B', 'C. Tangana', 'Lester Nowhere', 'TinTin V.', 'Skinny Stylus', 'Christian', 'Calero LDN', 'Bohemia', 'Control Machete', 'Kempi', 'Brulux', 'Tuamie', 'Klassik', 'Nag', 'Liiight', 'Myke Bogan', 'Emy Soul', 'DJ Sem', 'Adje', 'Elemental', 'Ele A El Dominio', 'CASTRO', "Sav'o", 'ShoSho', 'Ray Rizzy', '3robi', 'Biggs', 'Mad Stage', 'Anonimus', 'Rich The Kid', 'Post Malone', 'Ghostemane', 'Kalash Criminel', 'Yung Sarria', 'Revol', 'Hugo TSR', 'Pitizion', 'Zacari', 'Jeon', 'Swelto', 'Khaled', 'Paper Tiger', 'DaBaby', 'Jon Z', 'Gona', 'Omar Musa', 'Klondike Kat', 'Almighty', 'Recycled J', 'Tito Flow', 'Diplo', 'El Jose', 'Chicolisto', 'Vince Staples', 'Travis Scott', 'TL Jones', 'Vincent Van Great', 'M7', 'Anye Elite', 'Анна Хмара', 'PARTYNEXTDOOR', 'Lil Skritt', 'PEACE CHONG', 'Tereza', 'Kinetical', '42', 'Aitch', 'Super Yei', 'Wasabi', 'Ripp Flamez', 'Shady Nate', 'Tee Grizzley', 'Checkmate', 'EKR', 'Öökülm', 'Grupa Banana', 'Charlie Puth', 'Camb', 'Oscu', 'Young Lox', 'Frank Waln', 'David Scheid', 'Dillaz', 'Rober del Pyro', 'Big Soto', 'Najee Janey', 'Adán Cruz', 'Natos y Waor', 'Tyrek Greene', 'Feinos', 'YSY A', 'Ice One', 'Da Gudda Jazz', 'Summer Cem', 'J. Cole', 'Bman', 'Luke Vallen', 'Snow', 'Pouya', 'DJ Michael 5000 Watts', 'Kuniva', 'Hunter', 'Chanda Mbao', 'Berny', 'Muhnee', 'Ele A', 'Nati Hassid', 'Zaman', 'Sr Pablo', 'Dowba Montana', 'Meta Four', 'Shelow Shaq', 'Urban Hype', 'Denom', 'PB', 'Gata Cattana', "John'nay Lasha", '8L', 'Pistolposse', 'Odd Nosdam', 'Swae Lee', 'SLiNK', 'Duffel Bag Hottie', 'Hanjin Tan', 'Ruelle', 'Sibel', 'Moe Pope', 'Illinformed', 'Dyrti San', 'Lary Over', 'Raggio', 'Kid Indigo', 'VETO', 'Los Serenos Sefarad', 'Amazin Payne', 'Son Of Saturn', 'R De Rumba', 'Rah-C', 'Dintluanga Tochhawng', 'The WAAPA Gospel Choir', 'Rich The Factor', 'Choppa', 'Soprano', 'MadeinTYO', 'Bru Lei', 'Santa RM', 'Serengeti', 'Gera MX', 'The Cancel', 'Tokztero', 'Rendition', 'Kaydy Cain', 'Kane', 'Upol Islam', 'Buhodermia 夜', 'Atari Hanzo', 'Maestro Fresh Wes', 'Hamza', 'Negro Gonzáles', 'Felo Blonck', 'AVA', 'Promotioneel', 'Seven Kayne', 'Medusa Prods', 'CISKO', 'Future', 'Money Man', 'mgk', 'STL GLD', 'Beret', 'Avenue', 'Marbletop Orchestra', 'Icaki', 'BKO', 'Tiff the Gift', 'Konshens', 'Pain Loc', 'Dudu', 'Shle Berry', 'Dark Polo Gang', 'Dutch Rebelle', 'Nyukyung', 'Hyu', 'Chuc Eezi', 'Robot95', 'Gambeta', 'YFilla', 'Lil Pump', 'Vagrant Real Estate', 'ShabZi Madallion', 'Tizzy x Brandz', 'Ours Samplus', 'Murda', 'S Beater', 'Baze', 'Point Blank', 'Patra Kabatesi', 'La Santa Grifa', 'MYKKA', 'Piter-G', 'BL@CKBOX', 'Gnrl Ape1', 'Stewie G', 'Big Momma', 'KC Ortiz', 'Trapperman Dale', 'Cash Click Boog', 'Murs', 'Becky G', 'Tempo', 'SDM', 'Joey Bada$$', 'Guru Hebballi', 'Young Scooter', 'Truffel the Phunky Phaqir', 'Cinnay', 'J-Lamo', 'Sharif', 'Maxy Jay', 'Kendo', 'Mic O', 'CA7RIEL & Paco Amoroso', 'Djadja & Dinaz', 'Mclyne', 'Cool D', 'Foyone', 'Delaossa', 'Granuja', 'Dizzy Wright', 'Charlie Hijos Bastardos', 'Islas Junior', 'Omar Varela', 'Aya Nakamura', 'Pacho', 'Gemitaiz', 'Steve Lean', 'Akhil', 'Mardn', 'Stina Velocette', 'Wizdom', 'Sal ...

# %%
print(f"La lista del genero hip hop --> {lista_hiphop}")

lista_artistas = list(artistas_hiphop)  # Convertimos el set en lista
print("-" * 60)
print(f"Los artistas en hip hop son: {lista_artistas} con {len(lista_artistas)} artistas")
# Out:
# La lista del genero hip hop --> [('MHD', 'hip-hop', 'Afro Trap Pt. 3 (Champions League)', 2016), ('Post Malone', 'hip-hop', 'Congratulations', 2016), ('Quavo', 'hip-hop', 'Congratulations', 2016), ('Maikel Delacalle', 'hip-hop', 'Ganas', 2016), ('Kase.O', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('Hermano L', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('Shabu One Shant', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('McKlopedia', 'hip-hop', 'Pavos Reales (con Hermano L, Shabu One Shant y Mcklopedia)', 2016), ('Dvice', 'hip-hop', 'Hablame 2', 2016), ('Alex Kyza', 'hip-hop', 'Hablame 2', 2016), ('Darkiel', 'hip-hop', 'Hablame 2', 2016), ('Ñengo Flow', 'hip-hop', 'Hablame 2', 2016), ('Anuel AA', 'hip-hop', 'Hablame 2', 2016), ('Bryant Myers', 'hip-hop', 'Hablame 2', 2016), ('Lary Over', 'hip-hop', 'Hablame 2', 2016), ('Almighty', 'hip-hop', 'Hablame 2', 2016), ('Juanka', 'hip-hop', 'Hablame 2', 2016), ('Kase.O', 'hip-hop', 'Yemen', 2016), ('Kase.O', 'hip-hop', 'Esto No Para', 2016), ('Rels B', 'hip-hop', 'Baila Más', 2016), ('Javier Simon', 'hip-hop', 'Baila Más', 2016), ('Natos y Waor', 'hip-hop', 'Por ti', 2016), ('Anuel AA', 'hip-hop', 'Check', 2016), ('PNL', 'hip-hop', 'Uranus', 2016), ('Arcángel', 'hip-hop', 'Me Llamas', 2016), ('Mark B.', 'hip-hop', 'Me Llamas', 2016), ('De La Ghetto', 'hip-hop', 'Me Llamas', 2016), ('Bad Bunny', 'hip-hop', 'Me Llamas', 2016), ('Amenazzy', 'hip-hop', 'Me Llamas', 2016), ('Kase.O', 'hip-hop', 'Mitad y Mitad (con Najwa)', 2016), ('Najwa', 'hip-hop', 'Mitad y Mitad (con Najwa)', 2016), ('Drake', 'hip-hop', 'Too Good', 2016), ('Rihanna', 'hip-hop', 'Too Good', 2016), ('Kaze', 'hip-hop', 'Obsceno', 2016), ('Kase.O', 'hip-hop', 'Mazas y Catapultas', 2016), ('Drake', 'hip-hop', '9', 2016), ('Kase.O', 'hip-hop', 'Outro', 2016), ('Rvssian', 'hip-hop', 'Privado', 2016), ('Nicky Jam', 'hip-hop', 'Privado', 2016), ('Farruko', 'hip-hop', 'Privado', 2016), ('Arcángel', 'hip-hop', 'Privado', 2016), ('Konshens', 'hip-hop', 'Privado', 2016), ('Arce', 'hip-hop', 'T.H.C.', 2016), ('ieathumns', 'hip-hop', 'Made In Taiwan', 2016), ('Anuel AA', 'hip-hop', 'Nunca Sapo', 2016), ('Yomo', 'hip-hop', 'Juguetona - Remix', 2016), ('Wisin', 'hip-hop', 'Juguetona - Remix', 2016), ('Farruko', 'hip-hop', 'Juguetona - Remix', 2016), ('Tito "El Bambino"', 'hip-hop', 'Juguetona - Remix', 2016), ('Darell', 'hip-hop', 'Ninguno Se Monta', 2016), ('Anuel AA', 'hip-hop', 'Ninguno Se Monta', 2016), ('Tempo', 'hip-hop', 'Ninguno Se Monta', 2016), ('Juanka', 'hip-hop', 'Ninguno Se Monta', 2016), ('Lito Kirino', 'hip-hop', 'Ninguno Se Monta', 2016), ('Bryant Myers', 'hip-hop', 'Ninguno Se Monta', 2016), ('Kanye West', 'hip-hop', 'Saint Pablo', 2016), ('Cosculluela', 'hip-hop', 'Black Ops', 2016), ('Kaze', 'hip-hop', 'Venga Lo Que Venga', 2016), ('LFAM', 'hip-hop', 'Gang Banger', 2016), ('Dudu', 'hip-hop', 'Gang Banger', 2016), ('Charflex', 'hip-hop', 'Gang Banger', 2016), ('Kase.O', 'hip-hop', 'Amor Sin Cláusulas', 2016), ('Natos y Waor', 'hip-hop', 'Rara Avis', 2016), ('Canserbero', 'hip-hop', 'Buenas Noches', 2016), ('NicoJP', 'hip-hop', 'Buenas Noches', 2016), ('Drake', 'hip-hop', 'Feel No Ways', 2016), ('Meek Mill', 'hip-hop', 'Blue Notes', 2016), ('Kase.O', 'hip-hop', 'Repartiendo Arte', 2016), ('Soge', 'hip-hop', 'Entra', 2016), ('Arce', 'hip-hop', 'Freya', 2016), ('Denom', 'hip-hop', 'Freya', 2016), ('Brytiago', 'hip-hop', 'Punto G', 2016), ('Darell', 'hip-hop', 'Punto G', 2016), ('Kaze', 'hip-hop', 'Rap', 2016), ('Natos y Waor', 'hip-hop', 'Elegante (feat. Ivan Cano)', 2016), ('Ivan Cano', 'hip-hop', 'Elegante (feat. Ivan Cano)', 2016), ('Liana Malva', 'hip-hop', 'Te quiero', 2016), ('Canserbero', 'hip-hop', 'Te quiero', 2016), ('Solo Soul', 'hip-hop', 'Te quiero', 2016), ('Farruko', 'hip-hop', 'Así Crecí', 2016), ('Young Thug', 'hip-hop', 'Digits', 2016), ('Travis Scott', 'hip-hop', 'coordinate', 2016), ('Myke Towers ...
# ------------------------------------------------------------
# Los artistas en hip hop son: ['Raj Mahal', 'Quimico Ultra Mega', 'Fly Anakin', 'Sherry-ou', 'Assim', 'InfaRed', 'El Jincho', 'B.I.G', 'Icee', 'Maffy', 'Rich Vagos', 'Mrs M', 'Tyga', 'Lil Juu Widdaus', 'A Boogie Wit da Hoodie', 'MTM', 'Quality Control', 'PNL', 'Baby Gas', 'Bonez MC', 'Rogachev', 'Ayax y Prok', 'Anuel AA', 'Cilvaringz', 'Jay Romero', 'Biggie Paul', 'Gravy', 'Residente', 'ST!llness', 'SCH', 'Lord Apex', 'Desi Arnez', 'Vaze Haze', 'River', 'Kwasi', 'Carlytos Vela', 'Lui-G 21+', 'Loyle Carner', 'Alexis y Fido', 'Blizz', 'MicrowaveMan', 'Makassy', 'Carla Barnes', 'Mase', 'Cosculluela', 'Relle Caine', 'Edoby', 'Kaele Bigger', 'Mr Ammo', 'Rich Kidd', 'Venom', 'Ghali', 'Mr Noon', 'Xtacy', 'The Essence', 'Koba LaD', 'Risskant', 'Grind', 'Sleazy F Baby', 'Ironik', 'TBF', 'Ben Whale', 'SiR', 'Lil P', 'Anetta', 'Big M.I.C', 'Daddy Yankee', 'BSTFRND', 'Tom Misch', 'Tr1ckmusic', 'Ghetto B', 'C. Tangana', 'Lester Nowhere', 'TinTin V.', 'Skinny Stylus', 'Christian', 'Calero LDN', 'Bohemia', 'Control Machete', 'Kempi', 'Brulux', 'Tuamie', 'Klassik', 'Nag', 'Liiight', 'Myke Bogan', 'Emy Soul', 'DJ Sem', 'Adje', 'Elemental', 'Ele A El Dominio', 'CASTRO', "Sav'o", 'ShoSho', 'Ray Rizzy', '3robi', 'Biggs', 'Mad Stage', 'Anonimus', 'Rich The Kid', 'Post Malone', 'Ghostemane', 'Kalash Criminel', 'Yung Sarria', 'Revol', 'Hugo TSR', 'Pitizion', 'Zacari', 'Jeon', 'Swelto', 'Khaled', 'Paper Tiger', 'DaBaby', 'Jon Z', 'Gona', 'Omar Musa', 'Klondike Kat', 'Almighty', 'Recycled J', 'Tito Flow', 'Diplo', 'El Jose', 'Chicolisto', 'Vince Staples', 'Travis Scott', 'TL Jones', 'Vincent Van Great', 'M7', 'Anye Elite', 'Анна Хмара', 'PARTYNEXTDOOR', 'Lil Skritt', 'PEACE CHONG', 'Tereza', 'Kinetical', '42', 'Aitch', 'Super Yei', 'Wasabi', 'Ripp Flamez', 'Shady Nate', 'Tee Grizzley', 'Checkmate', 'EKR', 'Öökülm', 'Grupa Banana', 'Charlie Puth', 'Camb', 'Oscu', 'Young Lox', 'Frank Waln', 'David Scheid', 'Dillaz', 'Rober del Pyro', 'Big Soto', 'Najee Janey', 'Adán Cruz', 'Natos y Waor', 'Tyrek Greene', 'Feinos', 'YSY A', 'Ice One', 'Da Gudda Jazz', 'Summer Cem', 'J. Cole', 'Bman', 'Luke Vallen', 'Snow', 'Pouya', 'DJ Michael 5000 Watts', 'Kuniva', 'Hunter', 'Chanda Mbao', 'Berny', 'Muhnee', 'Ele A', 'Nati Hassid', 'Zaman', 'Sr Pablo', 'Dowba Montana', 'Meta Four', 'Shelow Shaq', 'Urban Hype', 'Denom', 'PB', 'Gata Cattana', "John'nay Lasha", '8L', 'Pistolposse', 'Odd Nosdam', 'Swae Lee', 'SLiNK', 'Duffel Bag Hottie', 'Hanjin Tan', 'Ruelle', 'Sibel', 'Moe Pope', 'Illinformed', 'Dyrti San', 'Lary Over', 'Raggio', 'Kid Indigo', 'VETO', 'Los Serenos Sefarad', 'Amazin Payne', 'Son Of Saturn', 'R De Rumba', 'Rah-C', 'Dintluanga Tochhawng', 'The WAAPA Gospel Choir', 'Rich The Factor', 'Choppa', 'Soprano', 'MadeinTYO', 'Bru Lei', 'Santa RM', 'Serengeti', 'Gera MX', 'The Cancel', 'Tokztero', 'Rendition', 'Kaydy Cain', 'Kane', 'Upol Islam', 'Buhodermia 夜', 'Atari Hanzo', 'Maestro Fresh Wes', 'Hamza', 'Negro Gonzáles', 'Felo Blonck', 'AVA', 'Promotioneel', 'Seven Kayne', 'Medusa Prods', 'CISKO', 'Future', 'Money Man', 'mgk', 'STL GLD', 'Beret', 'Avenue', 'Marbletop Orchestra', 'Icaki', 'BKO', 'Tiff the Gift', 'Konshens', 'Pain Loc', 'Dudu', 'Shle Berry', 'Dark Polo Gang', 'Dutch Rebelle', 'Nyukyung', 'Hyu', 'Chuc Eezi', 'Robot95', 'Gambeta', 'YFilla', 'Lil Pump', 'Vagrant Real Estate', 'ShabZi Madallion', 'Tizzy x Brandz', 'Ours Samplus', 'Murda', 'S Beater', 'Baze', 'Point Blank', 'Patra Kabatesi', 'La Santa Grifa', 'MYKKA', 'Piter-G', 'BL@CKBOX', 'Gnrl Ape1', 'Stewie G', 'Big Momma', 'KC Ortiz', 'Trapperman Dale', 'Cash Click Boog', 'Murs', 'Becky G', 'Tempo', 'SDM', 'Joey Bada$$', 'Guru Hebballi', 'Young Scooter', 'Truffel the Phunky Phaqir', 'Cinnay', 'J-Lamo', 'Sharif', 'Maxy Jay', 'Kendo', 'Mic O', 'CA7RIEL & Paco Amoroso', 'Djadja & Dinaz', 'Mclyne', 'Cool D', 'Foyone', 'Delaossa', 'Granuja', 'Dizzy Wright', 'Charlie Hijos Bastardos', 'Islas Junior', 'Omar Varela', 'Aya Nakamura', 'Pacho', 'Gemitaiz', 'Steve Lean', 'Akhil', 'Mardn', 'Stina Velocette', 'Wizdo ...

# %%
df_hiphop = pd.DataFrame(lista_hiphop, columns=["artist", "genre", "track_name", "year"])

# %%
print(df_hiphop.head())
# Out:
#              artist    genre  \
# 0               MHD  hip-hop
# 1       Post Malone  hip-hop
# 2             Quavo  hip-hop
# 3  Maikel Delacalle  hip-hop
# 4            Kase.O  hip-hop
#
#                                           track_name  year
# 0                 Afro Trap Pt. 3 (Champions League)  2016
# 1                                    Congratulations  2016
# 2                                    Congratulations  2016
# 3                                              Ganas  2016
# 4  Pavos Reales (con Hermano L, Shabu One Shant y...  2016

# %%
df_hiphop.to_csv("lista_hiphop.csv", index=False)

# %%
with open("artistas_hiphop.json", "w", encoding="utf-8") as fichero:
    json.dump(sorted(artistas_hiphop), fichero, ensure_ascii=False, indent=4)

# %%
API_KEY = "e8a8b4cd33b86332f741d2fd683ccabb"  # <-- pon tu API key aqui

def info_lastfm(artista):
    # Creamos una funcion que si le damos el nombre de un artista devuelve su info de Last.fm
    url = "https://ws.audioscrobbler.com/2.0/"  # endpoint

    params = {
        "method": "artist.getinfo",
        "artist": artista,
        "api_key": API_KEY,
        "format": "json"
    }

    response = requests.get(url, params=params, timeout=20)

    if response.status_code != 200:
        print("Error en la petición")
        return None

    data = response.json()

    # A veces Last.fm devuelve {"error":..., "message":...}
    if "artist" not in data:
        raise KeyError("artist")

    artist = data["artist"]

    return (
        artista,
        artist.get("bio", {}).get("summary"),
        artist.get("stats", {}).get("listeners"),
        artist.get("stats", {}).get("playcount"),
        [a.get("name") for a in artist.get("similar", {}).get("artist", [])]
    )


resultados = []
errores = []

for artista in lista_artistas:  # Bucle para que itere por la lista de artistas
    try:
        info = info_lastfm(artista)  # aplicar la funcion
        if info is not None:
            resultados.append(info)
    except Exception as e:
        errores.append({
            "artista": artista,
            "error": str(e)
        })
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 42
#      40 for artista in lista_artistas:  # Bucle para que itere por la lista de artistas
#      41     try:
# ---> 42         info = info_lastfm(artista)  # aplicar la funcion
#      43         if info is not None:
#      44             resultados.append(info)
#
# Cell In[28], line 14, in info_lastfm(artista)
#       5 url = "https://ws.audioscrobbler.com/2.0/"  # endpoint
#       7 params = {
#       8     "method": "artist.getinfo",
#       9     "artist": artista,
#      10     "api_key": API_KEY,
#      11     "format": "json"
#      12 }
# ---> 14 response = requests.get(url, params=params, timeout=20)
#      16 if response.status_code != 200:
#      17     print("Error en la petición")
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     793     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     794     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797         sock=sock,
#     798         cert_reqs=self.cert_reqs,
#     799         ssl_version=self.ssl_version,
#     800         ssl_minimum_version=self.ssl_minimum_version,
#     801         ssl_maximum_version=self.ssl_maximum_version,
#     802         ca_certs=self.ca_certs,
#     803         ca_cert_dir=self.ca_cert_dir,
#     804         ca_cert_data=self.ca_cert_data,
#     805         cert_file=self.cert_file,
#     806         key_file=self.key_file,
#     807         key_password=self.key_password,
#     808         server_hostname=server_hostname_rm_dot,
#     809         ssl_context=self.ssl_context,
#     810         tls_in_tls=tls_in_tls,
#     811         assert_hostname=self.assert_hostname,
#     812         assert_fingerprint=self.assert_fingerprint,
#     813     )
#     814     self.sock = sock_and_verified.socket
#     816 # If an error occurs during connection/handshake we may need to release
#     817 # our lock so another connection can probe the origin.
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     972     if is_ipaddress(normalized):
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#     989     if assert_fingerprint:
#
# File c:\Users\Personal\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:461, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     459 if ca_certs or ca_cert_dir or ca_cert_data:
#     460     try:
# --> 461         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     462     except OSError as e:
#     463         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
print(
    f"Resultado de la busqueda --> {resultados} \n"
    f"{'-' * 100}\n"
    f"La longitud de los resultados --> {len(resultados)} \n"
    f"{'-' * 100}\n"
    f"Errores encontrados --> {errores}"
)
# Out:
# Resultado de la busqueda --> [('Raj Mahal', ' <a href="https://www.last.fm/music/Raj+Mahal">Read more on Last.fm</a>', '4503', '22410', ['MBtheLIGHT', 'kesswa', 'jusoul', 'zeroh', 'House Shoes']), ('Quimico Ultra Mega', ' <a href="https://www.last.fm/music/Quimico+Ultra+Mega">Read more on Last.fm</a>', '26597', '153374', ['El Mayor Clasico', 'El Fother', 'Secreto "El Famoso Biberon"', 'El Fecho RD', 'Treintisiete']), ('Fly Anakin', 'Fly Anakin (born Frank L. Walton, Jr.) is an American rapper from Richmond, Virginia; best known as a member of the collectives Mutant Academy and Scheme Team. In 2014, Fly Anakin formed the Mutant Academy collective with fellow rapper Henny L.O., releasing the collaborative mixtape Open House that same year. This was followed by mirrors_episode.1, a collaborative EP with producer Ewonee. Anakin\'s debut solo mixtape Elsewhere Ave. was finally released in July 2015; followed by The Mandate [side a] EP with Koncept Jack$on <a href="https://www.last.fm/music/Fly+Anakin">Read more on Last.fm</a>', '59516', '1072079', ['Mutant Academy', 'Pink Siifu & Fly Anakin', 'ANKHLEJOHN', 'Obijuan', 'al.divino']), ('Sherry-ou', ' <a href="https://www.last.fm/music/Sherry-ou">Read more on Last.fm</a>', '520', '2433', ['davey6000', 'LCone', 'Stereo Luchs', 'chekaa', 'Manillio']), ('Assim', ' <a href="https://www.last.fm/music/Assim">Read more on Last.fm</a>', '250', '712', ['Ehrenmann', 'JACID BABY', 'JoshiParka', 'Yelen', 'Tony Ryo']), ('InfaRed', ' <a href="https://www.last.fm/music/Infared">Read more on Last.fm</a>', '1161', '7596', ['The Sickest Squad & Frazzbass', 'Negative Network', 'Fotzenarchitekt', 'Mutante', 'Bouncemasters vs. The Vizitor']), ('El Jincho', ' <a href="https://www.last.fm/music/El+Jincho">Read more on Last.fm</a>', '21228', '360735', ['Jarfaiter', 'prok', 'Arce', 'DOLLAR SELMOUNI', 'Nikone']), ('B.I.G', 'There are more than one artist using the name B.I.G.\n\n1) B.I.G (Hangul: 비아이지; an acronym for Boys In Groove) is a five-member South Korean boy band under GH Entertainment. The group consists of J-hoon, Gunmin,  Heedo and Jinseok.\nGunmin is currently part of the group NIK.\nBenji left the group in 2020, in 2021 Minpyo announced that he has left the group as well.\n\n2) Dimos and Michalis Siavelis, 29 and 27 years old respectively, started off with the best possible foundations <a href="https://www.last.fm/music/B.I.G">Read more on Last.fm</a>', '21046', '258394', ['Boys Republic', 'U-KISS', 'VIXX', 'ONF', 'B1A4']), ('Icee', ' <a href="https://www.last.fm/music/Icee">Read more on Last.fm</a>', '1241', '6516', ['Baby Boy Ene', '14 Caliber', 'Pistol Cee', 'Proud By Choice', 'Maloso']), ('Maffy', ' <a href="https://www.last.fm/music/Maffy">Read more on Last.fm</a>', '224', '1086', ['Dwaine feat. Trina, P. Diddy and Keri Hilson', 'Johnny Bravo and Mieczyk', 'Domino feat. Piper', 'Lik and Dak', 'Ryan Housewell feat. Alec Sun Drae']), ('Rich Vagos', ' <a href="https://www.last.fm/music/Rich+Vagos">Read more on Last.fm</a>', '38422', '658106', ['Faruz Feet', 'Yoss Bones', 'El Pinche Mara', 'West Gold', 'Phyzh Eye']), ('Mrs M', ' <a href="https://www.last.fm/music/Mrs+M">Read more on Last.fm</a>', '476', '2900', ['Ginjin', 'AM-C', 'Lil Thug E', 'Davaidasha', 'Choidog']), ('Tyga', 'Micheal Ray Stevenson (born November 19, 1989 in Compton, California), better known by his stage name Tyga, is an American hip hop artist signed to Lil Wayne\'s Young Money Entertainment and Decaydance. He is of Vietnamese and Jamaican descent.  He is the cousin of Travis McCoy, lead vocalist of the group Gym Class Heroes. \n\nIn 2006 he released his first mixtape, Young on Probation, and released his debut studio album, No Introduction, in 2008. He has since released a further mixtapes <a href="https://www.last.fm/music/Tyga">Read more on Last.fm</a>', '2730358', '37920518', ['Kid Ink', 'Chris Brown & Tyga', 'French Montana', 'YG', '2 Chainz']), ('A Boogie Wit da Hoodie', 'Artist Julius Dubose (born December 6, 1995), kn ...
# ----------------------------------------------------------------------------------------------------
# La longitud de los resultados --> 100
# ----------------------------------------------------------------------------------------------------
# Errores encontrados --> [{'artista': 'Lil Juu Widdaus', 'error': "'artist'"}, {'artista': 'Rogachev', 'error': "'artist'"}, {'artista': 'Lui-G 21+', 'error': "'artist'"}, {'artista': 'Carla Barnes', 'error': "'artist'"}, {'artista': 'Mr Ammo', 'error': "'artist'"}, {'artista': 'Emy Soul', 'error': "'artist'"}]

# %%
df_resultado = pd.DataFrame(resultados, columns=["artist", "bio", "listeners", "playcount", "similar_artist"])

# %%
df_resultado.sample(10)
# Out:
#           artist                                                bio listeners  \
# 51      Risskant  Risskant a.k.a. "De Woordvoerder"is a Dutch Hi...      1952
# 60     Big M.I.C   <a href="https://www.last.fm/music/Big+M.I.C"...         1
# 46         Ghali  Ghali, stage name of Ghali Amdouni (Milan, 21 ...    109506
# 38       Makassy   <a href="https://www.last.fm/music/Makassy">R...     11758
# 23   Biggie Paul   <a href="https://www.last.fm/music/Biggie+Pau...       469
# 43  Kaele Bigger   <a href="https://www.last.fm/music/Kaele+Bigg...      1101
# 9          Maffy   <a href="https://www.last.fm/music/Maffy">Rea...       224
# 78           Nag  at least three artists named Nag:\n\n1. punk/p...     12992
# 4          Assim   <a href="https://www.last.fm/music/Assim">Rea...       250
# 65      Ghetto B   <a href="https://www.last.fm/music/Ghetto+B">...         4
#
#    playcount                                     similar_artist
# 51     16386    [KGV, Tim Beumers, Skenkie, Cartes, $KEER&BOO$]
# 60         1                                                 []
# 46   5234523  [Sfera Ebbasta, thasup, Lazza, Charlie Charles...
# 38     62986         [T2R, Abou Debeing, Fababy, Dj BaBs, Ma2x]
# 23      2941  [Lanz Khan, Pepito Rella, Nerone, AXOS, Jangy ...
# 43     17454  [Yezzy Wallace, L.A Finesse, MNZR, Tryhan, Gab...
# 9       1086  [Dwaine feat. Trina, P. Diddy and Keri Hilson,...
# 78    128015  [Judy And The Jerks, Safi, Illiterates, Speed ...
# 4        712  [Ehrenmann, JACID BABY, JoshiParka, Yelen, Ton...
# 65        12                                                 []

# %%
df_resultado.to_csv("resultado_hiphop.csv", index=False)
