# %%
import json

# %%
with open ("archivos_json/definitivo.json", "r") as fichero:
        definitivo = json.load(fichero)

def extraer_por_genero(definitivo, rock):
    lista_rock = []
    for item in definitivo:
        año = item.get("year")
        if item.get("genre") == rock and 2016 <= año <= 2020:
            info = {"Artista": item.get("artist_name"),
                    "Género": item.get("genre"),
                    "Nombre de la cancion": item.get("track_name"),
                    "Año de lanzamiento": item.get("year")}
             
            lista_rock.append(info)
    canciones_totales = lista_rock
    numero_canciones = len(lista_rock)
    print(numero_canciones)
    return canciones_totales 
     
extraer_por_genero(definitivo, "rock")
# Out:
# 1679
# [{'Artista': 'Upchurch',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dirty Boys',
#   'Año de lanzamiento': 2016},
#  {'Artista': '091',
#   'Género': 'rock',
#   'Nombre de la cancion': '2000 Locos',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Los Flechazos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Suzette',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dark Necessities',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'THE ORAL CIGARETTES',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Kyouran Hey Kids!!',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Feel Invincible',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Resistance',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Goodbye Angels',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'KALEO',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hot Blood',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Phil Collins',
#   'Género': 'rock',
#   'Nombre de la cancion': 'True Colors - 2016 Remaster',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sick Love',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Pixies',
#   'Género': 'rock',
#   'Nombre de la cancion': 'All I Think About Now',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Cicatrices',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Longest Wave',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Strokes',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Oblivius',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Daydreaming',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Back from the Dead',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Elefantes',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Duele (feat. Bunbury)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Bunbury',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Duele (feat. Bunbury)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Go Robot',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Zoé',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Nada',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Bunbury',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Nada',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Bowie',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lazarus',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'True Love Waits',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Black Sabbath',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Paranoid',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'I Want to Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Spectre',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Black Rose',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Danko Jones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Black Rose',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Decks Dark',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Present Tense',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Royal Republic',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Getting Along',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Sweet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Fox on the Run - Single Version',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Getaway',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Los Destellos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Guajira Sicodélica',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Elvis Presley',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Heartbreak Hotel (1956 Single)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Glass Eyes',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Colombiana',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Undefeated',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Sleeper',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Atomic',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rapino Brothers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Atomic',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'State of Mine',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Rise',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Bowie',
#   'Género': 'rock',
#   'Nombre de la cancion': '★',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Keane',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Tear Up This Town - Orchestral Version / From "A Monster Calls" Original Motion Picture Soundtrack',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Inconscientes',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Arden las Sábanas',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Strokes',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Threat of Joy',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Joe Bonamassa',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Drive',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Deftones',
#   'Género': 'rock',
#   'Nombre de la cancion': '(L)MIRL',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'American Authors',
#   'Género': 'rock',
#   'Nombre de la cancion': "I'm Born To Run",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Vivamos el Momento',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Burn the Witch',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Temple Of The Dog',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hunger Strike - 25th Anniversary Mix',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ful Stop',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Metallica',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Now That We’re Dead',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Travis',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Idlewild',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Josephine Oniyama',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Idlewild',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'MAN WITH A MISSION',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Seven Deadly Sins',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Phil Collins',
#   'Género': 'rock',
#   'Nombre de la cancion': 'I Wish It Would Rain Down - 2016 Remaster',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Babasonicos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Vampi - En Vivo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Encore',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Deftones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Phantom Bride',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Las Pelotas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Víctimas del Cielo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Mike Oldfield',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Poison Arrows - Remastered 2015',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rio',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lo Peor de Todo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Mike Oldfield',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Tricks Of The Light - Remastered 2015',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Record Company',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Off The Ground',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'El Drogas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'En blanco y negro (con todos los invitados)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Bliss',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Ciro y los Persas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Luz',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Deftones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hearts / Wires',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Culpables',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Bowie',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dollar Days',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Celtas Cortos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'El Blues Del Pescador - Bonus Track Acústico',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'El Drogas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Todos mirando (con Vito Sinkope)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'VITO',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Todos mirando (con Vito Sinkope)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Cars',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Good Times Roll - 2016 Remaster',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'All Them Witches',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Marriage Of Coyote Woman',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Bowie',
#   'Género': 'rock',
#   'Nombre de la cancion': "'Tis A Pity She Was A Whore",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Let It Burn',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Highly Suspect',
#   'Género': 'rock',
#   'Nombre de la cancion': 'My Name Is Human',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Huracán',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Gran Encuentro',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Margarita Lugue',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Chucta Carajo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rio',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Contéstame',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Identikit',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Rolling Stones',
#   'Género': 'rock',
#   'Nombre de la cancion': "Ride 'Em On Down",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Los Prisioneros',
#   'Género': 'rock',
#   'Nombre de la cancion': 'El Baile de los Que Sobrán',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Mike Oldfield',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Talk About Your Life - Remastered 2015',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Bowie',
#   'Género': 'rock',
#   'Nombre de la cancion': "I Can't Give Everything Away",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rio',
#   'Género': 'rock',
#   'Nombre de la cancion': 'La Universidad (cosa de Locos)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Black Sabbath',
#   'Género': 'rock',
#   'Nombre de la cancion': 'War Pigs',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Coti',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Luz De Día - En Vivo En El Gran Rex / 2015',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Bones of J.R. Jones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Heat',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Babasonicos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'El Colmo - En Vivo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Rolling Stones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Just Your Fool',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Fray',
#   'Género': 'rock',
#   'Nombre de la cancion': 'How to Save a Life',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Suede',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Outsiders',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Feasting on the Flowers',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Mike Oldfield',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Crystal Gazing - Remastered 2015',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Car Seat Headrest',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Fill In The Blank',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Car Seat Headrest',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Drunk Drivers/Killer Whales',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Estelares',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Es el Amor',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Black Keys',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Keep Me',
#   'Año de lanzamiento': 2016},
#  {'Artista': '3 Doors Down',
#   'Género': 'rock',
#   'Nombre de la cancion': 'In The Dark',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Burn It Down',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Metallica',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Halo On Fire',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Numbers',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'SID',
#   'Género': 'rock',
#   'Nombre de la cancion': '乱舞のメロディ',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Bowie',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sue (Or In A Season Of Crime)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Rolling Stones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hate To See You Go',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Blackberry Smoke',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Waiting for the Thunder',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Stars',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'All Them Witches',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Charles William',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Fray',
#   'Género': 'rock',
#   'Nombre de la cancion': 'How To Save A Life',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Bowie',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Girl Loves Me',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Brian Jonestown Massacre',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Fingertips',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Mike Oldfield',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Discovery - Remastered 2015',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Forever Grey',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Style Is Death',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'El Drogas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'No sé qué hacer contigo (con Leiva)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Leiva',
#   'Género': 'rock',
#   'Nombre de la cancion': 'No sé qué hacer contigo (con Leiva)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'MAN WITH A MISSION',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Raise your flag',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Miguel',
#   'Género': 'rock',
#   'Nombre de la cancion': 'waves - Tame Impala Remix',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Tame Impala',
#   'Género': 'rock',
#   'Nombre de la cancion': 'waves - Tame Impala Remix',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Kills',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Doing It To Death',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Sixx:A.M.',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Prayers For The Damned',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Monster Truck',
#   'Género': 'rock',
#   'Nombre de la cancion': "Don't Tell Me How To Live",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Fray',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Look After You',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Desert Island Disk',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Babasonicos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Cómo Eran las Cosas - En Vivo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'El Drogas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Barrio conflictivo (con Kutxi Romero Marea)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Kutxi Romero',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Barrio conflictivo (con Kutxi Romero Marea)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Bunbury',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Vámonos',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Aterciopelados',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Maligno (feat. León Larregui)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'León Larregui',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Maligno (feat. León Larregui)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'DIIV',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Under the Sun',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Margarita Lugue',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Cuatro Tablas',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'We Turn Red',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Richard Ashcroft',
#   'Género': 'rock',
#   'Nombre de la cancion': "They Don't Own Me",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Evanescence',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Farther Away',
#   'Año de lanzamiento': 2016},
#  {'Artista': '9mm Parabellum Bullet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'インフェルノ',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Wolfmother',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Victorious',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rio',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Todo Estaba Bien',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Black Sabbath',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Iron Man',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Thousand Foot Krutch',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lifeline',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Temple Of The Dog',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Say Hello 2 Heaven - 25th Anniversary Mix',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Pretty Vicious',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Cave Song',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Margarita Lugue',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Caro Estas Pagando',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Pretty Reckless',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Take Me Down',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'BABYMETAL',
#   'Género': 'rock',
#   'Nombre de la cancion': 'GJ!',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Goodbye Forever',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Dylan LeBlanc',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Cautionary Tale',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Billy Talent',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Afraid of Heights',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Out of Hell',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Mumford & Sons',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Friend of the Devil',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Tinker Tailor Soldier Sailor Rich Man Poor Man Beggar Man Thief',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Prophets Of Rage',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Prophets Of Rage',
#   'Año de lanzamiento': 2016},
#  {'Artista': '3 Doors Down',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Still Alive',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'American Authors',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Go Big Or Go Home',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Morgan Delt',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Some Sunsick Day',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Tedeschi Trucks Band',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hear Me',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'This Cold Night',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Black Cathedral',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'DIIV',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Out of Mind',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Bonafide',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Bottle of Jack',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Saviors of the World',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Sun Rising',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Otherside',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Rides',
#   'Género': 'rock',
#   'Nombre de la cancion': "I've Got To Use My Imagination",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'SiM',
#   'Género': 'rock',
#   'Nombre de la cancion': 'EXiSTENCE',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Dandy Warhols',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Styggo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Gates Of Babylon',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Hunter',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Joe Bonamassa',
#   'Género': 'rock',
#   'Nombre de la cancion': "I'll Play The Blues For You (Live)",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Too Close To Touch',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sympathy',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Relámpagos',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'La Beriso',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Pensamientos',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Emerson, Lake & Palmer',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Fanfare for the Common Man (Single Edit)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'From Ashes to New',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Through It All',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Placebo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Every You, Every Me',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Chubby Checker',
#   'Género': 'rock',
#   'Nombre de la cancion': "Let's Twist Again - Radio Version",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Black Keys',
#   'Género': 'rock',
#   'Nombre de la cancion': '10 A.M. Automatic',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Margarita Lugue',
#   'Género': 'rock',
#   'Nombre de la cancion': 'El Pañuelito',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Detroit',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Mystery Lights',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Follow Me Home',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Mary Jane Kelly',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Bastille',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Anchor',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Alter Bridge',
#   'Género': 'rock',
#   'Nombre de la cancion': 'My Champion',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Travis',
#   'Género': 'rock',
#   'Nombre de la cancion': 'What Will Come',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Battleship Chains',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Sixx:A.M.',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Rise',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Detroit Cobras',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Midnite Blues',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Three Days Grace',
#   'Género': 'rock',
#   'Nombre de la cancion': "You Don't Get Me High Anymore",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Led Zeppelin',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Girl I Love She Got Long Black Wavy Hair - Live on Tasty Pop Sundae from BBC Sessions;Remaster',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'O Rappa',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sentimento - Ao vivo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Eric Clapton',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Layla (with J.J. Cale) - Live at Ipayone Center, San Diego, CA, 3/15/2007',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Eric Clapton',
#   'Género': 'rock',
#   'Nombre de la cancion': "Can't Let You Do It",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'This Ticonderoga',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Los Destellos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'El Boogalo del Perro',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Red Hot Chili Peppers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dreams of a Samurai',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'I Prevail',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lifelines',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Ciro y los Persas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Similar',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Famous',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'MY FIRST STORY',
#   'Género': 'rock',
#   'Nombre de la cancion': '不可逆リプレイス - Fukagyaku Replace',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Model',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Mey',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Los Destellos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'El Marcianito',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Deftones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Prayers / Triangles',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Pineapple Thief',
#   'Género': 'rock',
#   'Nombre de la cancion': 'In Exile',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Juaneco Y Su Combo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Me Robaron Mi Runa Mula',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Moth & The Flame',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Young & Unafraid',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Tedeschi Trucks Band',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Anyhow',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Airbag',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Apocalipsis Confort',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Corpore',
#   'Género': 'rock',
#   'Nombre de la cancion': 'She Came Like A Hurricane',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rob Zombie',
#   'Género': 'rock',
#   'Nombre de la cancion': "Well, Everybody's Fucking In A U.F.O.",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Sixx:A.M.',
#   'Género': 'rock',
#   'Nombre de la cancion': "Maybe It's Time",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'TK from Ling tosite sigure',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Signal',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Joe Bonamassa',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Valley Runs Low',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Marie Laveau',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rebelution',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lay My Claim',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Leader',
#   'Género': 'rock',
#   'Nombre de la cancion': 'This Is Why We Bleed',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Metallica',
#   'Género': 'rock',
#   'Nombre de la cancion': 'When A Blind Man Cries',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'SHISHAMO',
#   'Género': 'rock',
#   'Nombre de la cancion': '中庭の少女たち',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rebelution',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Pretty Lady',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Nickelback',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dirty Laundry',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Wolfmother',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Gypsy Caravan',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Phil Lesh & Communion',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Allen Toussaint',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Bill Kreutzmann',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'David Grisman',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Peter Frampton',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Buddy Miller',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Jorma Kaukonen',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Jimmy Cliff',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Mickey Hart',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Billy & The Kids',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ripple - Live',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'THE ORAL CIGARETTES',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Kizukeyo Baby',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'DADAROMA',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Risley Circus',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Thundermother',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hellevator',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Boxer Rebellion',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Big Ideas',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ill Wind',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Joe Bonamassa',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Mountain Climbing',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Theory of a Deadman',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hallelujah',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Dirty Heads',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Oxygen',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Normandie',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Awakening',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Ritchie Valens',
#   'Género': 'rock',
#   'Nombre de la cancion': 'La Bamba',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Jackyl',
#   'Género': 'rock',
#   'Nombre de la cancion': "Everyone's a Winner",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'American Authors',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Pocket Full Of Gold',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Tedeschi Trucks Band',
#   'Género': 'rock',
#   'Nombre de la cancion': "Don't Know What It Means",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Gerardo Morán',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ahora Que Estoy Vivo',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Boxer Rebellion',
#   'Género': 'rock',
#   'Nombre de la cancion': "Let's Disappear",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Car Seat Headrest',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Destroyed By Hippie Powers',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Pink Floyd',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Echoes (Live at Pompeii) [2016 Remix]',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Fray',
#   'Género': 'rock',
#   'Nombre de la cancion': 'You Found Me',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Blockheads',
#   'Género': 'rock',
#   'Nombre de la cancion': "Can't Get Enough",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'If These Trees Could Talk',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Giving Tree',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Magic Shoppe',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Redhead',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Pixies',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Bel Esprit',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Through Fire',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Stronger (Extended Version)',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'State of Mine',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Killing Me',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Rio',
#   'Género': 'rock',
#   'Nombre de la cancion': 'La Empiezo a Odiar',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Sixx:A.M.',
#   'Género': 'rock',
#   'Nombre de la cancion': 'We Will Not Go Quietly',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Eric Clapton',
#   'Género': 'rock',
#   'Nombre de la cancion': "Somebody's Knockin'",
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Heavy',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Turn Up',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Evanescence',
#   'Género': 'rock',
#   'Nombre de la cancion': 'If You Don’t Mind',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Fray',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Singing Low',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Night Moves',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Carl Sagan',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Blackberry Smoke',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sunrise in Texas',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'The Kills',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Impossible Tracks',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Libido',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Pero Aún Sigo Viéndote',
#   'Año de lanzamiento': 2016},
#  {'Artista': '3 Doors Down',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Inside Of Me',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'Joe Bonamassa',
#   'Género': 'rock',
#   'Nombre de la cancion': 'No Good Place For The Lonely',
#   'Año de lanzamiento': 2016},
#  {'Artista': 'VI Seconds',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Gawd',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Pignoise',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Todo Me Da Igual',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'David Otero',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Buscando El Sol',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Los Hermanos Dalton',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Nada Suena Igual',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'América de Vigo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Año 2000',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Bunbury',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Parecemos tontos',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Greta Van Fleet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Highway Tune',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Man of War',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Linkin Park',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Battle Symphony',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Ron Gallo',
#   'Género': 'rock',
#   'Nombre de la cancion': "Young Lady, You're Scaring Me",
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Greta Van Fleet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Black Smoke Rising',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Imelda May',
#   'Género': 'rock',
#   'Nombre de la cancion': 'How Bad Can A Good Girl Be',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'The Animals',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The House of the Rising Sun',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Greta Van Fleet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Safari Song',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Let Down - Remastered',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Scorpions',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Follow Your Heart',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Slowdive',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sugar for the Pill',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Foo Fighters',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Sky Is A Neighborhood',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'The Killers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Run For Cover',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Taburete',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Amos del Piano Bar (feat. Hombres G)',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Hombres G',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Amos del Piano Bar (feat. Hombres G)',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Papa Roach',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Help',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'alt-J',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Deadcrush',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Scorpions',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Rock You Like a Hurricane - 2011',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'U2',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ordinary Love - Extraordinary Mix',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'ZZ Top',
#   'Género': 'rock',
#   'Nombre de la cancion': 'La Grange',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Foo Fighters',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Run',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Asking Alexandria',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Alone In A Room',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Gary Clark Jr.',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Come Together',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Junkie XL',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Come Together',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Stone Sour',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Song #3',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Greta Van Fleet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Edge Of Darkness',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Royal Blood',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lights Out',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Linkin Park',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Talking to Myself',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'TOTO',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Africa',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Benito Kamelas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Las Calles Dormidas',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'STARSET',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Monster',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Sweet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ballroom Blitz',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Marilyn Manson',
#   'Género': 'rock',
#   'Nombre de la cancion': 'KILL4ME',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Liam Gallagher',
#   'Género': 'rock',
#   'Nombre de la cancion': "For What It's Worth",
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Tears For Fears',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Head Over Heels',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Papa Roach',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Born For Greatness',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Cult To Follow',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Murder Melody',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'U2',
#   'Género': 'rock',
#   'Nombre de la cancion': 'You’re The Best Thing About Me',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lift',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Manchester Orchestra',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Sunshine',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Mike + The Mechanics',
#   'Género': 'rock',
#   'Nombre de la cancion': "Don't Know What Came Over Me",
#   'Año de lanzamiento': 2017},
#  {'Artista': 'MIYAVI',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Flashback',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Ken Ken',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Flashback',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'NOTHING MORE',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Go To War',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'STARSET',
#   'Género': 'rock',
#   'Nombre de la cancion': 'DIE FOR YOU',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'No Surprises - Remastered',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'ONE OK ROCK',
#   'Género': 'rock',
#   'Nombre de la cancion': 'We Are',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Benito Kamelas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'María',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'alt-J',
#   'Género': 'rock',
#   'Nombre de la cancion': 'In Cold Blood',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'El Mató a un Policía Motorizado',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ahora Imagino Cosas',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Arcade Fire',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Put Your Money on Me',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Royal Blood',
#   'Género': 'rock',
#   'Nombre de la cancion': 'I Only Lie When I Love You',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Tame Impala',
#   'Género': 'rock',
#   'Nombre de la cancion': 'List Of People (To Try And Forget About)',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Radiohead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Exit Music (For A Film) - Remastered',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'ONE OK ROCK',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Take What You Want (feat. 5 Seconds of Summer)',
#   'Año de lanzamiento': 2017},
#  {'Artista': '5 Seconds of Summer',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Take What You Want (feat. 5 Seconds of Summer)',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Greta Van Fleet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'A Change Is Gonna Come',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Blacktop Mojo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dream On',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'All Them Witches',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Am I Going Up?',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Cult To Follow',
#   'Género': 'rock',
#   'Nombre de la cancion': '10 Seconds from Panic',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'The War On Drugs',
#   'Género': 'rock',
#   'Nombre de la cancion': 'In Chains',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Linkin Park',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Nobody Can Save Me',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Ilegales',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Tiempos Nuevos, Tiempos Salvajes - Version 2017',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Cruzando El Charco',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Terminales',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Kraftwerk',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Das Model',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Slowdive',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Slomo',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Falling In Reverse',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Superhero',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Danko Jones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'My Little RnR',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Greta Van Fleet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Flower Power',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Royal Blood',
#   'Género': 'rock',
#   'Nombre de la cancion': 'How Did We Get So Dark?',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Jarabe De Palo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'El lado oscuro',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Greta Van Fleet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Talk On The Street',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'El Último De La Fila',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Como Un Burro Amarrado En La Puerta Del Baile - Remastered',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Amén',
#   'Género': 'rock',
#   'Nombre de la cancion': 'La Chata',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Hollywood Undead',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Riot',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Imelda May',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sixth Sense',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Vestron Vulture',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Phantom',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Benito Kamelas',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Tatuajes',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'The War On Drugs',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Nothing to Find',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'TOPS',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Petals',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Linkin Park',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Invisible',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Slowdive',
#   'Género': 'rock',
#   'Nombre de la cancion': 'No Longer Making Time',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Royal Blood',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hook, Line & Sinker',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'DJ Hamida',
#   'Género': 'rock',
#   'Nombre de la cancion': "C'est une frappe - Radio Edit",
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Lartiste',
#   'Género': 'rock',
#   'Nombre de la cancion': "C'est une frappe - Radio Edit",
#   'Año de lanzamiento': 2017},
#  {'Artista': 'NOTHING MORE',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Fade In / Fade Out',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Glare',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Blank',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Tame Impala',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Taxi’s Here',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'The Technicolors',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Neon Roses',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Tregua',
#   'Género': 'rock',
#   'Nombre de la cancion': 'A Largo Plazo',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Rulo y la contrabanda',
#   'Género': 'rock',
#   'Nombre de la cancion': 'A Largo Plazo',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Slowdive',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Star Roving',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'The Psychedelic Furs',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Ghost in You',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Thundercat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Show You The Way',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Michael McDonald',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Show You The Way',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Kenny Loggins',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Show You The Way',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Cult To Follow',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Down',
#   'Año de lanzamiento': 2017},
#  {'Artista': "Noel Gallagher's High Flying Birds",
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dead in the Water - Live at Rté 2fm Studios, Dublin (Bonus Track)',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Cult To Follow',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Perfect',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'The Score',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Money Run Low',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Foster The People',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lotus Eater',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Sir Sly',
#   'Género': 'rock',
#   'Nombre de la cancion': 'High',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Marilyn Manson',
#   'Género': 'rock',
#   'Nombre de la cancion': 'SAY10',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Fito Paez',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Tu Vida Mi Vida',
#   'Año de lanzamiento': 2017},
#  {'Artista': 'Steve Miller Band',
#   'Género': 'rock',
# ...
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Carolina Durante',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Niña de Hielo',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Shinova',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Cartas de Navegación',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Huecco',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Mirando al cielo (feat. Rozalén) - X Aniversario',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Loquillo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Rey del Glam',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'The Neighbourhood',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Nervous',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Air Supply',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Making Love Out of Nothing at All',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Vanesa Martín',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Desobedecerme (feat. Kany García)',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Esne Beltza',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Argitzeraino',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Ska-P',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Colores',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'VK Blanka',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Black Rover',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Twenty One Pilots',
#   'Género': 'rock',
#   'Nombre de la cancion': 'My Blood',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Lenny Kravitz',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Low',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Kool & The Gang',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Celebration - Single Version',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Glenn Frey',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Heat Is On - From "Beverly Hills Cop" Soundtrack',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Manchester Orchestra',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Gold - Phoebe Bridgers Version',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Marlon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Me supo a poco',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Rawayana',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Sin Ti (feat. La Vida Bohème)',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Bacilos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Perderme Contigo',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'KANKAKU PIERO',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Harukamirai',
#   'Año de lanzamiento': 2018},
#  {'Artista': 'Teejayx6',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dynamic Duo 2 (feat. Kasher Quon)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Kasher Quon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dynamic Duo 2 (feat. Kasher Quon)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Famous',
#   'Género': 'rock',
#   'Nombre de la cancion': '2004',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Scarlett Miller',
#   'Género': 'rock',
#   'Nombre de la cancion': '2002',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Wallows',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Are You Bored Yet? (feat. Clairo)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Clairo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Are You Bored Yet? (feat. Clairo)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Surf Curse',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Disco',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Foster The People',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Imagination',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Celtas Cortos',
#   'Género': 'rock',
#   'Nombre de la cancion': '20 de abril (feat. Fito y Fitipaldis & IZAL)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Fito y Fitipaldis',
#   'Género': 'rock',
#   'Nombre de la cancion': '20 de abril (feat. Fito y Fitipaldis & IZAL)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Izal',
#   'Género': 'rock',
#   'Nombre de la cancion': '20 de abril (feat. Fito y Fitipaldis & IZAL)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Sinsinati',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Mi lugar',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Álvaro De Luna',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Mi lugar',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Rulo y la contrabanda',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Verano del 95',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Bakar',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hell N Back',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Celtas Cortos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Silencio',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Backseat Lovers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Kilby Girl',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'mgk',
#   'Género': 'rock',
#   'Nombre de la cancion': "I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Año de lanzamiento': 2019},
#  {'Artista': 'YUNGBLUD',
#   'Género': 'rock',
#   'Nombre de la cancion': "I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Travis Barker',
#   'Género': 'rock',
#   'Nombre de la cancion': "I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Falling In Reverse',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Popular Monster',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Rolling Stones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Honky Tonk Women',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Stick Figure',
#   'Género': 'rock',
#   'Nombre de la cancion': 'World on Fire (feat. Slightly Stoopid)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Slightly Stoopid',
#   'Género': 'rock',
#   'Nombre de la cancion': 'World on Fire (feat. Slightly Stoopid)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Djo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Personal Lies',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Wallows',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Remember When',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Walls',
#   'Género': 'rock',
#   'Nombre de la cancion': '38º',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Survive Said The Prophet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'MUKANJYO',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Black Keys',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lo/Hi',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Mala Hierba',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Quiero Que Vengas',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Legendary',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'I Prevail',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hurricane',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Vampire Weekend',
#   'Género': 'rock',
#   'Nombre de la cancion': 'This Life',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Score',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Fear',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Finish Line',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Cam Cole',
#   'Género': 'rock',
#   'Nombre de la cancion': 'New Age Blues',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Black Keys',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Shine A Little Light',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Orchestral Manoeuvres In The Dark',
#   'Género': 'rock',
#   'Nombre de la cancion': 'If You Leave - Remastered 2019',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Cam Cole',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Mama',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Celtian',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Niamh',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Antón Dávila',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Niamh',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Celtas Cortos',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Niamh',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'TOOL',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Invincible',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'YUNGBLUD',
#   'Género': 'rock',
#   'Nombre de la cancion': 'parents',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Falling In Reverse',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Drugs',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Bring Me The Horizon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'MANTRA',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Bad Wolves',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Killing Me Slowly',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Cage The Elephant',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Social Cues',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Tame Impala',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Patience',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Los Rodriguez',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Princesa',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Los De Marras',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Hoy - Remezclado y Remasterizado 2019',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Backseat Lovers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Maple Syrup',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Bring Me The Horizon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'in the dark',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'coldrain',
#   'Género': 'rock',
#   'Nombre de la cancion': 'MAYDAY (feat. Ryo from Crystal Lake)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Ryo',
#   'Género': 'rock',
#   'Nombre de la cancion': 'MAYDAY (feat. Ryo from Crystal Lake)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Wallows',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Scrawny',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Fitz and The Tantrums',
#   'Género': 'rock',
#   'Nombre de la cancion': 'I Just Wanna Shine',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Liam Gallagher',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Once',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Serú Girán',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Viernes, 3AM - 2019 Remasterizado',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Sinkope',
#   'Género': 'rock',
#   'Nombre de la cancion': 'De Vuelta de Ná',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Dani Fernández',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Bailemos (feat. Isma Romero) - Acústico',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Isma Romero',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Bailemos (feat. Isma Romero) - Acústico',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Maná',
#   'Género': 'rock',
#   'Nombre de la cancion': 'No Ha Parado De Llover (with Sebastián Yatra)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Sebastián Yatra',
#   'Género': 'rock',
#   'Nombre de la cancion': 'No Ha Parado De Llover (with Sebastián Yatra)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Foreigner',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Cold as Ice',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Bring Me The Horizon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'sugar honey ice & tea',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Vampire Weekend',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Harmony Hall',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'ONE OK ROCK',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Stand Out Fit In',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'STARSET',
#   'Género': 'rock',
#   'Nombre de la cancion': 'TRIALS',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Black Keys',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Tell Me Lies',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Foals',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Runner',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Dani Fernández',
#   'Género': 'rock',
#   'Nombre de la cancion': 'En llamas',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'MAN WITH A MISSION',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dark Crow',
#   'Año de lanzamiento': 2019},
#  {'Artista': "Somebody's Child",
#   'Género': 'rock',
#   'Nombre de la cancion': 'Jungle',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Palace',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Heaven Up There',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'TOOL',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Descending',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Cage The Elephant',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Ready To Let Go',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Score',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dreamin (with blackbear)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'blackbear',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Dreamin (with blackbear)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Voidz',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Did My Best',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Rolling Stones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Doom And Gloom',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Huecco',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Yo sé que tú me quieres',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Keane',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The Way I Feel',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Jadu Heart',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Forgotten Ghosts',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Lucas Colman',
#   'Género': 'rock',
#   'Nombre de la cancion': 'María (con Dani Fernández)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Dani Fernández',
#   'Género': 'rock',
#   'Nombre de la cancion': 'María (con Dani Fernández)',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Bring Me The Horizon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'medicine',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Backseat Lovers',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Pool House',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Liam Gallagher',
#   'Género': 'rock',
#   'Nombre de la cancion': 'One of Us',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Cruzando El Charco',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Soy',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Marilyn Manson',
#   'Género': 'rock',
#   'Nombre de la cancion': "God's Gonna Cut You Down",
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Volbeat',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Die To Live',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Neil Fallon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Die To Live',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Skillet',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Save Me',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Rulo y la contrabanda',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Todavía',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Black Keys',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Go',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Howard Jones',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Things Can Only Get Better',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Bring Me The Horizon',
#   'Género': 'rock',
#   'Nombre de la cancion': 'mother tongue',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Twin Tribes',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Fantasmas',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Beatles',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Oh! Darling - 2019 Mix',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Animals',
#   'Género': 'rock',
#   'Nombre de la cancion': 'The House of the Rising Sun',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Allah-Las',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Raspberry Jam',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'WildHeart',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Lonely',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'WildHeart',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Animal',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'Thorbjørn Risager & The Black Tornado',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Come on In',
#   'Año de lanzamiento': 2019},
#  {'Artista': 'The Black Tornado',
#   'Género': 'rock',
#   'Nombre de la cancion': 'Come on In',
#   'Año de lanzamiento': 2019},
#  ...]
