# %%
import json
import requests
import pandas as pd

# %%
with open ("archivos_json/definitivo.json", "r") as fichero:
    definitivo = json.load(fichero)

def extraer_por_genero(canciones, genero):
    lista_indie = []

    for item in canciones:
        año = item.get("year")

        if item.get("genre") == genero and 2016 <= año <= 2019:
            info = {
                "Artista": item.get("artist_name"),
                "Género": item.get("genre"),
                "Nombre de la Canción": item.get("track_name"),
                "Año de lanzamiento": año
            }

            lista_indie.append(info)

    print(len(lista_indie))
    return lista_indie

lista_indie = extraer_por_genero(definitivo, "indie")
print(lista_indie)
# Out:
# 1142
# [{'Artista': 'Jósean Log', 'Género': 'indie', 'Nombre de la Canción': 'Chachachá', 'Año de lanzamiento': 2016}, {'Artista': 'Siloé', 'Género': 'indie', 'Nombre de la Canción': 'La Verdad', 'Año de lanzamiento': 2016}, {'Artista': 'Viva Suecia', 'Género': 'indie', 'Nombre de la Canción': 'A Dónde Ir', 'Año de lanzamiento': 2016}, {'Artista': 'Miss Caffeina', 'Género': 'indie', 'Nombre de la Canción': 'Mira cómo vuelo', 'Año de lanzamiento': 2016}, {'Artista': 'Siloé', 'Género': 'indie', 'Nombre de la Canción': 'El Poder', 'Año de lanzamiento': 2016}, {'Artista': 'Viva Suecia', 'Género': 'indie', 'Nombre de la Canción': 'Bien por Ti', 'Año de lanzamiento': 2016}, {'Artista': 'Sidonie', 'Género': 'indie', 'Nombre de la Canción': 'Carreteras Infinitas', 'Año de lanzamiento': 2016}, {'Artista': 'Shinova', 'Género': 'indie', 'Nombre de la Canción': 'Qué casualidad', 'Año de lanzamiento': 2016}, {'Artista': 'TV Girl', 'Género': 'indie', 'Nombre de la Canción': 'Cigarettes out the Window', 'Año de lanzamiento': 2016}, {'Artista': 'TV Girl', 'Género': 'indie', 'Nombre de la Canción': 'Not Allowed', 'Año de lanzamiento': 2016}, {'Artista': 'TV Girl', 'Género': 'indie', 'Nombre de la Canción': 'Loving Machine', 'Año de lanzamiento': 2016}, {'Artista': 'Vacations', 'Género': 'indie', 'Nombre de la Canción': 'Young', 'Año de lanzamiento': 2016}, {'Artista': 'Siloé', 'Género': 'indie', 'Nombre de la Canción': 'Minas de Sal', 'Año de lanzamiento': 2016}, {'Artista': 'Joy Again', 'Género': 'indie', 'Nombre de la Canción': 'Looking Out for You', 'Año de lanzamiento': 2016}, {'Artista': 'Ivan Ferreiro', 'Género': 'indie', 'Nombre de la Canción': 'El pensamiento circular', 'Año de lanzamiento': 2016}, {'Artista': 'Love of Lesbian', 'Género': 'indie', 'Nombre de la Canción': 'Cuando no me ves', 'Año de lanzamiento': 2016}, {'Artista': 'Sidecars', 'Género': 'indie', 'Nombre de la Canción': 'Contra las cuerdas (feat. Leiva) - Acústico', 'Año de lanzamiento': 2016}, {'Artista': 'Leiva', 'Género': 'indie', 'Nombre de la Canción': 'Contra las cuerdas (feat. Leiva) - Acústico', 'Año de lanzamiento': 2016}, {'Artista': 'Leiva', 'Género': 'indie', 'Nombre de la Canción': 'Monstruos', 'Año de lanzamiento': 2016}, {'Artista': 'The Lumineers', 'Género': 'indie', 'Nombre de la Canción': 'Ophelia', 'Año de lanzamiento': 2016}, {'Artista': 'Jósean Log', 'Género': 'indie', 'Nombre de la Canción': 'Beso', 'Año de lanzamiento': 2016}, {'Artista': 'Cuco', 'Género': 'indie', 'Nombre de la Canción': 'Lover Is a Day', 'Año de lanzamiento': 2016}, {'Artista': 'Father John Misty', 'Género': 'indie', 'Nombre de la Canción': 'Real Love Baby', 'Año de lanzamiento': 2016}, {'Artista': 'Parcels', 'Género': 'indie', 'Nombre de la Canción': 'Gamesofluck', 'Año de lanzamiento': 2016}, {'Artista': 'TV Girl', 'Género': 'indie', 'Nombre de la Canción': "Taking What's Not Yours", 'Año de lanzamiento': 2016}, {'Artista': 'RY X', 'Género': 'indie', 'Nombre de la Canción': 'Only', 'Año de lanzamiento': 2016}, {'Artista': 'Jósean Log', 'Género': 'indie', 'Nombre de la Canción': 'Doma', 'Año de lanzamiento': 2016}, {'Artista': 'The Lumineers', 'Género': 'indie', 'Nombre de la Canción': 'Cleopatra', 'Año de lanzamiento': 2016}, {'Artista': 'Siloé', 'Género': 'indie', 'Nombre de la Canción': 'Invasor', 'Año de lanzamiento': 2016}, {'Artista': 'Shinova', 'Género': 'indie', 'Nombre de la Canción': 'Para cambiar el mundo', 'Año de lanzamiento': 2016}, {'Artista': 'Sidecars', 'Género': 'indie', 'Nombre de la Canción': 'Los amantes (feat. Iván Ferreiro) - Acústico', 'Año de lanzamiento': 2016}, {'Artista': 'Ivan Ferreiro', 'Género': 'indie', 'Nombre de la Canción': 'Los amantes (feat. Iván Ferreiro) - Acústico', 'Año de lanzamiento': 2016}, {'Artista': 'Charli xcx', 'Género': 'indie', 'Nombre de la Canción': 'Vroom Vroom', 'Año de lanzamiento': 2016}, {'Artista': 'KALEO', 'Género': 'indie', 'Nombre de la Canción': 'All the Pretty Girls', 'Año de lanzamiento': 2016}, {'Artista': 'RY X', 'Géner ...
