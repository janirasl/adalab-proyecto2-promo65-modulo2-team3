# %%
import json
import pandas as pd

# %%
# Vamos a convertir nuestro archivo json a csv
df = pd.read_json("archivos_json/definitivo.json")

# %%
#Esto es para que nos aparezcan los 5 primeros
df.head()
# Out:
#                        id     artist_name                  track_name  \
# 0  7AlYBA5M9FVXDqN31cbExE  Remedios Amaya                 El zarandeo
# 1  4uqcES2h19TKAXQlciycrO   Nobuo Uematsu          Vamo'alla flamenco
# 2  0z6xGK2u3nSsbk9XeKYwZQ   Maurice Ravel             Flamenco Bolero
# 3  6DjfWx0fXi0uQpedpvaCD9      Mark Towns              After the Rain
# 4  1t91qQaPbOoo4pumaLih4W  Franz Schubert  Tango Serenata (Ständchen)
#
#       genre  year
# 0  flamenco  2000
# 1  flamenco  2000
# 2  flamenco  2000
# 3  flamenco  2000
# 4  flamenco  2000

# %%
print(df)
# Out:
#                            id        artist_name                  track_name  \
# 0      7AlYBA5M9FVXDqN31cbExE     Remedios Amaya                 El zarandeo
# 1      4uqcES2h19TKAXQlciycrO      Nobuo Uematsu          Vamo'alla flamenco
# 2      0z6xGK2u3nSsbk9XeKYwZQ      Maurice Ravel             Flamenco Bolero
# 3      6DjfWx0fXi0uQpedpvaCD9         Mark Towns              After the Rain
# 4      1t91qQaPbOoo4pumaLih4W     Franz Schubert  Tango Serenata (Ständchen)
# ...                       ...                ...                         ...
# 61612  6Lv0uLFhPt6e4qcmoeltAq        Jade Macrae           Ain’t Nobody Home
# 61613  6Lv0uLFhPt6e4qcmoeltAq        Robben Ford           Ain’t Nobody Home
# 61614  4PtUbfBR2U2BC0uUrT9hnM    No Te Va Gustar                    Todo Mal
# 61615  4PtUbfBR2U2BC0uUrT9hnM  Ciro y los Persas                    Todo Mal
# 61616  762E489aCXNDuRg1sZaWmC            Artemas              time alone w u
#
#           genre  year
# ...

# %%
df.to_csv("definitivo.csv")

# %%
#Cargamos el json con "open" y con load() convertimos el json en un objt de python / "r"-->read
with open ("definitivo.json", "r") as fichero:
    definitivo = json.load(fichero)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 #Cargamos el json con "open" y con load() convertimos el json en un objt de python / "r"-->read
# ----> 2 with open ("definitivo.json", "r") as fichero:
#       3     definitivo = json.load(fichero)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'definitivo.json'

# %%
definitivo
# Out:
# [{'id': '7AlYBA5M9FVXDqN31cbExE',
#   'artist_name': 'Remedios Amaya',
#   'track_name': 'El zarandeo',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '4uqcES2h19TKAXQlciycrO',
#   'artist_name': 'Nobuo Uematsu',
#   'track_name': "Vamo'alla flamenco",
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '0z6xGK2u3nSsbk9XeKYwZQ',
#   'artist_name': 'Maurice Ravel',
#   'track_name': 'Flamenco Bolero',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '6DjfWx0fXi0uQpedpvaCD9',
#   'artist_name': 'Mark Towns',
#   'track_name': 'After the Rain',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '1t91qQaPbOoo4pumaLih4W',
#   'artist_name': 'Franz Schubert',
#   'track_name': 'Tango Serenata (Ständchen)',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '7Kuasu0H7jArcADoFIHGUk',
#   'artist_name': 'Mark Towns',
#   'track_name': 'Corriente',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '02jM23k8pgm9gcZpyIn8Wk',
#   'artist_name': 'Georges Moustaki',
# ...

# %%
type(definitivo)
# Out:
# list

# %%
definitivo[0]
# Out:
# {'id': '7AlYBA5M9FVXDqN31cbExE',
#  'artist_name': 'Remedios Amaya',
#  'track_name': 'El zarandeo',
#  'genre': 'flamenco',
#  'year': 2000}

# %%
type(definitivo[0])
# Out:
# dict

# %%
definitivo[0].keys()
# Out:
# dict_keys(['id', 'artist_name', 'track_name', 'genre', 'year'])

# %%
definitivo[0]["genre"]
# Out:
# 'flamenco'

# %%
#CREAMOS UN SET PARA SABER LOS GENEROS

generos = set() #genero una variable que sea = a un set vacio
for genero in definitivo: #bucle for para iterar 
    generos.add(genero["genre"]) #para que agregue los generos que va encontrando al set
print(generos)
# Out:
# {'orchestra', 'tango', 'indie', 'pop', 'rap', 'rock', 'latin', 'flamenco', 'reggaeton', 'hip-hop'}

# %%
list(generos)
# Out:
# ['orchestra',
#  'tango',
#  'indie',
#  'pop',
#  'rap',
#  'rock',
#  'latin',
#  'flamenco',
#  'reggaeton',
#  'hip-hop']

# %%
len(generos)
# Out:
# 10

# %%
#CREAMOS UN SET PARA SABER LOS AÑOS

años = set()
for año in definitivo:
    años.add(año["year"])
print(años)
# Out:
# {2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026}

# %%
list(años)
# Out:
# [2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025,
#  2026]

# %%
len(años)
# Out:
# 27

# %%
len(track_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 len(track_name)
#
# NameError: name 'track_name' is not defined

# %%
len(definitivo("track_name"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 len(definitivo("track_name"))
#
# TypeError: 'list' object is not callable

# %%
len(definitivo)
# Out:
# 61617

# %% [markdown]
# Extraer canciones y álbumes lanzados entre 2016 y 2019.
# - Queremos un diccionario en la cual se extraigan canciones y albumes de ese rango de tiempo

# %%
dict_años = []

for item in definitivo:
    if 2016 <= item["year"] <= 2019:
        dict_años.append(item)

# %%
print(dict_años)
# Out:
# [{'id': '0O4ewUtb7o71xYfKKkGy4P', 'artist_name': 'Angelillo', 'track_name': 'Paco el minero', 'genre': 'flamenco', 'year': 2016}, {'id': '5XIoHtfhbGBi0FppXSCELt', 'artist_name': 'Angelillo', 'track_name': '¡Ay Carmela!', 'genre': 'flamenco', 'year': 2016}, {'id': '7tnOyOeM9I1977e8TUeUYN', 'artist_name': 'Angelillo', 'track_name': 'Radio Cuba', 'genre': 'flamenco', 'year': 2016}, {'id': '3xtQIA9zvPkDfBVUSeutza', 'artist_name': 'Diego Guerrero', 'track_name': 'Tita Mercedes', 'genre': 'flamenco', 'year': 2016}, {'id': '4FvcXmgQrGIqKfGJzOAdx4', 'artist_name': 'Marina', 'track_name': 'Ciao, Adieu, Bye Bye', 'genre': 'flamenco', 'year': 2016}, {'id': '64e3GHTixRA6WQ0d0nCGEA', 'artist_name': 'Chiki Lora', 'track_name': 'Decidí', 'genre': 'flamenco', 'year': 2016}, {'id': '6JEtbPp5bHdZfwdKr8Vyag', 'artist_name': 'Chiki Lora', 'track_name': 'Tú y Yo', 'genre': 'flamenco', 'year': 2016}, {'id': '1vLZWrdTbFi9skGtAc8jw2', 'artist_name': 'Diego Guerrero', 'track_name': 'Miguel', 'genre': 'flamen
# ...

# %%
dict_años[200:203]
# Out:
# [{'id': '6WgQjBNpjnEJbOKAa0OMpY',
#   'artist_name': 'PNL',
#   'track_name': 'Luz de Luna',
#   'genre': 'hip-hop',
#   'year': 2016},
#  {'id': '0wFfaaLDtNIaGOJlMqlmyR',
#   'artist_name': 'Duki',
#   'track_name': 'No Vendo Trap',
#   'genre': 'hip-hop',
#   'year': 2016},
#  {'id': '3UXE7ePwfQK7HHqB993GkO',
#   'artist_name': 'Myke Towers',
#   'track_name': 'Habitación 420',
#   'genre': 'hip-hop',
#   'year': 2016}]

# %%
#filtrada de las canciones que hay del 2016 al 2019
len(dict_años)
# Out:
# 10921

# %%
dict_años[10920]["genre"]
# Out:
# 'tango'

# %%
dict_años[23]["genre"]
# Out:
# 'flamenco'

# %%
dict_años[100]["genre"]
# Out:
# 'hip-hop'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("dict_años.json", "w", encoding="utf-8") as fichero:
    json.dump(dict_años, fichero, ensure_ascii=False, indent=4)
