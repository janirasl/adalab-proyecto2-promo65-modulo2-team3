# %%
#Importamos las librerias necesarias
import requests
from dotenv import load_dotenv 
import os
import mysql.connector
import pandas as pd

load_dotenv("../rock/.env")                       #Cargamos nuestras contraseñas en el .env
SQL_pass = os.getenv("SQL")

# %%
def subir_csv_a_sql(ruta_csv):

    df = pd.read_csv(ruta_csv)                              # Leer el CSV

    conexion = mysql.connector.connect(
        host="127.0.0.1",                                  # Conectar a MySQL
        user="root",
        password=SQL_pass,
        database="music_db"
    )

    cursor = conexion.cursor() 

    errores = []

    for index, fila in df.iterrows():                 # Recorrer cada fila del dataframe     
        try:  
            #query para insertar los datos
            query = """
            INSERT INTO artists                                     
            (id_artist, artist_name, artist_bio, artist_listeners, artist_playcount, similar_artist)
            VALUES (%s, %s, %s, %s, %s, %s)
            """

            valores = (
                fila["id_artist"],
                fila["artist"],
                fila["bio"],
                fila["listeners"],
                fila["playcount"],
                fila["similar_artist"]
            )

            cursor.execute(query, valores)

        except Exception as e:                #Guardar el error y la fila
            errores.append((index, str(e)))
            print(f"Fila {index} fallo: {e}")
            continue                              #Sigue

    conexion.commit()                                    # Guardar cambios

    cursor.close()                                      # Cerrar conexión
    conexion.close()

    print("Datos subidos correctamente")

# %%
subir_csv_a_sql("resultado_rock.csv")
# Out:
# Fila 66 fallo: 1062 (23000): Duplicate entry '1f1a47d4-0167-4ed1-983e-acc40cee4881' for key 'artists.PRIMARY'
# Fila 79 fallo: 1062 (23000): Duplicate entry '68416724-6cc4-41ee-b81c-1ce169c00f03' for key 'artists.PRIMARY'
# Fila 94 fallo: 1062 (23000): Duplicate entry '14a22136-672e-4512-8659-5cf92ce88234' for key 'artists.PRIMARY'
# Fila 120 fallo: 1062 (23000): Duplicate entry '1dcee96e-7d8c-4ba1-ae62-bbb694033966' for key 'artists.PRIMARY'
# Fila 156 fallo: 1062 (23000): Duplicate entry '6d744917-187a-450f-a683-e2caa21591a5' for key 'artists.PRIMARY'
# Fila 163 fallo: 1062 (23000): Duplicate entry '8d1e76c8-80b0-44b9-9e86-25d148323a9e' for key 'artists.PRIMARY'
# Fila 180 fallo: 1062 (23000): Duplicate entry 'b97a82d1-cabd-4336-8476-b4e89ec1f1c7' for key 'artists.PRIMARY'
# Fila 187 fallo: 1062 (23000): Duplicate entry '9fc27a6f-fbcd-45a6-ae14-84d298c2c994' for key 'artists.PRIMARY'
# Fila 188 fallo: 1062 (23000): Duplicate entry 'e21857d5-3256-4547-afb3-4b6ded592596' for key 'artists.PRIMARY'
# Fila 198 fallo: 1062 (23000): Duplicate entry '7456e258-77f9-42b2-85e7-0d44e76abe04' for key 'artists.PRIMARY'
# Fila 259 fallo: 1062 (23000): Duplicate entry '513602fe-202a-4583-afb9-2a2aca8af55b' for key 'artists.PRIMARY'
# Fila 275 fallo: 1062 (23000): Duplicate entry '7caaa03b-164c-4827-b9d6-888aa1ec3a48' for key 'artists.PRIMARY'
# Fila 279 fallo: 1062 (23000): Duplicate entry '99f2ae00-5c8a-4465-ae30-d932f9e5ba81' for key 'artists.PRIMARY'
# Fila 289 fallo: 1062 (23000): Duplicate entry 'c7cdc95e-c301-46fb-9c99-3a7cfc5084aa' for key 'artists.PRIMARY'
# Fila 290 fallo: 1062 (23000): Duplicate entry '8b0f05ce-354e-4121-9e0b-8b4732ea844f' for key 'artists.PRIMARY'
# Fila 291 fallo: 1062 (23000): Duplicate entry '93ba42f8-10c5-4865-9ca1-e7e7a5c9f389' for key 'artists.PRIMARY'
# Fila 319 fallo: 1062 (23000): Duplicate entry '40de1c05-2a3b-4fab-a7c6-82776c37edfa' for key 'artists.PRIMARY'
# Fila 354 fallo: 1062 (23000): Duplicate entry '87650e79-e7af-40a4-b208-4adf58b2a519' for key 'artists.PRIMARY'
# Fila 359 fallo: 1062 (23000): Duplicate entry 'ca9766a0-1c30-43e6-a213-bac1334efc4a' for key 'artists.PRIMARY'
# Fila 396 fallo: 1062 (23000): Duplicate entry '7e3a670c-b4aa-4f27-8682-1b28c063aff2' for key 'artists.PRIMARY'
# Fila 418 fallo: 1062 (23000): Duplicate entry '61af87f4-16ee-4431-8504-cc06187079fb' for key 'artists.PRIMARY'
# Fila 419 fallo: 1062 (23000): Duplicate entry '7de398f0-b4cf-476d-ac60-41d47d3511ca' for key 'artists.PRIMARY'
# Fila 450 fallo: 1062 (23000): Duplicate entry '43a86a8a-3659-4911-9c36-cbcf0cbcd5b5' for key 'artists.PRIMARY'
# Fila 454 fallo: 1062 (23000): Duplicate entry 'e3d5b5ec-101a-4529-9f2d-01dca64cf44e' for key 'artists.PRIMARY'
# Fila 468 fallo: 1062 (23000): Duplicate entry 'f6af669a-56ea-448a-a044-de76181ada33' for key 'artists.PRIMARY'
# Fila 475 fallo: 1062 (23000): Duplicate entry 'f1d7817b-80f4-48c3-a4d0-e324015c7e96' for key 'artists.PRIMARY'
# Fila 481 fallo: 1062 (23000): Duplicate entry '736e1cf9-09c6-47ac-9b98-5374e40fecf0' for key 'artists.PRIMARY'
# Fila 495 fallo: 1062 (23000): Duplicate entry 'ea103218-16a7-4260-b1d7-1d1fea4d1d8c' for key 'artists.PRIMARY'
# Fila 523 fallo: 1062 (23000): Duplicate entry '436eb956-2a52-4bdf-aa79-4d73d952b2da' for key 'artists.PRIMARY'
# Fila 532 fallo: 1062 (23000): Duplicate entry '38ae1a57-de55-4183-adb4-75ff3739bc4d' for key 'artists.PRIMARY'
# Fila 544 fallo: 1062 (23000): Duplicate entry '38b511a2-76fa-4a1e-9b7a-e2a6efa6399b' for key 'artists.PRIMARY'
# Datos subidos correctamente

# %%
subir_csv_a_sql("resultado_latin.csv")
# Out:
# Fila 0 fallo: 1062 (23000): Duplicate entry 'c1a3132a-c23e-4283-8f9a-4080dc52a177' for key 'artists.PRIMARY'
# Fila 2 fallo: 1062 (23000): Duplicate entry 'e5a1e5fa-fd7e-4e10-aa84-f51cbdb1e3fd' for key 'artists.PRIMARY'
# Fila 6 fallo: 1062 (23000): Duplicate entry 'c0c401e0-eb84-4266-9ccb-9160988e7a8e' for key 'artists.PRIMARY'
# Fila 7 fallo: 1062 (23000): Duplicate entry '44869536-0262-4f22-9c23-b4821c13cd97' for key 'artists.PRIMARY'
# Fila 8 fallo: 1062 (23000): Duplicate entry 'd95a4680-1337-4132-b0bf-7750e1098eca' for key 'artists.PRIMARY'
# Fila 11 fallo: 1062 (23000): Duplicate entry 'ce09ea31-3d4a-4487-a797-e315175457a0' for key 'artists.PRIMARY'
# Fila 16 fallo: 1062 (23000): Duplicate entry '14a22136-672e-4512-8659-5cf92ce88234' for key 'artists.PRIMARY'
# Fila 21 fallo: 1062 (23000): Duplicate entry 'd62adf19-169e-4878-8b04-b8b4a7023802' for key 'artists.PRIMARY'
# Fila 23 fallo: 1062 (23000): Duplicate entry 'd606b860-cc03-4959-a3fd-3a24bccf2560' for key 'artists.PRIMARY'
# Fila 27 fallo: 1062 (23000): Duplicate entry 'fc17992b-d3c2-423e-9c7e-f479c1c4d8a8' for key 'artists.PRIMARY'
# Fila 28 fallo: 1062 (23000): Duplicate entry '5bdeb32d-56a5-4b6d-a768-264101fa0a0a' for key 'artists.PRIMARY'
# Fila 29 fallo: 1062 (23000): Duplicate entry '3deeb747-c228-4d33-9892-f0aa081783c3' for key 'artists.PRIMARY'
# Fila 34 fallo: 1062 (23000): Duplicate entry '2373943f-9c75-46cd-a651-dbdd9867565a' for key 'artists.PRIMARY'
# Fila 36 fallo: 1062 (23000): Duplicate entry '965c6053-0bfb-42c1-97e7-84b34218ac53' for key 'artists.PRIMARY'
# Fila 39 fallo: 1062 (23000): Duplicate entry 'da286874-6e1e-4ca1-bcc9-c275827ac926' for key 'artists.PRIMARY'
# Fila 42 fallo: 1062 (23000): Duplicate entry 'b97a82d1-cabd-4336-8476-b4e89ec1f1c7' for key 'artists.PRIMARY'
# Fila 46 fallo: 1062 (23000): Duplicate entry 'efa56203-008a-422a-a863-4ddda4dc3aa4' for key 'artists.PRIMARY'
# Fila 49 fallo: 1062 (23000): Duplicate entry '299f7958-15f5-4ca2-b4ed-222b169dd74e' for key 'artists.PRIMARY'
# Fila 56 fallo: 1062 (23000): Duplicate entry '89aa5ecb-59ad-46f5-b3eb-2d424e941f19' for key 'artists.PRIMARY'
# Fila 60 fallo: 1062 (23000): Duplicate entry '7cd0657a-a661-43c4-ad19-95819a6003eb' for key 'artists.PRIMARY'
# Fila 61 fallo: 1062 (23000): Duplicate entry '45dc5f07-6609-4760-a933-8c9e0f858d05' for key 'artists.PRIMARY'
# Fila 62 fallo: 1062 (23000): Duplicate entry 'b7f5054e-c9de-49d8-b0eb-6deefb89b86b' for key 'artists.PRIMARY'
# Fila 63 fallo: 1062 (23000): Duplicate entry '86e4ae25-f45b-4c52-904d-94c0004f907e' for key 'artists.PRIMARY'
# Fila 66 fallo: 1062 (23000): Duplicate entry 'c63b3a59-cb13-4ed4-867f-b46f30fc7e45' for key 'artists.PRIMARY'
# Fila 67 fallo: 1062 (23000): Duplicate entry '9f653365-95d9-4adc-9296-3bf0b27ebee5' for key 'artists.PRIMARY'
# Fila 69 fallo: 1062 (23000): Duplicate entry 'd2945137-b01d-4195-9f82-64d20f8ba657' for key 'artists.PRIMARY'
# Fila 72 fallo: 1062 (23000): Duplicate entry '24ec58e8-9d3f-482f-a07d-0ea11c2ffcd5' for key 'artists.PRIMARY'
# Fila 73 fallo: 1062 (23000): Duplicate entry '70cb4669-ad7a-4d5c-b99e-7582df393cc7' for key 'artists.PRIMARY'
# Fila 80 fallo: 1062 (23000): Duplicate entry 'eb90c8b8-d733-4c14-a293-105c3d1ba9b3' for key 'artists.PRIMARY'
# Fila 81 fallo: 1062 (23000): Duplicate entry '768ba077-c2ae-4c59-9212-5ff05c8db0f7' for key 'artists.PRIMARY'
# Fila 84 fallo: 1062 (23000): Duplicate entry '3c490f79-d333-47d6-8a4a-8d676da4d1d2' for key 'artists.PRIMARY'
# Fila 89 fallo: 1062 (23000): Duplicate entry 'b5e48298-41ec-4933-8e3d-d6b2c0b49030' for key 'artists.PRIMARY'
# Fila 90 fallo: 1062 (23000): Duplicate entry 'c0f72373-8947-4509-9611-fff7fd9dee4c' for key 'artists.PRIMARY'
# Fila 94 fallo: 1062 (23000): Duplicate entry '6143403a-df6c-429e-8ee6-ef869896b0da' for key 'artists.PRIMARY'
# Fila 97 fallo: 1062 (23000): Duplicate entry '2b67658e-429f-425a-adf5-345b13112fc1' for key 'artists.PRIMARY'
# Fila 98 fallo: 1062 (23000): Duplicate entry '532e4ed5-1ad9-4997-9fa2-4271fe7eb757' for key 'artists.PRIMARY'
# Fila 100 fallo: 1062 (23000): Duplicate entry '28e6d28f-e134-476f-bcad-26051c27c9ba' for key 'artists.PRIMARY'
# Fila 103 fallo: 1062 (23000): Duplicate entry '59bc1ba2-ce50-4c2c-985b-0502b281f19a' for key 'artists.PRIMARY'
# Fila 110 fallo: 1062 (23000): Duplicate entry '709f5e96-51cd-49b4-a8e4-0ca0bf808de3' for key 'artists.PRIMARY'
# Fila 111 fallo: 1062 (23000): Duplicate entry '38ae1a57-de55-4183-adb4-75ff3739bc4d' for key 'artists.PRIMARY'
# Fila 112 fallo: 1062 (23000): Duplicate entry 'e79f452c-d174-4c36-919e-a80f71aa4cf6' for key 'artists.PRIMARY'
# Fila 113 fallo: 1062 (23000): Duplicate entry '9fff2f8a-21e6-47de-a2b8-7f449929d43f' for key 'artists.PRIMARY'
# Fila 115 fallo: 1062 (23000): Duplicate entry '5fdae5d2-8aff-4671-8cf8-3b216f63265f' for key 'artists.PRIMARY'
# Fila 119 fallo: 1062 (23000): Duplicate entry '21029ef5-0842-46f8-b068-d99e2f06d231' for key 'artists.PRIMARY'
# Fila 121 fallo: 1062 (23000): Duplicate entry 'ae44dccd-8fdc-42ff-84a6-2a0549bacca4' for key 'artists.PRIMARY'
# Fila 122 fallo: 1062 (23000): Duplicate entry 'ff958d63-c910-42d1-960e-a3f005855ddc' for key 'artists.PRIMARY'
# Fila 125 fallo: 1062 (23000): Duplicate entry 'a06afacd-7894-442e-95ba-49366b2b3e02' for key 'artists.PRIMARY'
# Fila 126 fallo: 1062 (23000): Duplicate entry '947f21fa-4244-433c-8d51-bf43513d3f71' for key 'artists.PRIMARY'
# Fila 134 fallo: 1062 (23000): Duplicate entry '7e3a670c-b4aa-4f27-8682-1b28c063aff2' for key 'artists.PRIMARY'
# Fila 136 fallo: 1062 (23000): Duplicate entry '786ce8c5-cb6c-4667-ad27-f61b6bfc3ed0' for key 'artists.PRIMARY'
# Fila 138 fallo: 1062 (23000): Duplicate entry 'db607377-aace-4a32-a439-373b7236df7e' for key 'artists.PRIMARY'
# Fila 139 fallo: 1062 (23000): Duplicate entry '9fc27a6f-fbcd-45a6-ae14-84d298c2c994' for key 'artists.PRIMARY'
# Fila 142 fallo: 1062 (23000): Duplicate entry 'f1d7817b-80f4-48c3-a4d0-e324015c7e96' for key 'artists.PRIMARY'
# Fila 148 fallo: 1062 (23000): Duplicate entry 'd2b3524f-67e8-45ef-bfc1-693cac525135' for key 'artists.PRIMARY'
# Fila 150 fallo: 1062 (23000): Duplicate entry '85b0112b-50ce-4b3e-8857-6ca7ea3f3584' for key 'artists.PRIMARY'
# Fila 151 fallo: 1062 (23000): Duplicate entry '716c711c-b9cc-4b83-bfd9-dc14bdc1e770' for key 'artists.PRIMARY'
# Fila 152 fallo: 1062 (23000): Duplicate entry '40de1c05-2a3b-4fab-a7c6-82776c37edfa' for key 'artists.PRIMARY'
# Fila 153 fallo: 1062 (23000): Duplicate entry '289b0796-7b37-438e-bec8-c0590961c4cc' for key 'artists.PRIMARY'
# Fila 162 fallo: 1062 (23000): Duplicate entry '575ca0a7-c35a-4bd3-bbfc-044007922216' for key 'artists.PRIMARY'
# Fila 166 fallo: 1062 (23000): Duplicate entry '3d291f48-a8be-4113-baad-c73618a7897d' for key 'artists.PRIMARY'
# Fila 170 fallo: 1062 (23000): Duplicate entry 'ab1d4693-41dd-44ed-9e9c-da2ff76f1a3a' for key 'artists.PRIMARY'
# Fila 179 fallo: 1062 (23000): Duplicate entry '6d744917-187a-450f-a683-e2caa21591a5' for key 'artists.PRIMARY'
# Fila 180 fallo: 1062 (23000): Duplicate entry '48262e82-db9f-4a92-b650-dfef979b73ec' for key 'artists.PRIMARY'
# Fila 187 fallo: 1062 (23000): Duplicate entry '2df9cb59-5cbb-42d2-bde4-34a3d391a7ea' for key 'artists.PRIMARY'
# Fila 188 fallo: 1062 (23000): Duplicate entry '8248c905-689d-4e36-9def-7c515c5ef5eb' for key 'artists.PRIMARY'
# Fila 193 fallo: 1062 (23000): Duplicate entry '918e77fc-f42b-4fa2-a8c0-4e7720e4e724' for key 'artists.PRIMARY'
# Fila 195 fallo: 1062 (23000): Duplicate entry 'f2651b63-a44d-4d1d-ba64-d981d971ecd1' for key 'artists.PRIMARY'
# Fila 197 fallo: 1062 (23000): Duplicate entry 'd1689304-23ac-4eae-a147-bd2e4100581a' for key 'artists.PRIMARY'
# Fila 198 fallo: 1062 (23000): Duplicate entry 'e5fdb46c-eb73-4820-94ba-5dd5b35948cf' for key 'artists.PRIMARY'
# Fila 200 fallo: 1062 (23000): Duplicate entry '2d049e0f-9069-474f-a7fd-3c48f7a92b68' for key 'artists.PRIMARY'
# Fila 202 fallo: 1062 (23000): Duplicate entry '6a6eea03-b435-446c-bab1-312b45580aee' for key 'artists.PRIMARY'
# Fila 208 fallo: 1062 (23000): Duplicate entry 'e8979f75-9110-4df8-ac70-898898d080d1' for key 'artists.PRIMARY'
# Fila 210 fallo: 1062 (23000): Duplicate entry '8e68819d-71be-4e7d-b41d-f1df81b01d3f' for key 'artists.PRIMARY'
# Fila 213 fallo: 1062 (23000): Duplicate entry 'e2e593af-0b56-4a12-90fd-53611e14abcd' for key 'artists.PRIMARY'
# Fila 215 fallo: 1062 (23000): Duplicate entry '8116d0a6-f9de-42f6-b2f6-8c3c419043dd' for key 'artists.PRIMARY'
# Fila 216 fallo: 1062 (23000): Duplicate entry '87650e79-e7af-40a4-b208-4adf58b2a519' for key 'artists.PRIMARY'
# Fila 217 fallo: 1062 (23000): Duplicate entry '0a81ff99-c783-4605-b338-863c182460ff' for key 'artists.PRIMARY'
# Fila 219 fallo: 1062 (23000): Duplicate entry '30a57b7b-47c9-4234-86fd-9b8ff660e7cb' for key 'artists.PRIMARY'
# Fila 220 fallo: 1062 (23000): Duplicate entry '47e7833f-f1a7-4703-942d-9acf12f39a1d' for key 'artists.PRIMARY'
# Fila 222 fallo: 1062 (23000): Duplicate entry 'cd277e93-dbc4-4565-be57-44264413f28b' for key 'artists.PRIMARY'
# Fila 223 fallo: 1062 (23000): Duplicate entry '255a79b3-85eb-48a5-ba30-313a27ceb341' for key 'artists.PRIMARY'
# Fila 227 fallo: 1062 (23000): Duplicate entry '7456e258-77f9-42b2-85e7-0d44e76abe04' for key 'artists.PRIMARY'
# Fila 228 fallo: 1062 (23000): Duplicate entry 'de22adae-f8ac-414f-b653-b0162611bd60' for key 'artists.PRIMARY'
# Fila 230 fallo: 1062 (23000): Duplicate entry 'bbf0ea5d-b229-4882-9b3d-c0da0af116d6' for key 'artists.PRIMARY'
# Fila 233 fallo: 1062 (23000): Duplicate entry '4d01d0b5-98e4-4fea-bf68-41123d27abbc' for key 'artists.PRIMARY'
# Fila 238 fallo: 1062 (23000): Duplicate entry '7fb4a3df-377c-41c0-91ee-f286ecca1e0f' for key 'artists.PRIMARY'
# Fila 239 fallo: 1062 (23000): Duplicate entry '7caaa03b-164c-4827-b9d6-888aa1ec3a48' for key 'artists.PRIMARY'
# Fila 242 fallo: 1062 (23000): Duplicate entry '99f2ae00-5c8a-4465-ae30-d932f9e5ba81' for key 'artists.PRIMARY'
# Fila 244 fallo: 1062 (23000): Duplicate entry '3b6abaef-febf-4cfe-943f-6a20cf0afdad' for key 'artists.PRIMARY'
# Fila 250 fallo: 1062 (23000): Duplicate entry '2deb0058-8571-4f57-8470-1e63cdc9ef98' for key 'artists.PRIMARY'
# Fila 251 fallo: 1062 (23000): Duplicate entry '61abe51a-54e6-486a-b6b5-dc60a0e35ab6' for key 'artists.PRIMARY'
# Fila 252 fallo: 1062 (23000): Duplicate entry '513602fe-202a-4583-afb9-2a2aca8af55b' for key 'artists.PRIMARY'
# Fila 255 fallo: 1062 (23000): Duplicate entry '2f3c4d70-0462-40da-bba3-0aec5772c556' for key 'artists.PRIMARY'
# Fila 264 fallo: 1062 (23000): Duplicate entry '6252f6ed-5b34-4afd-a0bc-ab8156c2a524' for key 'artists.PRIMARY'
# Fila 265 fallo: 1062 (23000): Duplicate entry 'd262ea27-3ffe-40f7-b922-85c42d625e67' for key 'artists.PRIMARY'
# Fila 267 fallo: 1062 (23000): Duplicate entry 'e662ea36-81bf-4840-a143-cbbf8b2a74eb' for key 'artists.PRIMARY'
# Fila 269 fallo: 1062 (23000): Duplicate entry '87a75fc3-59e7-4598-925c-8e230bce5db9' for key 'artists.PRIMARY'
# Fila 271 fallo: 1062 (23000): Duplicate entry '197b70c7-8910-4030-ad03-632d82aa40e3' for key 'artists.PRIMARY'
# Fila 274 fallo: 1062 (23000): Duplicate entry 'faa2f0f5-14bf-46fd-85a1-486263bb64bb' for key 'artists.PRIMARY'
# Fila 277 fallo: 1062 (23000): Duplicate entry '0b1aea37-1b1a-4c1f-bd59-23443ba90741' for key 'artists.PRIMARY'
# Fila 280 fallo: 1062 (23000): Duplicate entry '46d3689c-23e6-46f7-8ad6-c12f13ac9dea' for key 'artists.PRIMARY'
# Fila 283 fallo: 1062 (23000): Duplicate entry 'cabbb345-e61c-4e80-a0a8-a3beb2823851' for key 'artists.PRIMARY'
# Fila 285 fallo: 1062 (23000): Duplicate entry '1d47b224-2cd9-4852-8e55-b9ec635e0c43' for key 'artists.PRIMARY'
# Fila 290 fallo: 1062 (23000): Duplicate entry '43a86a8a-3659-4911-9c36-cbcf0cbcd5b5' for key 'artists.PRIMARY'
# Fila 297 fallo: 1062 (23000): Duplicate entry 'f4d7f8aa-8f38-41cd-bc57-e214cfe2982f' for key 'artists.PRIMARY'
# Fila 299 fallo: 1062 (23000): Duplicate entry '89fe777e-8d33-411d-9fe9-027f67c1e8f1' for key 'artists.PRIMARY'
# Fila 301 fallo: 1062 (23000): Duplicate entry 'c458e9dc-e0d5-45ea-9e83-f9d0395f030d' for key 'artists.PRIMARY'
# Fila 303 fallo: 1062 (23000): Duplicate entry '0d37f1cd-ee7f-4b5d-a565-11c105c55898' for key 'artists.PRIMARY'
# Fila 304 fallo: 1062 (23000): Duplicate entry '1dcee96e-7d8c-4ba1-ae62-bbb694033966' for key 'artists.PRIMARY'
# Fila 305 fallo: 1062 (23000): Duplicate entry '4cea5aae-7b0e-4167-a187-e97407828a57' for key 'artists.PRIMARY'
# Fila 309 fallo: 1062 (23000): Duplicate entry '4db5a9a8-42bc-4c9e-812b-067cbab04db7' for key 'artists.PRIMARY'
# Fila 313 fallo: 1062 (23000): Duplicate entry '1266823d-bd9d-4e1b-9ec2-601180e057b3' for key 'artists.PRIMARY'
# Fila 316 fallo: 1062 (23000): Duplicate entry '2f522f5c-111c-4ce8-8bd0-d82e97c227ad' for key 'artists.PRIMARY'
# Fila 317 fallo: 1062 (23000): Duplicate entry '93ba42f8-10c5-4865-9ca1-e7e7a5c9f389' for key 'artists.PRIMARY'
# Fila 318 fallo: 1062 (23000): Duplicate entry '37705ca5-fb95-4f03-be56-7259973c77e7' for key 'artists.PRIMARY'
# Fila 326 fallo: 1062 (23000): Duplicate entry '7e2012a4-2752-46c1-90b8-f48f3fa43412' for key 'artists.PRIMARY'
# Fila 328 fallo: 1062 (23000): Duplicate entry 'f043a667-d0cc-41ec-b242-22068c5cd736' for key 'artists.PRIMARY'
# Fila 330 fallo: 1062 (23000): Duplicate entry '149c65b2-93e3-4009-84fb-5643f6d1094e' for key 'artists.PRIMARY'
# Fila 335 fallo: 1062 (23000): Duplicate entry '4d4de8bd-b05d-4b0a-befd-62a267e75756' for key 'artists.PRIMARY'
# Fila 337 fallo: 1062 (23000): Duplicate entry 'e3d5b5ec-101a-4529-9f2d-01dca64cf44e' for key 'artists.PRIMARY'
# Fila 343 fallo: 1062 (23000): Duplicate entry '88c05751-d71c-4594-aca1-cfcb682083a6' for key 'artists.PRIMARY'
# Fila 354 fallo: 1062 (23000): Duplicate entry 'e0ca6433-952c-4768-8ffa-a8df71234217' for key 'artists.PRIMARY'
# Fila 355 fallo: 1062 (23000): Duplicate entry '1036b808-f58c-4a3e-b461-a2c4492ecf1b' for key 'artists.PRIMARY'
# Datos subidos correctamente

# %%
subir_csv_a_sql("resultado_indie.csv")
# Out:
# Fila 188 fallo: 1062 (23000): Duplicate entry 'IZAL' for key 'artists.PRIMARY'
# Datos subidos correctamente

# %%
subir_csv_a_sql("resultado_hiphop.csv")
# Out:
# Fila 113 fallo: 1062 (23000): Duplicate entry '7fb4a3df-377c-41c0-91ee-f286ecca1e0f' for key 'artists.PRIMARY'
# Fila 124 fallo: 1062 (23000): Duplicate entry '5bdeb32d-56a5-4b6d-a768-264101fa0a0a' for key 'artists.PRIMARY'
# Fila 212 fallo: 1062 (23000): Duplicate entry '4db5a9a8-42bc-4c9e-812b-067cbab04db7' for key 'artists.PRIMARY'
# Fila 224 fallo: 1062 (23000): Duplicate entry '89fe777e-8d33-411d-9fe9-027f67c1e8f1' for key 'artists.PRIMARY'
# Fila 230 fallo: 1062 (23000): Duplicate entry '59bc1ba2-ce50-4c2c-985b-0502b281f19a' for key 'artists.PRIMARY'
# Fila 247 fallo: 1062 (23000): Duplicate entry 'c458e9dc-e0d5-45ea-9e83-f9d0395f030d' for key 'artists.PRIMARY'
# Fila 330 fallo: 1062 (23000): Duplicate entry 'e5fdb46c-eb73-4820-94ba-5dd5b35948cf' for key 'artists.PRIMARY'
# Fila 340 fallo: 1062 (23000): Duplicate entry 'da286874-6e1e-4ca1-bcc9-c275827ac926' for key 'artists.PRIMARY'
# Fila 346 fallo: 1062 (23000): Duplicate entry 'faa2f0f5-14bf-46fd-85a1-486263bb64bb' for key 'artists.PRIMARY'
# Fila 378 fallo: 1062 (23000): Duplicate entry 'd2945137-b01d-4195-9f82-64d20f8ba657' for key 'artists.PRIMARY'
# Fila 386 fallo: 1062 (23000): Duplicate entry '47e7833f-f1a7-4703-942d-9acf12f39a1d' for key 'artists.PRIMARY'
# Fila 424 fallo: 1062 (23000): Duplicate entry '965c6053-0bfb-42c1-97e7-84b34218ac53' for key 'artists.PRIMARY'
# Fila 425 fallo: 1062 (23000): Duplicate entry '87a75fc3-59e7-4598-925c-8e230bce5db9' for key 'artists.PRIMARY'
# Fila 452 fallo: 1062 (23000): Duplicate entry '2f522f5c-111c-4ce8-8bd0-d82e97c227ad' for key 'artists.PRIMARY'
# Fila 595 fallo: 1062 (23000): Duplicate entry '86e4ae25-f45b-4c52-904d-94c0004f907e' for key 'artists.PRIMARY'
# Fila 597 fallo: 1062 (23000): Duplicate entry '28e6d28f-e134-476f-bcad-26051c27c9ba' for key 'artists.PRIMARY'
# Fila 622 fallo: 1062 (23000): Duplicate entry 'cd277e93-dbc4-4565-be57-44264413f28b' for key 'artists.PRIMARY'
# Fila 701 fallo: 1062 (23000): Duplicate entry 'e8979f75-9110-4df8-ac70-898898d080d1' for key 'artists.PRIMARY'
# Fila 725 fallo: 1062 (23000): Duplicate entry '88c05751-d71c-4594-aca1-cfcb682083a6' for key 'artists.PRIMARY'
# Fila 754 fallo: 1406 (22001): Data too long for column 'similar_artist' at row 1
# Fila 755 fallo: 1062 (23000): Duplicate entry '2a5a8871-ef4a-4a69-b3bb-057ca472f20c' for key 'artists.PRIMARY'
# Fila 812 fallo: 1062 (23000): Duplicate entry '2deb0058-8571-4f57-8470-1e63cdc9ef98' for key 'artists.PRIMARY'
# Fila 833 fallo: 1062 (23000): Duplicate entry '89aa5ecb-59ad-46f5-b3eb-2d424e941f19' for key 'artists.PRIMARY'
# Datos subidos correctamente

# %%
subir_csv_a_sql("resultado_reggaeton.csv")
# Out:
# Datos subidos correctamente

# %%
def subir_csv_a_sql_tracks(ruta_csv):

    df = pd.read_csv(ruta_csv)                              # Leer el CSV

    mapeo_generos = {"rock": 1,"indie": 2,"latin": 3,"reggaeton": 4,"hip-hop": 5}

    conexion = mysql.connector.connect(
        host="127.0.0.1",                                  # Conectar a MySQL
        user="root",
        password=SQL_pass,
        database="music_db"
    )

    cursor = conexion.cursor() 

    errores = []

    for index, fila in df.iterrows():                 # Recorrer cada fila del dataframe     
        try: 
            nombre_genero_csv = fila["genre"] 
            id_genero_numerico = mapeo_generos.get(nombre_genero_csv, None)             
            if id_genero_numerico is None:                 
                print(f"Fila {index}: El género '{nombre_genero_csv}' no está en el mapeo. Saltando...") 
                continue

            #query para insertar los datos
            query = """
            INSERT INTO tracks                                     
            (id_artist, id_genre, track_name, year)
            VALUES (%s, %s, %s, %s)
            """

            valores = (
                fila["artist"],
                id_genero_numerico,
                fila["track_name"],
                fila["year"],
            )

            cursor.execute(query, valores)

        except Exception as e:                #Guardar el error y la fila
            errores.append((index, str(e)))
            print(f"Fila {index} fallo: {e}")
            continue                              #Sigue

    conexion.commit()                                    # Guardar cambios

    cursor.close()                                      # Cerrar conexión
    conexion.close()

    print("Datos subidos correctamente")

# %%
def subir_csv_a_sql_tracks(ruta_csv):
    # 1. Leer el CSV
    df = pd.read_csv(ruta_csv)
    # Convertir NaNs a None para que SQL no explote
    df = df.where(pd.notnull(df), None)

    # El mapeo debe coincidir EXACTAMENTE con lo que hay en tu tabla 'genre'
    mapeo_generos = {"rock": 1, "indie": 2, "latin": 3, "reggaeton": 4, "hip-hop": 5}

    try:
        conexion = mysql.connector.connect(
            host="127.0.0.1",
            user="root",
            password=SQL_pass, # Asegúrate de que esta variable sea accesible
            database="music_db"
        )
        cursor = conexion.cursor()
        
        # Opcional: Obtener los mbid válidos de la DB para verificar antes de insertar
        cursor.execute("SELECT id_artist FROM artists")
        artistas_validos = {row[0] for row in cursor.fetchall()}

        errores = []

        for index, fila in df.iterrows():
            try:
                # 1. Manejo del género (Normalizamos a minúsculas por si acaso)
                nombre_genero_csv = str(fila["genre"]).lower() if fila["genre"] else ""
                id_genero_numerico = mapeo_generos.get(nombre_genero_csv)
                
                # 2. Obtener el ID del artista (mbid)
                id_artista_csv = fila["artist"] # Este debe ser el MBID que subiste antes

                # Validaciones previas
                if id_genero_numerico is None:
                    print(f"Fila {index}: Género '{nombre_genero_csv}' no reconocido.")
                    continue
                
                if id_artista_csv not in artistas_validos:
                    print(f"Fila {index}: El artista '{id_artista_csv}' no existe en la tabla 'artists'.")
                    continue

                # 3. Query de inserción (Fíjate en los nombres de columnas de tu imagen)
                query = """
                INSERT INTO tracks 
                (id_artist, id_genre, track_name, year)
                VALUES (%s, %s, %s, %s)
                """
                
                valores = (
                    id_artista_csv,     # Debe ser VARCHAR(50) según tu diagrama
                    id_genero_numerico, # INT
                    fila["track_name"], # VARCHAR
                    fila["year"]        # YEAR
                )

                cursor.execute(query, valores)

            except Exception as e:
                errores.append((index, str(e)))
                print(f"Error en fila {index}: {e}")

        conexion.commit()
        print(f"Proceso terminado. Se intentaron subir {len(df)} canciones.")

    except mysql.connector.Error as err:
        print(f"Error de conexión: {err}")
    finally:
        if 'conexion' in locals() and conexion.is_connected():
            cursor.close()
            conexion.close()

# Llamada a la función
# subir_csv_a_sql_tracks("mis_canciones.csv")

# %%
subir_csv_a_sql_tracks("lista_hiphop.csv")
# Out:
# Fila 0: El artista 'MHD' no existe en la tabla 'artists'.
# Fila 1: El artista 'Post Malone' no existe en la tabla 'artists'.
# Fila 2: El artista 'Quavo' no existe en la tabla 'artists'.
# Fila 3: El artista 'Maikel Delacalle' no existe en la tabla 'artists'.
# Fila 4: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 5: El artista 'Hermano L' no existe en la tabla 'artists'.
# Fila 6: El artista 'Shabu One Shant' no existe en la tabla 'artists'.
# Fila 7: El artista 'McKlopedia' no existe en la tabla 'artists'.
# Fila 8: El artista 'Dvice' no existe en la tabla 'artists'.
# Fila 9: El artista 'Alex Kyza' no existe en la tabla 'artists'.
# Fila 10: El artista 'Darkiel' no existe en la tabla 'artists'.
# Fila 11: El artista 'Ñengo Flow' no existe en la tabla 'artists'.
# Fila 12: El artista 'Anuel AA' no existe en la tabla 'artists'.
# Fila 13: El artista 'Bryant Myers' no existe en la tabla 'artists'.
# Fila 14: El artista 'Lary Over' no existe en la tabla 'artists'.
# Fila 15: El artista 'Almighty' no existe en la tabla 'artists'.
# Fila 16: El artista 'Juanka' no existe en la tabla 'artists'.
# Fila 17: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 18: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 19: El artista 'Rels B' no existe en la tabla 'artists'.
# Fila 20: El artista 'Javier Simon' no existe en la tabla 'artists'.
# Fila 21: El artista 'Natos y Waor' no existe en la tabla 'artists'.
# Fila 22: El artista 'Anuel AA' no existe en la tabla 'artists'.
# Fila 23: El artista 'PNL' no existe en la tabla 'artists'.
# Fila 24: El artista 'Arcángel' no existe en la tabla 'artists'.
# Fila 25: El artista 'Mark B.' no existe en la tabla 'artists'.
# Fila 26: El artista 'De La Ghetto' no existe en la tabla 'artists'.
# Fila 27: El artista 'Bad Bunny' no existe en la tabla 'artists'.
# Fila 28: El artista 'Amenazzy' no existe en la tabla 'artists'.
# Fila 29: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 30: El artista 'Najwa' no existe en la tabla 'artists'.
# Fila 31: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 32: El artista 'Rihanna' no existe en la tabla 'artists'.
# Fila 33: El artista 'Kaze' no existe en la tabla 'artists'.
# Fila 34: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 35: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 36: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 37: El artista 'Rvssian' no existe en la tabla 'artists'.
# Fila 38: El artista 'Nicky Jam' no existe en la tabla 'artists'.
# Fila 39: El artista 'Farruko' no existe en la tabla 'artists'.
# Fila 40: El artista 'Arcángel' no existe en la tabla 'artists'.
# Fila 41: El artista 'Konshens' no existe en la tabla 'artists'.
# Fila 42: El artista 'Arce' no existe en la tabla 'artists'.
# Fila 43: El artista 'ieathumns' no existe en la tabla 'artists'.
# Fila 44: El artista 'Anuel AA' no existe en la tabla 'artists'.
# Fila 45: El artista 'Yomo' no existe en la tabla 'artists'.
# Fila 46: El artista 'Wisin' no existe en la tabla 'artists'.
# Fila 47: El artista 'Farruko' no existe en la tabla 'artists'.
# Fila 48: El artista 'Tito "El Bambino"' no existe en la tabla 'artists'.
# Fila 49: El artista 'Darell' no existe en la tabla 'artists'.
# Fila 50: El artista 'Anuel AA' no existe en la tabla 'artists'.
# Fila 51: El artista 'Tempo' no existe en la tabla 'artists'.
# Fila 52: El artista 'Juanka' no existe en la tabla 'artists'.
# Fila 53: El artista 'Lito Kirino' no existe en la tabla 'artists'.
# Fila 54: El artista 'Bryant Myers' no existe en la tabla 'artists'.
# Fila 55: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 56: El artista 'Cosculluela' no existe en la tabla 'artists'.
# Fila 57: El artista 'Kaze' no existe en la tabla 'artists'.
# Fila 58: El artista 'LFAM' no existe en la tabla 'artists'.
# Fila 59: El artista 'Dudu' no existe en la tabla 'artists'.
# Fila 60: El artista 'Charflex' no existe en la tabla 'artists'.
# Fila 61: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 62: El artista 'Natos y Waor' no existe en la tabla 'artists'.
# Fila 63: El artista 'Canserbero' no existe en la tabla 'artists'.
# Fila 64: El artista 'NicoJP' no existe en la tabla 'artists'.
# Fila 65: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 66: El artista 'Meek Mill' no existe en la tabla 'artists'.
# Fila 67: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 68: El artista 'Soge' no existe en la tabla 'artists'.
# Fila 69: El artista 'Arce' no existe en la tabla 'artists'.
# Fila 70: El artista 'Denom' no existe en la tabla 'artists'.
# Fila 71: El artista 'Brytiago' no existe en la tabla 'artists'.
# Fila 72: El artista 'Darell' no existe en la tabla 'artists'.
# Fila 73: El artista 'Kaze' no existe en la tabla 'artists'.
# Fila 74: El artista 'Natos y Waor' no existe en la tabla 'artists'.
# Fila 75: El artista 'Ivan Cano' no existe en la tabla 'artists'.
# Fila 76: El artista 'Liana Malva' no existe en la tabla 'artists'.
# Fila 77: El artista 'Canserbero' no existe en la tabla 'artists'.
# Fila 78: El artista 'Solo Soul' no existe en la tabla 'artists'.
# Fila 79: El artista 'Farruko' no existe en la tabla 'artists'.
# Fila 80: El artista 'Young Thug' no existe en la tabla 'artists'.
# Fila 81: El artista 'Travis Scott' no existe en la tabla 'artists'.
# Fila 82: El artista 'Myke Towers' no existe en la tabla 'artists'.
# Fila 83: El artista 'Arce' no existe en la tabla 'artists'.
# Fila 84: El artista 'Shotta' no existe en la tabla 'artists'.
# Fila 85: El artista 'Natos' no existe en la tabla 'artists'.
# Fila 86: El artista 'Waor' no existe en la tabla 'artists'.
# Fila 87: El artista 'Mad Division' no existe en la tabla 'artists'.
# Fila 88: El artista 'Trap Capos' no existe en la tabla 'artists'.
# Fila 89: El artista 'Noriel' no existe en la tabla 'artists'.
# Fila 90: El artista 'Gigolo Y La Exce' no existe en la tabla 'artists'.
# Fila 91: El artista 'Miky Woodz' no existe en la tabla 'artists'.
# Fila 92: El artista 'Juhn' no existe en la tabla 'artists'.
# Fila 93: El artista 'Baby Angel' no existe en la tabla 'artists'.
# Fila 94: El artista 'Natos y Waor' no existe en la tabla 'artists'.
# Fila 95: El artista 'Recycled J' no existe en la tabla 'artists'.
# Fila 96: El artista 'Hijos de la Ruina' no existe en la tabla 'artists'.
# Fila 97: El artista 'Jarfaiter' no existe en la tabla 'artists'.
# Fila 98: El artista 'Boef' no existe en la tabla 'artists'.
# Fila 99: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 100: El artista 'Cosculluela' no existe en la tabla 'artists'.
# Fila 101: El artista 'Lui-G 21+' no existe en la tabla 'artists'.
# Fila 102: El artista 'Ñejo' no existe en la tabla 'artists'.
# Fila 103: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 104: El artista 'Kaze' no existe en la tabla 'artists'.
# Fila 105: El artista 'Carrion GodBle$$' no existe en la tabla 'artists'.
# Fila 106: El artista 'J.Moods' no existe en la tabla 'artists'.
# Fila 107: El artista 'Ayax y Prok' no existe en la tabla 'artists'.
# Fila 108: El artista 'Kaze' no existe en la tabla 'artists'.
# Fila 109: El artista 'Ayax y Prok' no existe en la tabla 'artists'.
# Fila 110: El artista 'Beret' no existe en la tabla 'artists'.
# Fila 111: El artista 'Dante' no existe en la tabla 'artists'.
# Fila 112: El artista 'Soge' no existe en la tabla 'artists'.
# Fila 113: El artista 'Beret' no existe en la tabla 'artists'.
# Fila 114: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 115: El artista 'Travis Scott' no existe en la tabla 'artists'.
# Fila 116: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 117: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 118: El artista 'Mañas Ru-Fino' no existe en la tabla 'artists'.
# Fila 119: El artista 'Beret' no existe en la tabla 'artists'.
# Fila 120: El artista 'Trap Capos' no existe en la tabla 'artists'.
# Fila 121: El artista 'Noriel' no existe en la tabla 'artists'.
# Fila 122: El artista 'Baby Rasta' no existe en la tabla 'artists'.
# Fila 123: El artista 'Juanka' no existe en la tabla 'artists'.
# Fila 124: El artista 'Ñengo Flow' no existe en la tabla 'artists'.
# Fila 125: El artista 'Pacho' no existe en la tabla 'artists'.
# Fila 126: El artista 'Nanpa Básico' no existe en la tabla 'artists'.
# Fila 127: El artista 'Alka Produce' no existe en la tabla 'artists'.
# Fila 128: El artista 'Almighty' no existe en la tabla 'artists'.
# Fila 129: El artista 'Kulto Kultibo' no existe en la tabla 'artists'.
# Fila 130: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 131: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 132: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 133: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 134: El artista 'Rapsusklei' no existe en la tabla 'artists'.
# Fila 135: El artista 'fernando costa' no existe en la tabla 'artists'.
# Fila 136: El artista 'Kidd Keo' no existe en la tabla 'artists'.
# Fila 137: El artista 'MHD' no existe en la tabla 'artists'.
# Fila 138: El artista 'LFAM' no existe en la tabla 'artists'.
# Fila 139: El artista 'Dudu' no existe en la tabla 'artists'.
# Fila 140: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 141: El artista 'PNL' no existe en la tabla 'artists'.
# Fila 142: El artista 'Porta' no existe en la tabla 'artists'.
# Fila 143: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 144: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 145: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 146: El artista 'J. Cole' no existe en la tabla 'artists'.
# Fila 147: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 148: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 149: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 150: El artista 'J. Cole' no existe en la tabla 'artists'.
# Fila 151: El artista 'Jaloner' no existe en la tabla 'artists'.
# Fila 152: El artista 'Dabeunotres' no existe en la tabla 'artists'.
# Fila 153: El artista 'Myke Towers' no existe en la tabla 'artists'.
# Fila 154: El artista 'Ayax y Prok' no existe en la tabla 'artists'.
# Fila 155: El artista 'Garolo' no existe en la tabla 'artists'.
# Fila 156: El artista 'Hard GZ' no existe en la tabla 'artists'.
# Fila 157: El artista 'Hielo Beats' no existe en la tabla 'artists'.
# Fila 158: El artista 'Charlie Hijos Bastardos' no existe en la tabla 'artists'.
# Fila 159: El artista 'Crudo Means Raw' no existe en la tabla 'artists'.
# Fila 160: El artista 'Cráneo' no existe en la tabla 'artists'.
# Fila 161: El artista 'Made in M' no existe en la tabla 'artists'.
# Fila 162: El artista 'BxRod' no existe en la tabla 'artists'.
# Fila 163: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 164: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 165: El artista 'Soprano' no existe en la tabla 'artists'.
# Fila 166: El artista 'Jul' no existe en la tabla 'artists'.
# Fila 167: El artista '6LACK' no existe en la tabla 'artists'.
# Fila 168: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 169: El artista 'AMBKOR' no existe en la tabla 'artists'.
# Fila 170: El artista 'Piter-G' no existe en la tabla 'artists'.
# Fila 171: El artista 'Porta' no existe en la tabla 'artists'.
# Fila 172: El artista 'Kaze' no existe en la tabla 'artists'.
# Fila 173: El artista 'Hopsin' no existe en la tabla 'artists'.
# Fila 174: El artista 'PNL' no existe en la tabla 'artists'.
# Fila 175: El artista 'Duki' no existe en la tabla 'artists'.
# Fila 176: El artista 'Myke Towers' no existe en la tabla 'artists'.
# Fila 177: El artista 'Kidd Keo' no existe en la tabla 'artists'.
# Fila 178: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 179: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 180: El artista 'Mañas Ru-Fino' no existe en la tabla 'artists'.
# Fila 181: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 182: El artista 'PARTYNEXTDOOR' no existe en la tabla 'artists'.
# Fila 183: El artista 'Ninho' no existe en la tabla 'artists'.
# Fila 184: El artista 'Nanpa Básico' no existe en la tabla 'artists'.
# Fila 185: El artista 'Santa RM' no existe en la tabla 'artists'.
# Fila 186: El artista 'Future' no existe en la tabla 'artists'.
# Fila 187: El artista 'Meek Mill' no existe en la tabla 'artists'.
# Fila 188: El artista 'Sound M.O.B.' no existe en la tabla 'artists'.
# Fila 189: El artista 'Tory Lanez' no existe en la tabla 'artists'.
# Fila 190: El artista 'Young Thug' no existe en la tabla 'artists'.
# Fila 191: El artista 'Sfera Ebbasta' no existe en la tabla 'artists'.
# Fila 192: El artista 'Poldoore' no existe en la tabla 'artists'.
# Fila 193: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 194: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 195: El artista 'Gucci Mane' no existe en la tabla 'artists'.
# Fila 196: El artista 'Big Sean' no existe en la tabla 'artists'.
# Fila 197: El artista '2 Chainz' no existe en la tabla 'artists'.
# Fila 198: El artista 'Travis Scott' no existe en la tabla 'artists'.
# Fila 199: El artista 'Yo Gotti' no existe en la tabla 'artists'.
# Fila 200: El artista 'Quavo' no existe en la tabla 'artists'.
# Fila 201: El artista 'Desiigner' no existe en la tabla 'artists'.
# Fila 202: El artista 'Cartel De Santa' no existe en la tabla 'artists'.
# Fila 203: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 204: El artista 'Xhelazz' no existe en la tabla 'artists'.
# Fila 205: El artista 'Sho-Hai' no existe en la tabla 'artists'.
# Fila 206: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 207: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 208: El artista 'Cartel De Santa' no existe en la tabla 'artists'.
# Fila 209: El artista 'Sfera Ebbasta' no existe en la tabla 'artists'.
# Fila 210: El artista 'Crack Family' no existe en la tabla 'artists'.
# Fila 212: El artista 'Snoop Dogg' no existe en la tabla 'artists'.
# Fila 213: El artista 'Anuel AA' no existe en la tabla 'artists'.
# Fila 214: El artista 'Rapsusklei' no existe en la tabla 'artists'.
# Fila 215: El artista 'Sharif' no existe en la tabla 'artists'.
# Fila 216: El artista 'Sr. Wilson' no existe en la tabla 'artists'.
# Fila 217: El artista 'Beret' no existe en la tabla 'artists'.
# Fila 218: El artista 'Kase.O' no existe en la tabla 'artists'.
# Fila 219: El artista 'Beret' no existe en la tabla 'artists'.
# Fila 220: El artista 'Isaiah Rashad' no existe en la tabla 'artists'.
# Fila 221: El artista 'Zacari' no existe en la tabla 'artists'.
# Fila 222: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 223: El artista 'Jul' no existe en la tabla 'artists'.
# Fila 224: El artista 'PNL' no existe en la tabla 'artists'.
# Fila 225: El artista 'Jul' no existe en la tabla 'artists'.
# Fila 226: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 227: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 228: El artista 'Myke Towers' no existe en la tabla 'artists'.
# Fila 229: El artista 'Lytos' no existe en la tabla 'artists'.
# Fila 230: El artista 'Beret' no existe en la tabla 'artists'.
# Fila 231: El artista 'A Boogie Wit da Hoodie' no existe en la tabla 'artists'.
# Fila 232: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 233: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 234: El artista 'Future' no existe en la tabla 'artists'.
# Fila 235: El artista 'Booba' no existe en la tabla 'artists'.
# Fila 236: El artista 'Fat Joe' no existe en la tabla 'artists'.
# Fila 237: El artista 'Remy Ma' no existe en la tabla 'artists'.
# Fila 238: El artista 'JAY-Z' no existe en la tabla 'artists'.
# Fila 239: El artista 'French Montana' no existe en la tabla 'artists'.
# Fila 240: El artista 'InfaRed' no existe en la tabla 'artists'.
# Fila 241: El artista 'Zof Ziro' no existe en la tabla 'artists'.
# Fila 242: El artista 'ZetaZeta' no existe en la tabla 'artists'.
# Fila 243: El artista 'Ali Aka Mind' no existe en la tabla 'artists'.
# Fila 244: El artista 'PNL' no existe en la tabla 'artists'.
# Fila 245: El artista 'Canserbero' no existe en la tabla 'artists'.
# Fila 246: El artista 'NicoJP' no existe en la tabla 'artists'.
# Fila 247: El artista 'Gran Calibre' no existe en la tabla 'artists'.
# Fila 248: El artista 'NF' no existe en la tabla 'artists'.
# Fila 249: El artista 'Mac Miller' no existe en la tabla 'artists'.
# Fila 250: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 251: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 252: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 253: El artista 'NF' no existe en la tabla 'artists'.
# Fila 254: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 255: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 256: El artista 'Alvaro Diaz' no existe en la tabla 'artists'.
# Fila 257: El artista 'Almighty' no existe en la tabla 'artists'.
# Fila 258: El artista 'Porta' no existe en la tabla 'artists'.
# Fila 259: El artista 'Crudo Means Raw' no existe en la tabla 'artists'.
# Fila 260: El artista 'DJ Dmoe' no existe en la tabla 'artists'.
# Fila 261: El artista 'Young Thug' no existe en la tabla 'artists'.
# Fila 262: El artista 'Quavo' no existe en la tabla 'artists'.
# Fila 263: El artista 'Offset' no existe en la tabla 'artists'.
# Fila 264: El artista 'Young Scooter' no existe en la tabla 'artists'.
# Fila 265: El artista 'Drake' no existe en la tabla 'artists'.
# Fila 266: El artista 'Playboi Carti' no existe en la tabla 'artists'.
# Fila 267: El artista 'Rich The Kid' no existe en la tabla 'artists'.
# Fila 268: El artista 'Kodak Black' no existe en la tabla 'artists'.
# Fila 269: El artista 'Bonez MC' no existe en la tabla 'artists'.
# Fila 270: El artista 'RAF Camora' no existe en la tabla 'artists'.
# Fila 271: El artista 'Maxwell' no existe en la tabla 'artists'.
# Fila 272: El artista 'Big L' no existe en la tabla 'artists'.
# Fila 273: El artista 'La Cueva Mokoya' no existe en la tabla 'artists'.
# Fila 274: El artista 'Al2 El Aldeano' no existe en la tabla 'artists'.
# Fila 275: El artista 'Silvito El Libre' no existe en la tabla 'artists'.
# Fila 276: El artista 'Cráneo' no existe en la tabla 'artists'.
# Fila 277: El artista 'Made in M' no existe en la tabla 'artists'.
# Fila 278: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 279: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 280: El artista 'Piter-G' no existe en la tabla 'artists'.
# Fila 281: El artista 'Damso' no existe en la tabla 'artists'.
# Fila 282: El artista 'Alvaro Diaz' no existe en la tabla 'artists'.
# Fila 283: El artista 'Cartel De Santa' no existe en la tabla 'artists'.
# Fila 284: El artista 'J. Cole' no existe en la tabla 'artists'.
# Fila 285: El artista 'PNL' no existe en la tabla 'artists'.
# Fila 286: El artista 'PNL' no existe en la tabla 'artists'.
# Fila 287: El artista 'J. Cole' no existe en la tabla 'artists'.
# Fila 288: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 289: El artista 'Muslim' no existe en la tabla 'artists'.
# Fila 290: El artista 'Dj Van' no existe en la tabla 'artists'.
# Fila 291: El artista 'Crudo Means Raw' no existe en la tabla 'artists'.
# Fila 292: El artista 'Cosculluela' no existe en la tabla 'artists'.
# Fila 293: El artista 'Arcángel' no existe en la tabla 'artists'.
# Fila 294: El artista 'De La Ghetto' no existe en la tabla 'artists'.
# Fila 295: El artista 'Lil Uzi Vert' no existe en la tabla 'artists'.
# Fila 296: El artista 'Future' no existe en la tabla 'artists'.
# Fila 297: El artista 'BONES' no existe en la tabla 'artists'.
# Fila 298: El artista 'Ninho' no existe en la tabla 'artists'.
# Fila 299: El artista 'Big L' no existe en la tabla 'artists'.
# Fila 300: El artista 'Hooss' no existe en la tabla 'artists'.
# Fila 301: El artista 'Jul' no existe en la tabla 'artists'.
# Fila 302: El artista 'Post Malone' no existe en la tabla 'artists'.
# Fila 303: El artista '2 Chainz' no existe en la tabla 'artists'.
# Fila 304: El artista 'Farruko' no existe en la tabla 'artists'.
# Fila 305: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 306: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 307: El artista 'Mañas Ru-Fino' no existe en la tabla 'artists'.
# Fila 308: El artista 'Crudo Means Raw' no existe en la tabla 'artists'.
# Fila 309: El artista 'Emapea' no existe en la tabla 'artists'.
# Fila 310: El artista 'Kanye West' no existe en la tabla 'artists'.
# Fila 311: El artista 'J. Cole' no existe en la tabla 'artists'.
# Fila 312: El artista 'Kalash Criminel' no existe en la tabla 'artists'.
# Fila 313: El artista 'Rilès' no existe en la tabla 'artists'.
# Fila 314: El artista 'Future' no existe en la tabla 'artists'.
# Fila 315: El artista 'Hungria' no existe en la tabla 'artists'.
# Fila 316: El artista 'Laylow' no existe en la tabla 'artists'.
# Fila 317: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 318: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 319: El artista 'Mañas Ru-Fino' no existe en la tabla 'artists'.
# Fila 320: El artista 'Granuja' no existe en la tabla 'artists'.
# Fila 321: El artista 'Yung Lean' no existe en la tabla 'artists'.
# Fila 322: El artista 'Black Kray' no existe en la tabla 'artists'.
# Fila 323: El artista 'Bladee' no existe en la tabla 'artists'.
# Fila 324: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 325: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 326: El artista 'Big L' no existe en la tabla 'artists'.
# Fila 327: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 328: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 329: El artista 'A Tribe Called Quest' no existe en la tabla 'artists'.
# Fila 330: El artista 'Norick' no existe en la tabla 'artists'.
# Fila 331: El artista 'Damso' no existe en la tabla 'artists'.
# Fila 332: El artista 'Booba' no existe en la tabla 'artists'.
# Fila 333: El artista 'Salmo' no existe en la tabla 'artists'.
# Fila 334: El artista '6LACK' no existe en la tabla 'artists'.
# Fila 335: El artista 'Young Thug' no existe en la tabla 'artists'.
# Fila 336: El artista 'Nekfeu' no existe en la tabla 'artists'.
# Fila 337: El artista 'Big L' no existe en la tabla 'artists'.
# Fila 338: El artista 'Kent Jones' no existe en la tabla 'artists'.
# Fila 339: El artista 'Pitbull' no existe en la tabla 'artists'.
# Fila 340: El artista 'Lil Wayne' no existe en la tabla 'artists'.
# Fila 341: El artista 'Adán Cruz' no existe en la tabla 'artists'.
# Fila 342: El artista 'Young Thug' no existe en la tabla 'artists'.
# Fila 343: El artista 'Cartel De Santa' no existe en la tabla 'artists'.
# Fila 344: El artista 'Rilès' no existe en la tabla 'artists'.
# Fila 345: El artista 'Kalash' no existe en la tabla 'artists'.
# Fila 346: El artista 'Booba' no existe en la tabla 'artists'.
# Fila 347: El artista 'MadeinTYO' no existe en la tabla 'artists'.
# Fila 348: El artista '2 Chainz' no existe en la tabla 'artists'.
# Fila 349: El artista 'Scrop' no existe en la tabla 'artists'.
# Fila 350: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 351: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 352: El artista 'Mañas Ru-Fino' no existe en la tabla 'artists'.
# Fila 353: El artista 'DJ Destroy' no existe en la tabla 'artists'.
# Fila 354: El artista 'Doble Porcion' no existe en la tabla 'artists'.
# Fila 355: El artista 'Métricas Frías' no existe en la tabla 'artists'.
# Fila 356: El artista 'Mañas Ru-Fino' no existe en la tabla 'artists'.
# Fila 357: El artista 'Almas de Barrio' no existe en la tabla 'artists'.
# Fila 358: El artista 'Sabino' no existe en la tabla 'artists'.
# Fila 359: El artista 'Young Thug' no existe en la tabla 'artists'.
# Fila 360: El artista 'Chystemc' no existe en la tabla 'artists'.
# Fila 361: El artista 'Capo Plaza' no existe en la tabla 'artists'.
# Fila 362: El artista 'AVA' no existe en la tabla 'artists'.
# Fila 363: El artista 'Millonario' no existe en la tabla 'artists'.
# Fila 364: El artista 'Mister You' no existe en la tabla 'artists'.
# Fila 365: El artista 'Ninho' no existe en la tabla 'artists'.
# Fila 366: El artista 'Dark Polo Gang' no existe en la tabla 'artists'.
# Fila 367: El artista 'Sfera Ebbasta' no existe en la tabla 'artists'.
# Fila 369: El artista 'Norick' no existe en la tabla 'artists'.
# Fila 370: El artista 'J. Cole' no existe en la tabla 'artists'.
# Fila 371: El artista 'Cartel De Santa' no existe en la tabla 'artists'.
# Fila 372: El artista 'Dark Polo Gang' no existe en la tabla 'artists'.
# Fila 373: El artista 'Hungria' no existe en la tabla 'artists'.
# Fila 374: El artista 'Hamza' no existe en la tabla 'artists'.
# Fila 375: El artista 'Niska' no existe en la tabla 'artists'.
# Fila 376: El artista 'Young Greatness' no existe en la tabla 'artists'.
# Fila 377: El artista 'Ljones' no existe en la tabla 'artists'.
# Fila 378: El artista 'Akapellah' no existe en la tabla 'artists'.
# Fila 379: El artista '2nd Exit' no existe en la tabla 'artists'.
# Fila 380: El artista 'Alfa Mist' no existe en la tabla 'artists'.
# Fila 381: El artista 'Lester Duval' no existe en la tabla 'artists'.
# Fila 382: El artista 'Mamborap' no existe en la tabla 'artists'.
# Fila 383: El artista 'Dillaz' no existe en la tabla 'artists'.
# Fila 384: El artista 'Cartel De Santa' no existe en la tabla 'artists'.
# Fila 385: El artista 'Hungria' no existe en la tabla 'artists'.
# Fila 386: El artista 'Kid Cudi' no existe en la tabla 'artists'.
# Fila 387: El artista 'Travis Scott' no existe en la tabla 'artists'.
# Fila 388: El artista 'Lianna' no existe en la tabla 'artists'.
# Fila 389: El artista 'Gambeta' no existe en la tabla 'artists'.
# Fila 390: El artista 'Samurai' no existe en la tabla 'artists'.
# Fila 391: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 392: El artista 'Young Thug' no existe en la tabla 'artists'.
# Fila 393: El artista 'Baby Brown' no existe en la tabla 'artists'.
# Fila 394: El artista 'Idrise' no existe en la tabla 'artists'.
# Fila 395: El artista 'The Mith' no existe en la tabla 'artists'.
# Fila 396: El artista 'J.C Muyonjo' no existe en la tabla 'artists'.
# Fila 397: El artista 'Lord Of Ajasa' no existe en la tabla 'artists'.
# Fila 398: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 399: El artista 'Old Self' no existe en la tabla 'artists'.
# Fila 400: El artista 'Sukkerfabrikken' no existe en la tabla 'artists'.
# Fila 401: El artista 'Big Momma' no existe en la tabla 'artists'.
# Fila 402: El artista 'Ansa' no existe en la tabla 'artists'.
# Fila 403: El artista 'Zorimawi' no existe en la tabla 'artists'.
# Fila 404: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 405: El artista 'Freeway' no existe en la tabla 'artists'.
# Fila 406: El artista 'Dena' no existe en la tabla 'artists'.
# Fila 407: El artista 'Brown Sugar' no existe en la tabla 'artists'.
# Fila 408: El artista 'DEADP' no existe en la tabla 'artists'.
# Fila 409: El artista 'Hoodini' no existe en la tabla 'artists'.
# Fila 410: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 411: El artista 'TBF' no existe en la tabla 'artists'.
# Fila 412: El artista 'ILL BILL' no existe en la tabla 'artists'.
# Fila 413: El artista 'Da Gudda Jazz' no existe en la tabla 'artists'.
# Fila 414: El artista 'Lord Of Ajasa' no existe en la tabla 'artists'.
# Fila 415: El artista 'Osaniyi Olusegun' no existe en la tabla 'artists'.
# Fila 416: El artista 'Cam Murdoch' no existe en la tabla 'artists'.
# Fila 417: El artista 'Mardn' no existe en la tabla 'artists'.
# Fila 418: El artista 'ManHanD' no existe en la tabla 'artists'.
# Fila 419: El artista 'K Kutta' no existe en la tabla 'artists'.
# Fila 420: El artista 'Ansa' no existe en la tabla 'artists'.
# Fila 421: El artista 'Mac Dre' no existe en la tabla 'artists'.
# Fila 422: El artista 'DJ Michael 5000 Watts' no existe en la tabla 'artists'.
# Fila 423: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 424: El artista 'Game on! Minnesota' no existe en la tabla 'artists'.
# Fila 425: El artista 'Alex Frecon' no existe en la tabla 'artists'.
# Fila 426: El artista '40 Cal.' no existe en la tabla 'artists'.
# Fila 427: El artista 'Kholebeatz' no existe en la tabla 'artists'.
# Fila 428: El artista 'Un Kasa' no existe en la tabla 'artists'.
# Fila 429: El artista 'HMD' no existe en la tabla 'artists'.
# Fila 430: El artista 'Zungu Pablo' no existe en la tabla 'artists'.
# Fila 431: El artista 'Violence' no existe en la tabla 'artists'.
# Fila 432: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 433: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 434: El artista 'Hezi Shaked' no existe en la tabla 'artists'.
# Fila 435: El artista 'Meta Four' no existe en la tabla 'artists'.
# Fila 436: El artista 'Sebway' no existe en la tabla 'artists'.
# Fila 437: El artista 'Point Blank' no existe en la tabla 'artists'.
# Fila 438: El artista 'Wreckless Klan' no existe en la tabla 'artists'.
# Fila 439: El artista 'K Kutta' no existe en la tabla 'artists'.
# Fila 440: El artista 'BFP' no existe en la tabla 'artists'.
# Fila 441: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 442: El artista 'Shady Nate' no existe en la tabla 'artists'.
# Fila 443: El artista 'ShabZi Madallion' no existe en la tabla 'artists'.
# Fila 444: El artista 'CISKO' no existe en la tabla 'artists'.
# Fila 445: El artista 'Rowlan' no existe en la tabla 'artists'.
# Fila 446: El artista 'Nigma' no existe en la tabla 'artists'.
# Fila 447: El artista 'Anetta' no existe en la tabla 'artists'.
# Fila 448: El artista 'K Kutta' no existe en la tabla 'artists'.
# Fila 449: El artista 'Makkie' no existe en la tabla 'artists'.
# Fila 450: El artista 'Romario Panka' no existe en la tabla 'artists'.
# Fila 451: El artista 'TNO' no existe en la tabla 'artists'.
# Fila 452: El artista 'TMC' no existe en la tabla 'artists'.
# Fila 453: El artista 'Red Shaydez' no existe en la tabla 'artists'.
# Fila 454: El artista 'Анна Хмара' no existe en la tabla 'artists'.
# Fila 455: El artista 'Олег Ким' no existe en la tabla 'artists'.
# Fila 456: El artista 'Frank Waln' no existe en la tabla 'artists'.
# Fila 457: El artista 'Tanaya Winder' no existe en la tabla 'artists'.
# Fila 458: El artista 'Nag' no existe en la tabla 'artists'.
# Fila 459: El artista 'Arlo Maverick' no existe en la tabla 'artists'.
# Fila 460: El artista 'LMR' no existe en la tabla 'artists'.
# Fila 461: El artista 'Rebi' no existe en la tabla 'artists'.
# Fila 462: El artista 'FDK' no existe en la tabla 'artists'.
# Fila 463: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 464: El artista 'Bo' no existe en la tabla 'artists'.
# Fila 465: El artista 'Bucci' no existe en la tabla 'artists'.
# Fila 466: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 467: El artista 'D-Weez' no existe en la tabla 'artists'.
# Fila 468: El artista 'Scoot Da Kidd' no existe en la tabla 'artists'.
# Fila 469: El artista 'Smoke DZA' no existe en la tabla 'artists'.
# Fila 470: El artista 'John'nay Lasha' no existe en la tabla 'artists'.
# Fila 471: El artista 'Rydah J. Klyde' no existe en la tabla 'artists'.
# Fila 472: El artista 'Shawn May' no existe en la tabla 'artists'.
# Fila 473: El artista 'Isaiah Pharaoh' no existe en la tabla 'artists'.
# Fila 474: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 475: El artista 'Amazin Payne' no existe en la tabla 'artists'.
# Fila 476: El artista 'Doe Boy' no existe en la tabla 'artists'.
# Fila 477: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 478: El artista 'Eden Gabay' no existe en la tabla 'artists'.
# Fila 479: El artista 'Cool D' no existe en la tabla 'artists'.
# Fila 480: El artista 'Dubbul O' no existe en la tabla 'artists'.
# Fila 481: El artista 'Pro P' no existe en la tabla 'artists'.
# Fila 482: El artista 'Hyu' no existe en la tabla 'artists'.
# Fila 483: El artista 'Point Blank' no existe en la tabla 'artists'.
# Fila 484: El artista 'Yungstar' no existe en la tabla 'artists'.
# Fila 485: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 486: El artista 'Point Blank' no existe en la tabla 'artists'.
# Fila 487: El artista 'Klondike Kat' no existe en la tabla 'artists'.
# Fila 488: El artista 'Lil' Keke' no existe en la tabla 'artists'.
# Fila 489: El artista 'The Rook' no existe en la tabla 'artists'.
# Fila 490: El artista 'Dirty Alex' no existe en la tabla 'artists'.
# Fila 491: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 492: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 493: El artista 'John'nay Lasha' no existe en la tabla 'artists'.
# Fila 494: El artista 'Stasiak' no existe en la tabla 'artists'.
# Fila 495: El artista 'Wasabi' no existe en la tabla 'artists'.
# Fila 496: El artista 'Leo The Kind' no existe en la tabla 'artists'.
# Fila 497: El artista 'EffE' no existe en la tabla 'artists'.
# Fila 498: El artista 'Hyu' no existe en la tabla 'artists'.
# Fila 499: El artista 'Ro9' no existe en la tabla 'artists'.
# Fila 500: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 501: El artista 'Kid Quill' no existe en la tabla 'artists'.
# Fila 502: El artista 'Kuniva' no existe en la tabla 'artists'.
# Fila 503: El artista 'Hunter' no existe en la tabla 'artists'.
# Fila 504: El artista 'Foxx' no existe en la tabla 'artists'.
# Fila 505: El artista 'Kuniva' no existe en la tabla 'artists'.
# Fila 506: El artista 'Rich The Factor' no existe en la tabla 'artists'.
# Fila 507: El artista 'Ampichino' no existe en la tabla 'artists'.
# Fila 508: El artista 'P3' no existe en la tabla 'artists'.
# Fila 509: El artista 'John'nay Lasha' no existe en la tabla 'artists'.
# Fila 510: El artista 'Meta Four' no existe en la tabla 'artists'.
# Fila 511: El artista 'RKO' no existe en la tabla 'artists'.
# Fila 512: El artista 'Sebway' no existe en la tabla 'artists'.
# Fila 513: El artista 'Biggie Paul' no existe en la tabla 'artists'.
# Fila 514: El artista 'The Essence' no existe en la tabla 'artists'.
# Fila 515: El artista 'Sleazy F Baby' no existe en la tabla 'artists'.
# Fila 516: El artista 'Kinetical' no existe en la tabla 'artists'.
# Fila 517: El artista 'Odd Nosdam' no existe en la tabla 'artists'.
# Fila 518: El artista 'Zeman' no existe en la tabla 'artists'.
# Fila 519: El artista 'Bad Balance' no existe en la tabla 'artists'.
# Fila 520: El artista 'Cam Murdoch' no existe en la tabla 'artists'.
# Fila 521: El artista 'ShabZi Madallion' no existe en la tabla 'artists'.
# Fila 522: El artista 'The Mith' no existe en la tabla 'artists'.
# Fila 523: El artista 'Freeway' no existe en la tabla 'artists'.
# Fila 524: El artista 'Rich The Factor' no existe en la tabla 'artists'.
# Fila 525: El artista 'Berny' no existe en la tabla 'artists'.
# Fila 526: El artista 'Grupa Banana' no existe en la tabla 'artists'.
# Fila 527: El artista 'Adam Kanyama' no existe en la tabla 'artists'.
# Fila 528: El artista 'Side' no existe en la tabla 'artists'.
# Fila 529: El artista 'femdot.' no existe en la tabla 'artists'.
# Fila 530: El artista 'AGE McSoul' no existe en la tabla 'artists'.
# Fila 531: El artista 'Mclyne' no existe en la tabla 'artists'.
# Fila 532: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 533: El artista 'Eden Gabay' no existe en la tabla 'artists'.
# Fila 534: El artista 'Bad Balance' no existe en la tabla 'artists'.
# Fila 535: El artista 'EKR' no existe en la tabla 'artists'.
# Fila 536: El artista 'Bucci' no existe en la tabla 'artists'.
# Fila 537: El artista 'Texta' no existe en la tabla 'artists'.
# Fila 538: El artista 'Rankz' no existe en la tabla 'artists'.
# Fila 539: El artista 'Lilluminati' no existe en la tabla 'artists'.
# Fila 540: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 541: El artista 'Eden Gabay' no existe en la tabla 'artists'.
# Fila 542: El artista 'VETO' no existe en la tabla 'artists'.
# Fila 543: El artista 'Sherry-ou' no existe en la tabla 'artists'.
# Fila 544: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 545: El artista 'Eden Gabay' no existe en la tabla 'artists'.
# Fila 546: El artista 'Hoodini' no existe en la tabla 'artists'.
# Fila 547: El artista 'Factor' no existe en la tabla 'artists'.
# Fila 548: El artista 'Promoe' no existe en la tabla 'artists'.
# Fila 549: El artista 'Biggie Paul' no existe en la tabla 'artists'.
# Fila 550: El artista 'The Essence' no existe en la tabla 'artists'.
# Fila 551: El artista 'Stina Velocette' no existe en la tabla 'artists'.
# Fila 552: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 553: El artista 'Rich The Factor' no existe en la tabla 'artists'.
# Fila 554: El artista 'Trapperman Dale' no existe en la tabla 'artists'.
# Fila 555: El artista 'Hella Maze' no existe en la tabla 'artists'.
# Fila 556: El artista 'DA 108' no existe en la tabla 'artists'.
# Fila 557: El artista 'ТНМК' no existe en la tabla 'artists'.
# Fila 558: El artista 'Kitok' no existe en la tabla 'artists'.
# Fila 559: El artista 'J-Lamo' no existe en la tabla 'artists'.
# Fila 560: El artista 'Wizdom' no existe en la tabla 'artists'.
# Fila 561: El artista 'Stunner' no existe en la tabla 'artists'.
# Fila 562: El artista 'Claire Willis' no existe en la tabla 'artists'.
# Fila 563: El artista 'Bad Balance' no existe en la tabla 'artists'.
# Fila 564: El artista 'Bucci' no existe en la tabla 'artists'.
# Fila 565: El artista 'K. Jizzle' no existe en la tabla 'artists'.
# Fila 566: El artista 'Jae' no existe en la tabla 'artists'.
# Fila 567: El artista 'Factor' no existe en la tabla 'artists'.
# Fila 568: El artista 'Wizdom' no existe en la tabla 'artists'.
# Fila 569: El artista 'AGE McSoul' no existe en la tabla 'artists'.
# Fila 570: El artista 'FGT Ndocci' no existe en la tabla 'artists'.
# Fila 571: El artista 'Mr. Wilson' no existe en la tabla 'artists'.
# Fila 572: El artista 'Twee P' no existe en la tabla 'artists'.
# Fila 573: El artista 'Slick Styles' no existe en la tabla 'artists'.
# Fila 574: El artista 'The Mith' no existe en la tabla 'artists'.
# Fila 575: El artista 'Ekky' no existe en la tabla 'artists'.
# Fila 576: El artista 'Kydd Jones' no existe en la tabla 'artists'.
# Fila 577: El artista 'Y2' no existe en la tabla 'artists'.
# Fila 578: El artista 'John'nay Lasha' no existe en la tabla 'artists'.
# Fila 579: El artista 'AGE McSoul' no existe en la tabla 'artists'.
# Fila 580: El artista 'Traphik' no existe en la tabla 'artists'.
# Fila 581: El artista 'Cam Murdoch' no existe en la tabla 'artists'.
# Fila 582: El artista 'Ed Washington' no existe en la tabla 'artists'.
# Fila 583: El artista 'EQuBE' no existe en la tabla 'artists'.
# Fila 584: El artista 'Mr Noon' no existe en la tabla 'artists'.
# Fila 585: El artista 'Hella Maze' no existe en la tabla 'artists'.
# Fila 586: El artista 'Ціна Ритму' no existe en la tabla 'artists'.
# Fila 587: El artista 'John'nay Lasha' no existe en la tabla 'artists'.
# Fila 588: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 589: El artista 'Eden Gabay' no existe en la tabla 'artists'.
# Fila 590: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 591: El artista 'Crack Ignaz' no existe en la tabla 'artists'.
# Fila 592: El artista 'Nicko' no existe en la tabla 'artists'.
# Fila 593: El artista 'Ironik' no existe en la tabla 'artists'.
# Fila 594: El artista 'Brown Sugar' no existe en la tabla 'artists'.
# Fila 595: El artista 'Freelow' no existe en la tabla 'artists'.
# Fila 596: El artista 'Zeman' no existe en la tabla 'artists'.
# Fila 597: El artista 'Sarafa' no existe en la tabla 'artists'.
# Fila 598: El artista 'Hyu' no existe en la tabla 'artists'.
# Fila 599: El artista 'Anamarija Majcen' no existe en la tabla 'artists'.
# Fila 600: El artista 'Azrael The Silent Angel' no existe en la tabla 'artists'.
# Fila 601: El artista 'D-Weez' no existe en la tabla 'artists'.
# Fila 602: El artista 'Self Da Gritter' no existe en la tabla 'artists'.
# Fila 603: El artista 'Tae G' no existe en la tabla 'artists'.
# Fila 604: El artista 'Eazy Racks' no existe en la tabla 'artists'.
# Fila 605: El artista 'Noah23' no existe en la tabla 'artists'.
# Fila 606: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 607: El artista 'Eden Gabay' no existe en la tabla 'artists'.
# Fila 608: El artista 'Cool D' no existe en la tabla 'artists'.
# Fila 609: El artista 'Sarafa' no existe en la tabla 'artists'.
# Fila 610: El artista 'Si-Si' no existe en la tabla 'artists'.
# Fila 611: El artista 'Adam Kanyama' no existe en la tabla 'artists'.
# Fila 612: El artista 'D-Weez' no existe en la tabla 'artists'.
# Fila 613: El artista 'Self Da Gritter' no existe en la tabla 'artists'.
# Fila 614: El artista 'S Dot Honcho' no existe en la tabla 'artists'.
# Fila 615: El artista 'Big Flame' no existe en la tabla 'artists'.
# Fila 616: El artista 'VETO' no existe en la tabla 'artists'.
# Fila 617: El artista 'D-Weez' no existe en la tabla 'artists'.
# Fila 618: El artista 'Self Da Gritter' no existe en la tabla 'artists'.
# Fila 619: El artista 'Koi Child' no existe en la tabla 'artists'.
# Fila 620: El artista 'VETO' no existe en la tabla 'artists'.
# Fila 621: El artista 'Mrs M' no existe en la tabla 'artists'.
# Fila 622: El artista 'Hella Maze' no existe en la tabla 'artists'.
# Fila 623: El artista 'Hoodini' no existe en la tabla 'artists'.
# Fila 624: El artista '4 5th' no existe en la tabla 'artists'.
# Fila 625: El artista 'Point Blank' no existe en la tabla 'artists'.
# Fila 626: El artista 'Blackface' no existe en la tabla 'artists'.
# Fila 627: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 628: El artista 'Hezi Shaked' no existe en la tabla 'artists'.
# Fila 629: El artista 'Rich The Factor' no existe en la tabla 'artists'.
# Fila 630: El artista 'Christian' no existe en la tabla 'artists'.
# Fila 631: El artista 'EKR' no existe en la tabla 'artists'.
# Fila 632: El artista 'Kaliber 44' no existe en la tabla 'artists'.
# Fila 633: El artista 'Chey Dolla' no existe en la tabla 'artists'.
# Fila 634: El artista 'Jack Tunny' no existe en la tabla 'artists'.
# Fila 635: El artista 'D-Weez' no existe en la tabla 'artists'.
# Fila 636: El artista 'Self Da Gritter' no existe en la tabla 'artists'.
# Fila 637: El artista 'Jack Tunny' no existe en la tabla 'artists'.
# Fila 638: El artista 'B:folk' no existe en la tabla 'artists'.
# Fila 639: El artista 'Chey Dolla' no existe en la tabla 'artists'.
# Fila 640: El artista 'Good Evening' no existe en la tabla 'artists'.
# Fila 641: El artista 'Blackface' no existe en la tabla 'artists'.
# Fila 642: El artista 'Jaya' no existe en la tabla 'artists'.
# Fila 643: El artista 'Myndbandabúi NFMH' no existe en la tabla 'artists'.
# Fila 644: El artista 'Hyu' no existe en la tabla 'artists'.
# Fila 645: El artista 'Tilen Jan' no existe en la tabla 'artists'.
# Fila 646: El artista 'Ante Cash' no existe en la tabla 'artists'.
# Fila 647: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 648: El artista 'Hezi Shaked' no existe en la tabla 'artists'.
# Fila 649: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 650: El artista 'Ali As' no existe en la tabla 'artists'.
# Fila 651: El artista 'Crack Ignaz' no existe en la tabla 'artists'.
# Fila 652: El artista 'Tereza' no existe en la tabla 'artists'.
# Fila 653: El artista 'ShabZi Madallion' no existe en la tabla 'artists'.
# Fila 654: El artista 'Porter Ray' no existe en la tabla 'artists'.
# Fila 655: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 656: El artista 'Ori Shochat' no existe en la tabla 'artists'.
# Fila 657: El artista 'Chanda Mbao' no existe en la tabla 'artists'.
# Fila 658: El artista 'Malz' no existe en la tabla 'artists'.
# Fila 659: El artista 'Bucci' no existe en la tabla 'artists'.
# Fila 660: El artista 'Lil Raider' no existe en la tabla 'artists'.
# Fila 661: El artista 'Masteri' no existe en la tabla 'artists'.
# Fila 662: El artista 'Conscious Route' no existe en la tabla 'artists'.
# Fila 663: El artista 'Micall Parknsun' no existe en la tabla 'artists'.
# Fila 664: El artista 'VETO' no existe en la tabla 'artists'.
# Fila 665: El artista 'VETO' no existe en la tabla 'artists'.
# Fila 666: El artista 'Cool D' no existe en la tabla 'artists'.
# Fila 667: El artista 'Skittles' no existe en la tabla 'artists'.
# Fila 668: El artista 'Chey Dolla' no existe en la tabla 'artists'.
# Fila 669: El artista 'Gifted Gab' no existe en la tabla 'artists'.
# Fila 670: El artista 'Hoodini' no existe en la tabla 'artists'.
# Fila 671: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 672: El artista 'Frenchie' no existe en la tabla 'artists'.
# Fila 673: El artista 'Dirty Alex' no existe en la tabla 'artists'.
# Fila 674: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 675: El artista 'Carlos Leal' no existe en la tabla 'artists'.
# Fila 676: El artista 'Bucci' no existe en la tabla 'artists'.
# Fila 677: El artista 'Anuel AA' no existe en la tabla 'artists'.
# Fila 678: El artista 'Ñengo Flow' no existe en la tabla 'artists'.
# Fila 679: El artista 'Sinfonico' no existe en la tabla 'artists'.
# Fila 680: El artista 'Lil Geniuz' no existe en la tabla 'artists'.
# Fila 681: El artista 'Farruko' no existe en la tabla 'artists'.
# Fila 682: El artista 'Casper Magico' no existe en la tabla 'artists'.
# Fila 683: El artista 'Darell' no existe en la tabla 'artists'.
# Fila 684: El artista 'Bad Bunny' no existe en la tabla 'artists'.
# Fila 685: El artista 'Kidd Keo' no existe en la tabla 'artists'.
# Fila 686: El artista 'Rels B' no existe en la tabla 'artists'.
# Fila 687: El artista 'Maikel Delacalle' no existe en la tabla 'artists'.
# Fila 688: El artista 'Daddy Yankee' no existe en la tabla 'artists'.
# Fila 689: El artista 'Bad Bunny' no existe en la tabla 'artists'.
# Fila 690: El artista 'Bad Bunny' no existe en la tabla 'artists'.
# Fila 691: El artista 'Mambo Kingz' no existe en la tabla 'artists'.
# Fila 692: El artista 'DJ Luian' no existe en la tabla 'artists'.
# Fila 693: El artista 'Arcángel' no existe en la tabla 'artists'.
# Fila 694: El artista 'Almighty' no existe en la tabla 'artists'.
# Fila 695: El artista 'Bryant Myers' no existe en la tabla 'artists'.
# Fila 696: El artista 'Noriel' no existe en la tabla 'artists'.
# Fila 697: El artista 'Baby Rasta' no existe en la tabla 'artists'.
# Fila 698: El artista 'Brytiago' no existe en la tabla 'artists'.
# Fila 699: El artista 'Kidd Keo' no existe en la tabla 'artists'.
# Fila 700: El artista 'Natos y Waor' no existe en la tabla 'artists'.
# Fila 701: El artista 'Nic' no existe en la tabla 'artists'.
# Fila 702: El artista 'Dollar Selmouni' no existe en la tabla 'artists'.
# Fila 703: El artista 'FERNANDOCOSTA' no existe en la tabla 'artists'.
# Fila 704: El artista 'Kaydy Cain' no existe en la tabla 'artists'.
# Fila 705: El artista 'Maikel Delacalle' no existe en la tabla 'artists'.
# Fila 706: El artista 'Steve Lean' no existe en la tabla 'artists'.
# Fila 707: El artista 'Los del Control' no existe en la tabla 'artists'.
# Fila 708: El artista 'Darell' no existe en la tabla 'artists'.
# Fila 709: El artista 'Ñengo Flow' no existe en la tabla 'artists'.
# Fila 710: El artista 'Jory Boy' no existe en la tabla 'artists'.
# Fila 711: El artista 'Midel' no existe en la tabla 'artists'.
# Fila 712: El artista 'Arse' no existe en la tabla 'artists'.
# Fila 713: El artista 'KHEA' no existe en la tabla 'artists'.
# Fila 714: El artista 'Duki' no existe en la tabla 'artists'.
# Fila 715: El artista 'Klave' no existe en la tabla 'artists'.
# Fila 716: El artista 'MYKKA' no existe en la tabla 'artists'.
# Fila 717: El artista 'Omar Varela' no existe en la tabla 'artists'.
# Fila 718: El artista 'Nikone' no existe en la tabla 'artists'.
# Fila 719: El artista 'Juancho Marqués' no existe en la tabla 'artists'.
# Error en fila 720: 1406 (22001): Data too long for column 'track_name' at row 1
# Fila 721: El artista 'Kendrick Lamar' no existe en la tabla 'artists'.
# Fila 722: El artista 'Subze' no existe en la tabla 'artists'.
# Fila 723: El artista 'Blake' no existe en la tabla 'artists'.
# Fila 724: El artista 'Bad Bunny' no existe en la tabla 'artists'.
# Fila 725: El artista 'Arcángel' no existe en la tabla 'artists'.
# Fila 726: El artista 'Almighty' no existe en la tabla 'artists'.
# Fila 727: El artista 'Black Jonas Point' no existe en la tabla 'artists'.
# Fila 728: El artista 'Quimico Ultra Mega' no existe en la tabla 'artists'.
# Fila 729: El artista 'Delaossa' no existe en la tabla 'artists'.
# Fila 730: El artista 'Paulo Londra' no existe en la tabla 'artists'.
# Fila 731: El artista 'Cosculluela' no existe en la tabla 'artists'.
# Fila 732: El artista 'Anuel AA' no existe en la tabla 'artists'.
# Fila 733: El artista 'Eminem' no existe en la tabla 'artists'.
# ...
# Fila 2651: El artista 'Lord Apex' no existe en la tabla 'artists'.
# Fila 2652: El artista 'Lester Nowhere' no existe en la tabla 'artists'.
# Fila 2653: El artista 'o k h o' no existe en la tabla 'artists'.
# Fila 2654: El artista 'M.One' no existe en la tabla 'artists'.
# Fila 2655: El artista '220v' no existe en la tabla 'artists'.
# Fila 2656: El artista 'JEKAJIO' no existe en la tabla 'artists'.
# Fila 2657: El artista 'Porto' no existe en la tabla 'artists'.
# Fila 2658: El artista 'The Architect' no existe en la tabla 'artists'.
# Fila 2659: El artista 'C.W. Da YoungBlood' no existe en la tabla 'artists'.
# Fila 2660: El artista 'Thug Lucciano' no existe en la tabla 'artists'.
# Fila 2661: El artista 'Baby Brown' no existe en la tabla 'artists'.
# Fila 2662: El artista 'Eskatology' no existe en la tabla 'artists'.
# Fila 2663: El artista 'Dryman' no existe en la tabla 'artists'.
# Fila 2664: El artista 'Benjahvites' no existe en la tabla 'artists'.
# Fila 2665: El artista 'Hamed Slash' no existe en la tabla 'artists'.
# Fila 2666: El artista 'M.C. Mack' no existe en la tabla 'artists'.
# Fila 2667: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2668: El artista 'Vagan' no existe en la tabla 'artists'.
# Fila 2669: El artista 'Starboi Ebriima' no existe en la tabla 'artists'.
# Fila 2670: El artista 'Muhnee' no existe en la tabla 'artists'.
# Fila 2671: El artista 'Jimmy Traxx' no existe en la tabla 'artists'.
# Fila 2672: El artista 'Cirok Starr' no existe en la tabla 'artists'.
# Fila 2673: El artista 'One Hunned' no existe en la tabla 'artists'.
# Fila 2674: El artista 'Phidizz' no existe en la tabla 'artists'.
# Fila 2675: El artista 'Mirez' no existe en la tabla 'artists'.
# Fila 2676: El artista 'Richie Ledreagle' no existe en la tabla 'artists'.
# Fila 2677: El artista 'Susanna Morgan' no existe en la tabla 'artists'.
# Fila 2678: El artista 'C.W. Da YoungBlood' no existe en la tabla 'artists'.
# Fila 2679: El artista 'Chucky Blk' no existe en la tabla 'artists'.
# Fila 2680: El artista 'Jacin Trill' no existe en la tabla 'artists'.
# Fila 2681: El artista 'Leafs' no existe en la tabla 'artists'.
# Fila 2682: El artista 'Hoodini' no existe en la tabla 'artists'.
# Fila 2683: El artista 'Nicko' no existe en la tabla 'artists'.
# Fila 2684: El artista 'Osten' no existe en la tabla 'artists'.
# Fila 2685: El artista '42' no existe en la tabla 'artists'.
# Fila 2686: El artista 'Shadayawar' no existe en la tabla 'artists'.
# Fila 2687: El artista 'Sleepy Laflare' no existe en la tabla 'artists'.
# Fila 2688: El artista 'Cliff Notez' no existe en la tabla 'artists'.
# Fila 2689: El artista 'Latrell James' no existe en la tabla 'artists'.
# Fila 2690: El artista 'Moe Pope' no existe en la tabla 'artists'.
# Fila 2691: El artista 'Optic Bloom' no existe en la tabla 'artists'.
# Fila 2692: El artista 'Tyrek Greene' no existe en la tabla 'artists'.
# Fila 2693: El artista 'G-rdz' no existe en la tabla 'artists'.
# Fila 2694: El artista 'ShabZi Madallion' no existe en la tabla 'artists'.
# Fila 2695: El artista 'Brandie Blaze' no existe en la tabla 'artists'.
# Fila 2696: El artista 'D-Weez' no existe en la tabla 'artists'.
# Fila 2697: El artista 'B. Rog' no existe en la tabla 'artists'.
# Fila 2698: El artista 'Scoot Da Kidd' no existe en la tabla 'artists'.
# Fila 2699: El artista 'Munch Lauren' no existe en la tabla 'artists'.
# Fila 2700: El artista 'Mula Kkhan' no existe en la tabla 'artists'.
# Fila 2701: El artista 'Landro' no existe en la tabla 'artists'.
# Fila 2702: El artista 'Kacie Hoffman' no existe en la tabla 'artists'.
# Fila 2703: El artista 'Dubb Saq' no existe en la tabla 'artists'.
# Fila 2704: El artista 'Spectacular Diagnostics' no existe en la tabla 'artists'.
# Fila 2705: El artista 'Lil Chera' no existe en la tabla 'artists'.
# Fila 2706: El artista 'DM' no existe en la tabla 'artists'.
# Fila 2707: El artista 'Love Guru' no existe en la tabla 'artists'.
# Fila 2708: El artista 'Eva María Glimmer' no existe en la tabla 'artists'.
# Fila 2709: El artista 'Ice One' no existe en la tabla 'artists'.
# Fila 2710: El artista 'Dyrti San' no existe en la tabla 'artists'.
# Fila 2711: El artista 'Robin Love' no existe en la tabla 'artists'.
# Fila 2712: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2713: El artista 'Mad Stage' no existe en la tabla 'artists'.
# Fila 2714: El artista 'Islas Junior' no existe en la tabla 'artists'.
# Fila 2715: El artista 'Drexo' no existe en la tabla 'artists'.
# Fila 2716: El artista 'C.W. Da YoungBlood' no existe en la tabla 'artists'.
# Fila 2717: El artista 'Lil Skritt' no existe en la tabla 'artists'.
# Fila 2718: El artista 'Skinny White' no existe en la tabla 'artists'.
# Fila 2719: El artista 'Lanoo' no existe en la tabla 'artists'.
# Fila 2720: El artista 'MicrowaveMan' no existe en la tabla 'artists'.
# Fila 2721: El artista 'ATK' no existe en la tabla 'artists'.
# Fila 2722: El artista 'Castelló' no existe en la tabla 'artists'.
# Fila 2723: El artista 'Hanjin Tan' no existe en la tabla 'artists'.
# Fila 2724: El artista 'Brian Clark Music' no existe en la tabla 'artists'.
# Fila 2725: El artista 'The Architect' no existe en la tabla 'artists'.
# Fila 2726: El artista 'Byrd Land' no existe en la tabla 'artists'.
# Fila 2727: El artista 'Ice One' no existe en la tabla 'artists'.
# Fila 2728: El artista 'Peku' no existe en la tabla 'artists'.
# Fila 2729: El artista 'Baze' no existe en la tabla 'artists'.
# Fila 2730: El artista 'Ramson Badbonez' no existe en la tabla 'artists'.
# Fila 2731: El artista 'Kenny K-Shot' no existe en la tabla 'artists'.
# Fila 2732: El artista 'ET' no existe en la tabla 'artists'.
# Fila 2733: El artista 'Zuti' no existe en la tabla 'artists'.
# Fila 2734: El artista 'Lil P' no existe en la tabla 'artists'.
# Fila 2735: El artista 'ShabZi Madallion' no existe en la tabla 'artists'.
# Fila 2736: El artista 'Jimmy Wiz' no existe en la tabla 'artists'.
# Fila 2737: El artista 'J-Lamo' no existe en la tabla 'artists'.
# Fila 2738: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2739: El artista 'Islas Junior' no existe en la tabla 'artists'.
# Fila 2740: El artista 'Jairzinho' no existe en la tabla 'artists'.
# Fila 2741: El artista 'Skinny Stylus' no existe en la tabla 'artists'.
# Fila 2742: El artista 'Cole James' no existe en la tabla 'artists'.
# Fila 2743: El artista 'MikS' no existe en la tabla 'artists'.
# Fila 2744: El artista 'River' no existe en la tabla 'artists'.
# Fila 2745: El artista 'Zuti' no existe en la tabla 'artists'.
# Fila 2746: El artista 'Omg Oumy Gueye' no existe en la tabla 'artists'.
# Fila 2747: El artista 'Tao Quit' no existe en la tabla 'artists'.
# Fila 2748: El artista 'Gnrl Ape1' no existe en la tabla 'artists'.
# Fila 2749: El artista 'Nia Dope' no existe en la tabla 'artists'.
# Fila 2750: El artista 'Ruggedman' no existe en la tabla 'artists'.
# Fila 2751: El artista 'GRGY' no existe en la tabla 'artists'.
# Fila 2752: El artista 'Reklews' no existe en la tabla 'artists'.
# Fila 2753: El artista 'Bang On!' no existe en la tabla 'artists'.
# Fila 2754: El artista 'Leumas Owabajaja' no existe en la tabla 'artists'.
# Fila 2755: El artista 'Stewie G' no existe en la tabla 'artists'.
# Fila 2756: El artista 'Big Som' no existe en la tabla 'artists'.
# Fila 2757: El artista 'Jonesiii from the Moon' no existe en la tabla 'artists'.
# Fila 2758: El artista 'Lanoo' no existe en la tabla 'artists'.
# Fila 2759: El artista 'Pimp Daddy Dane' no existe en la tabla 'artists'.
# Fila 2760: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 2761: El artista 'Amit Sagie' no existe en la tabla 'artists'.
# Fila 2762: El artista 'Benjahvites' no existe en la tabla 'artists'.
# Fila 2763: El artista 'Hoodini' no existe en la tabla 'artists'.
# Fila 2764: El artista 'Fang' no existe en la tabla 'artists'.
# Fila 2765: El artista 'Manny Phesto' no existe en la tabla 'artists'.
# Fila 2766: El artista 'Bad Balance' no existe en la tabla 'artists'.
# Fila 2767: El artista 'Guru Hebballi' no existe en la tabla 'artists'.
# Fila 2768: El artista 'Ironik' no existe en la tabla 'artists'.
# Fila 2769: El artista 'Starvz' no existe en la tabla 'artists'.
# Fila 2770: El artista 'Daniel Williams' no existe en la tabla 'artists'.
# Fila 2771: El artista 'Fat Jack' no existe en la tabla 'artists'.
# Fila 2772: El artista 'TinTin V.' no existe en la tabla 'artists'.
# Fila 2773: El artista 'Fat Jack' no existe en la tabla 'artists'.
# Fila 2774: El artista 'Raheem the Dream' no existe en la tabla 'artists'.
# Fila 2775: El artista 'Mase' no existe en la tabla 'artists'.
# Fila 2776: El artista 'Baby Brown' no existe en la tabla 'artists'.
# Fila 2777: El artista 'Nyanda' no existe en la tabla 'artists'.
# Fila 2778: El artista 'D-Weez' no existe en la tabla 'artists'.
# Fila 2779: El artista 'Eazy Racks' no existe en la tabla 'artists'.
# Fila 2780: El artista 'Lil Juu Widdaus' no existe en la tabla 'artists'.
# Fila 2781: El artista 'Icaki' no existe en la tabla 'artists'.
# Fila 2782: El artista 'Atchi' no existe en la tabla 'artists'.
# Fila 2783: El artista 'Novem' no existe en la tabla 'artists'.
# Fila 2784: El artista 'Rogachev' no existe en la tabla 'artists'.
# Fila 2785: El artista 'Pistolposse' no existe en la tabla 'artists'.
# Fila 2786: El artista 'Baby Shiva' no existe en la tabla 'artists'.
# Fila 2787: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2788: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2789: El artista 'Old Grape God' no existe en la tabla 'artists'.
# Fila 2790: El artista 'Spiderunit' no existe en la tabla 'artists'.
# Fila 2791: El artista 'Munch Lauren' no existe en la tabla 'artists'.
# Fila 2792: El artista 'Mestizo' no existe en la tabla 'artists'.
# Fila 2793: El artista 'Jacin Trill' no existe en la tabla 'artists'.
# Fila 2794: El artista 'Leafs' no existe en la tabla 'artists'.
# Fila 2795: El artista 'Mula Kkhan' no existe en la tabla 'artists'.
# Fila 2796: El artista 'Thug Lucciano' no existe en la tabla 'artists'.
# Fila 2797: El artista 'Kenny K-Shot' no existe en la tabla 'artists'.
# Fila 2798: El artista 'Lil Skritt' no existe en la tabla 'artists'.
# Fila 2799: El artista 'Ben Jones' no existe en la tabla 'artists'.
# Fila 2800: El artista 'CERTIBEATS' no existe en la tabla 'artists'.
# Fila 2801: El artista 'Love Guru' no existe en la tabla 'artists'.
# Fila 2802: El artista 'Lísa Einars' no existe en la tabla 'artists'.
# Fila 2803: El artista 'The Architect' no existe en la tabla 'artists'.
# Fila 2804: El artista 'Byrd Land' no existe en la tabla 'artists'.
# Fila 2805: El artista 'Zaga El Veterano' no existe en la tabla 'artists'.
# Fila 2806: El artista 'YFilla' no existe en la tabla 'artists'.
# Fila 2807: El artista 'B-Threy' no existe en la tabla 'artists'.
# Fila 2808: El artista 'U.Nique' no existe en la tabla 'artists'.
# Fila 2809: El artista 'Lelenoflops' no existe en la tabla 'artists'.
# Fila 2810: El artista 'C.W. Da YoungBlood' no existe en la tabla 'artists'.
# Fila 2811: El artista 'Snow' no existe en la tabla 'artists'.
# Fila 2812: El artista 'The Architect' no existe en la tabla 'artists'.
# Fila 2813: El artista 'Byrd Land' no existe en la tabla 'artists'.
# Fila 2814: El artista 'Benjahvites' no existe en la tabla 'artists'.
# Fila 2815: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2816: El artista 'Benjahvites' no existe en la tabla 'artists'.
# Fila 2817: El artista 'MDR Tilla' no existe en la tabla 'artists'.
# Fila 2818: El artista 'Conjuro Epiléptico' no existe en la tabla 'artists'.
# Fila 2819: El artista 'Sondy' no existe en la tabla 'artists'.
# Fila 2820: El artista 'Zeman' no existe en la tabla 'artists'.
# Fila 2821: El artista 'Adem Delon' no existe en la tabla 'artists'.
# Fila 2822: El artista 'Shle Berry' no existe en la tabla 'artists'.
# Fila 2823: El artista 'Rico' no existe en la tabla 'artists'.
# Fila 2824: El artista 'Jairzinho' no existe en la tabla 'artists'.
# Fila 2825: El artista 'Blauwe Uil' no existe en la tabla 'artists'.
# Fila 2826: El artista 'Old Grape God' no existe en la tabla 'artists'.
# Fila 2827: El artista 'Heartspace' no existe en la tabla 'artists'.
# Fila 2828: El artista 'J-Lamo' no existe en la tabla 'artists'.
# Fila 2829: El artista 'Sean Gonzalez' no existe en la tabla 'artists'.
# Fila 2830: El artista 'Omg Oumy Gueye' no existe en la tabla 'artists'.
# Fila 2831: El artista 'Dj Spinna' no existe en la tabla 'artists'.
# Fila 2832: El artista 'Kacie Hoffman' no existe en la tabla 'artists'.
# Fila 2833: El artista 'Choppa' no existe en la tabla 'artists'.
# Fila 2834: El artista 'C.W. Da YoungBlood' no existe en la tabla 'artists'.
# Fila 2835: El artista 'Benjahvites' no existe en la tabla 'artists'.
# Fila 2836: El artista 'Akhil' no existe en la tabla 'artists'.
# Fila 2837: El artista 'Lay Lay' no existe en la tabla 'artists'.
# Fila 2838: El artista 'Coop the Emcee' no existe en la tabla 'artists'.
# Fila 2839: El artista 'Chip Charlez' no existe en la tabla 'artists'.
# Fila 2840: El artista 'Snelle' no existe en la tabla 'artists'.
# Fila 2841: El artista 'Lelenoflops' no existe en la tabla 'artists'.
# Fila 2842: El artista 'Малик Тухигов' no existe en la tabla 'artists'.
# Fila 2843: El artista 'Blackface' no existe en la tabla 'artists'.
# Fila 2844: El artista 'Richie Ledreagle' no existe en la tabla 'artists'.
# Fila 2845: El artista 'Kenny K-Shot' no existe en la tabla 'artists'.
# Fila 2846: El artista 'Spectacular Diagnostics' no existe en la tabla 'artists'.
# Fila 2847: El artista 'Nazeem' no existe en la tabla 'artists'.
# Fila 2848: El artista '$kinny Hardaway' no existe en la tabla 'artists'.
# Fila 2849: El artista 'MainCiaga' no existe en la tabla 'artists'.
# Fila 2850: El artista 'Dugga Mulla' no existe en la tabla 'artists'.
# Fila 2851: El artista 'Vagrant Real Estate' no existe en la tabla 'artists'.
# Fila 2852: El artista 'Freeway' no existe en la tabla 'artists'.
# Fila 2853: El artista 'Camp Blood' no existe en la tabla 'artists'.
# Fila 2854: El artista 'Reklews' no existe en la tabla 'artists'.
# Fila 2855: El artista 'Bang On!' no existe en la tabla 'artists'.
# Fila 2856: El artista 'PEACE CHONG' no existe en la tabla 'artists'.
# Fila 2857: El artista 'Bad Balance' no existe en la tabla 'artists'.
# Fila 2858: El artista 'Jonah Cruzz' no existe en la tabla 'artists'.
# Fila 2859: El artista 'Kenny K-Shot' no existe en la tabla 'artists'.
# Fila 2860: El artista 'Getts Kent' no existe en la tabla 'artists'.
# Fila 2861: El artista 'Pix'L' no existe en la tabla 'artists'.
# Fila 2862: El artista 'M7' no existe en la tabla 'artists'.
# Fila 2863: El artista 'Luminary' no existe en la tabla 'artists'.
# Fila 2864: El artista 'Hamed Slash' no existe en la tabla 'artists'.
# Fila 2865: El artista 'Drug Dilla' no existe en la tabla 'artists'.
# Fila 2866: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2867: El artista 'RaHa' no existe en la tabla 'artists'.
# Fila 2868: El artista 'Lil Skritt' no existe en la tabla 'artists'.
# Fila 2869: El artista 'Skinny White' no existe en la tabla 'artists'.
# Fila 2870: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2871: El artista 'Zuti' no existe en la tabla 'artists'.
# Fila 2872: El artista 'Dog' no existe en la tabla 'artists'.
# Fila 2873: El artista 'Love Guru' no existe en la tabla 'artists'.
# Fila 2874: El artista 'Bergmál' no existe en la tabla 'artists'.
# Fila 2875: El artista 'Namkeen Rappers' no existe en la tabla 'artists'.
# Fila 2876: El artista 'Mr Sherry' no existe en la tabla 'artists'.
# Fila 2877: El artista 'K_Appner' no existe en la tabla 'artists'.
# Fila 2878: El artista 'Jamal' no existe en la tabla 'artists'.
# Fila 2879: El artista 'BabZo' no existe en la tabla 'artists'.
# Fila 2880: El artista 'Hooligan' no existe en la tabla 'artists'.
# Fila 2881: El artista 'Guy Mar' no existe en la tabla 'artists'.
# Fila 2882: El artista 'Rayen Youssef' no existe en la tabla 'artists'.
# Fila 2883: El artista 'Gonzo G' no existe en la tabla 'artists'.
# Fila 2884: El artista 'Mad Stage' no existe en la tabla 'artists'.
# Fila 2885: El artista 'Subliminal' no existe en la tabla 'artists'.
# Fila 2886: El artista 'Zaman' no existe en la tabla 'artists'.
# Proceso terminado. Se intentaron subir 2887 canciones.

# %%
def insertar_cancion_con_genero(conexion, titulo, nombre_genero): 

    cursor = conexion.cursor()     # 1. Buscamos el ID del género en la tabla de géneros    

    query_genero = "SELECT id_genero FROM generos WHERE nombre_genero = %s"   

    cursor.execute(query_genero, (nombre_genero,))    

    resultado = cursor.fetchone()     

    if resultado:         
        id_genero_encontrado = resultado[0] # 2. Insertamos la canción usando ese ID 

        query_cancion = """ INSERT INTO canciones (titulo, id_genero) VALUES (%s, %s) """ 

        cursor.execute(query_cancion, (titulo, id_genero_encontrado)) 

        conexion.commit() 
        
    else: print(f"El género '{nombre_genero}' no existe en la base de datos.") 
    cursor.close()
