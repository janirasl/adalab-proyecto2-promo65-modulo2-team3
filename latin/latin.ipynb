# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\dacil\appdata\local\programs\python\python312\lib\site-packages (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\dacil\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\dacil\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
import mysql.connector

# %%
with open ("../archivos_json/definitivo.json", "r") as fichero: 
    definitivo = json.load(fichero)           

def extraer_por_genero(canciones, genero):    
    lista_latin = []                      

    for item in canciones:                  
        año = item.get("year")

        if item.get("genre") == genero and 2016 <= año <= 2019:    
            info = (                                       
                item.get("artist_name"),
                item.get("genre"),
                item.get("track_name"),
                año
            )

            lista_latin.append(info)        

    return lista_latin                   

lista_latin = extraer_por_genero(definitivo, "latin")      
print(f"La longitud de la lista es ---> {len(lista_latin)} canciones de Latin")
print(f"{'-' * 100} \n{lista_latin}")
# Out:
# La longitud de la lista es ---> 1956 canciones de Latin
# ----------------------------------------------------------------------------------------------------
# [('Bad Bunny', 'latin', 'Diles', 2016), ('Ozuna', 'latin', 'Diles', 2016), ('Farruko', 'latin', 'Diles', 2016), ('Arcángel', 'latin', 'Diles', 2016), ('Ñengo Flow', 'latin', 'Diles', 2016), ('DJ Luian', 'latin', 'Diles', 2016), ('Mambo Kingz', 'latin', 'Diles', 2016), ('Anuel AA', 'latin', 'Sola (Remix)', 2016), ('Daddy Yankee', 'latin', 'Sola (Remix)', 2016), ('Zion & Lennox', 'latin', 'Sola (Remix)', 2016), ('Farruko', 'latin', 'Sola (Remix)', 2016), ('Wisin', 'latin', 'Sola (Remix)', 2016), ('Bryant Myers', 'latin', 'Esclava - Remix', 2016), ('Anuel AA', 'latin', 'Esclava - Remix', 2016), ('Anonimus', 'latin', 'Esclava - Remix', 2016), ('Almighty', 'latin', 'Esclava - Remix', 2016), ('Gente De Zona', 'latin', 'La Gozadera (feat. Marc Anthony)', 2016), ('Marc Anthony', 'latin', 'La Gozadera (feat. Marc Anthony)', 2016), ('Anuel AA', 'latin', 'No Love', 2016), ('Spiff TV', 'latin', 'No Love', 2016), ('Arcángel', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('Bad Bunny', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('Mambo Kingz', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('DJ Luian', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('Maluma', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Trap Capos', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Noriel', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Bryant Myers', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Juhn', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Trap Capos', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Noriel', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Anuel AA', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Baby Rasta', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Bad Gyal', 'latin', 'Fiebre - Prod. King DouDou', 2016), ('C. Tangana', 'latin', 'Antes de Morirme - feat. ROSALÍA', 2016), ('ROSALÍA', 'latin', 'Antes de Morirme - feat. ROSALÍA', 2016), ('Danny Ocean', 'latin', 'Me Rehúso', 2016), ('Chino & Nacho', 'latin', 'Andas En Mi Cabeza', 2016), ('Daddy Yankee', 'latin', 'Andas En Mi Cabeza', 2016), ('Trap Capos', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Noriel', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Gigolo Y La Exce', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Sammy & Falsetto', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Mike Duran', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Baby Angel', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('La Mafia del Amor', 'latin', 'Multiorgásmica', 2016), ('Cosculluela', 'latin', 'Manicomio', 2016), ('Anuel AA', 'latin', 'Nacimos Pa Morir (feat. Jory Boy)', 2016), ('Jory Boy', 'latin', 'Nacimos Pa Morir (feat. Jory Boy)', 2016), ('Zion & Lennox', 'latin', 'Otra Vez (feat. J Balvin)', 2016), ('J Balvin', 'latin', 'Otra Vez (feat. J Balvin)', 2016), ('CNCO', 'latin', 'Reggaetón Lento (Bailemos)', 2016), ('Bad Bunny', 'latin', 'Caile', 2016), ('Bryant Myers', 'latin', 'Caile', 2016), ('De La Ghetto', 'latin', 'Caile', 2016), ('Revol', 'latin', 'Caile', 2016), ('Zion', 'latin', 'Caile', 2016), ('Bad Bunny', 'latin', 'Soy Peor', 2016), ('Pepe Quintana', 'latin', 'Ella Y Yo (feat. Farruko, Ozuna, Arcangel, Anuel AA, Bryant Myers, Kevin Roldan, Ñengo Flow, Alexis La Bestia & Ñejo) - Remix', 2016), ('Alexis La Bestia', 'latin', 'Ella Y Yo (feat. Farruko, Ozuna, Arcangel, Anuel AA, Bryant Myers, Kevin Roldan, Ñengo Flow, Alexis La Bestia & Ñejo) - Remix',  ...

# %%
artistas_latin = set()                 
for dato in lista_latin:                       
    artistas_latin.add(dato[0])       
print(f"La longitud de los artistas es ---> {len(artistas_latin)} artistas \n{'-' * 100} \nLos artistas son ---> {artistas_latin}")
# Out:
# La longitud de los artistas es ---> 489 artistas
# ----------------------------------------------------------------------------------------------------
# Los artistas son ---> {'Luigi 21 Plus', 'Pedro Calderon', 'Randy Nota Loca', 'Bryant Myers', 'Rawayana', 'David Otero', 'Danny Ocean', 'Dalmata', 'Cruz Cafuné', 'Chris Viz', 'Chael Produciendo', 'Farruko', 'Soto Asa', 'DJ Snake', 'Los 40', 'Yampi', 'Chema Rivas', 'Alvaro Soler', 'Mambo Kingz', 'Mishelle Master Boys', 'Buuoy', 'Frank Miami', 'Myke Towers', 'La Suprema Corte', 'Carla Morrison', 'Juhn', 'Rocío Dúrcal', 'Fred De Palma', 'Offset', 'Banda MS de Sergio Lizárraga', 'DJ Luian', 'Descemer Bueno', 'Enrique Iglesias', 'MYKKA', 'Opi the Hit Machine', 'El Alfa', 'JHAYCO', 'Guitarricadelafuente', 'Maldy', 'El Conejo', 'Leka el Poeta', 'Joel Santos', 'Yai y Toly', 'Moncho Chavea', 'DELLAFUENTE', 'Sanluis', 'Keko Musik', 'Zion', 'Omar Varela', 'Casper Magico', 'Juan Luis Guerra 4.40', 'Ceky Viciny', 'KHEA', 'ROSALÍA', 'Trap Capos', 'Dasoul', 'La Joaqui', 'Ñengo Flow', 'El Chacal', "Oscar D'León", 'Maluma', 'Anuel AA', 'KEVIN ROLDAN', 'Joaquín Sabina', 'Maka', 'Bad Bunny', 'Rita Payés', 'El Chaval de la Bachata', 'Kaydy Cain', 'Camila Cabello', 'Costa', 'Paloma Mami', 'Los Fantastikos', 'El Guincho', 'Sean Paul', 'Luis Fonsi', 'Tainy', 'Gadiel', 'Shaggy', 'Lunay', 'Morad', 'Wisin & Yandel', 'Nicky Jam', 'DM', 'Buxxi', 'Secreto "El Famoso Biberon"', 'Jantony', 'Victor Cardenas', 'Shakira', 'Pitbull', 'D-Enyel', 'DICC', 'Lito Kirino', 'Ana Mena', 'Galindo Again', 'Yaga & Mackie', 'Ñejo', 'Young Vene', 'Teejayx6', 'Alex Goot', 'Jey Blessing', 'Bomba Estéreo', 'Celia Cruz', 'Danny Paz', 'Trapani', 'Demi Lovato', 'YSY A', 'Feid', 'Luciana', 'Eduarny Morales', 'C.R.O', 'Mozart La Para', 'Nyno Vargas', 'Elvis KNK', 'J Alvarez', 'Anuel', 'Eloy', 'Willy William', 'La Factoria', 'Dalex', 'Kika Edgar', 'Carlos Baute', 'Andy Rivera', 'El Daddy', 'Reik', 'Sky Rompiendo', 'Pharrell Williams', 'El Varon de la bachata', 'Jc La Nevula', 'El Villano', 'Cosculluela', 'Jessi Uribe', 'Dayvi', 'Chiki El De La Vaina', 'Yiyo Sarante', 'Snova', 'Bardero$', 'Pipe Bueno', 'Belinda', 'Unorthodocks', 'Antonio Banderas', 'Yandel', 'Natalia Lafourcade', 'Marcianos Crew', 'Camin', 'Alex Rose', 'Tony Brouzee', 'Jaycob Duque', 'Anne-Marie', 'La Mafia del Amor', 'Juacko', 'Jhonny Rivera', 'Deorro', 'Steve Lean', 'Kola Loka', 'Brray', 'Selena Gomez', 'Kion Studio', 'Mark B.', 'Miranda!', 'Cotorra Music Grup', 'Bandaga', 'Sammy', 'Revol', 'El Super Nuevo', 'Galvan Real', 'DJ Pablito', 'Sammy Baby', 'DeeWunn', 'Mike Duran', 'Beret', 'Tempo', 'Piso 21', 'Bad Gyal', 'Sammy & Falsetto', 'Romeo Santos', 'LOWLIGHT', 'Jorge Drexler', 'Mau y Ricky', 'DJ Nelson', 'AC3', 'Mym', 'Natos y Waor', 'Fernando Burbano', 'Oken', 'Jacob Forever', 'Taxi', 'La Sonora Dinamita', 'Bizarrap', 'Cauty', 'Egbert Rosa aka Haze', 'Marcy Chin', 'Anonimus', 'Ozuna', 'rusowsky', 'La Nueva Escuela', 'Jay Wheeler', 'Super Yei', 'Villanosam', 'Voltio', 'Musicologo The Libro', 'Khaled', 'Nego do Borel', 'Jone Quest', 'Brytiago', 'Eladio Carrion', 'Yeison Jimenez', 'Wolfine', 'Elilluminari', 'Mon Laferte', 'Zacarias Ferreira', 'Lele Pons', 'Juanka', '6ix9ine', 'Kevin Kaarl', 'Henry Mendez', 'Homer El Mero Mero', 'Juanes', 'Mr Eazi', 'Quavo', 'Dayme y El High', 'Los De La Nazza', 'Elisabeth Roma', 'Los Lobos', 'Benny Benni', 'Fakeguido', 'MC Bin Laden', 'Mackie', 'Los Hermanos Dalton', 'Bebe', 'Kelly Ruíz', 'ECKO', 'Ptazeta', 'FlowZeta', 'Haze', 'Prince Royce', 'Shadow Blow', 'Lenny Tavárez', 'Pyllo Cortes', 'Elvis Crespo', 'Karetta el Gucci', 'Duki', 'VI Seconds', 'Boni & Kelly', 'Sech', 'The Secret Panda', 'El Perla', 'Busy Signal', 'Kasher Quon', 'Tapia El Sikario', 'Kenai', 'Sebastian Yatra', 'Jon Z', 'Ele A', 'Yung Beef', 'Alexio La Bruja', 'Princesa Alba', 'Nicki Minaj', 'Jarabe De Palo', 'Felipe Muñiz', 'Upchurch', 'Jada Facer', 'Leoni Torres', 'Guaynaa', 'Lucho SSJ', 'CNCO', 'TIMBALIVE', 'Vicente Garcia', 'Alexio', 'Los 4', 'EZ El Ezeta', 'Mueka', 'Travis Scott', 'Paulo Londra', 'Don Omar', 'Ele A El Dominio', 'Mariah Angeliq', 'Marc Anthony', 'Alexis', 'Rvfv', 'Spiff TV', 'Future', 'Plan B',  ...

# %%
print(f"La lista del genero Latin ---> {lista_latin}")     
lista_artistas = list(artistas_latin)                     
print("--------------------------------------")
print(f"Los artistas en Latin son: {lista_artistas} con {len(lista_artistas)} artistas")
# Out:
# La lista del genero Latin ---> [('Bad Bunny', 'latin', 'Diles', 2016), ('Ozuna', 'latin', 'Diles', 2016), ('Farruko', 'latin', 'Diles', 2016), ('Arcángel', 'latin', 'Diles', 2016), ('Ñengo Flow', 'latin', 'Diles', 2016), ('DJ Luian', 'latin', 'Diles', 2016), ('Mambo Kingz', 'latin', 'Diles', 2016), ('Anuel AA', 'latin', 'Sola (Remix)', 2016), ('Daddy Yankee', 'latin', 'Sola (Remix)', 2016), ('Zion & Lennox', 'latin', 'Sola (Remix)', 2016), ('Farruko', 'latin', 'Sola (Remix)', 2016), ('Wisin', 'latin', 'Sola (Remix)', 2016), ('Bryant Myers', 'latin', 'Esclava - Remix', 2016), ('Anuel AA', 'latin', 'Esclava - Remix', 2016), ('Anonimus', 'latin', 'Esclava - Remix', 2016), ('Almighty', 'latin', 'Esclava - Remix', 2016), ('Gente De Zona', 'latin', 'La Gozadera (feat. Marc Anthony)', 2016), ('Marc Anthony', 'latin', 'La Gozadera (feat. Marc Anthony)', 2016), ('Anuel AA', 'latin', 'No Love', 2016), ('Spiff TV', 'latin', 'No Love', 2016), ('Arcángel', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('Bad Bunny', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('Mambo Kingz', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('DJ Luian', 'latin', 'Tu No Vive Asi (feat. Mambo Kingz & DJ Luian)', 2016), ('Maluma', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Trap Capos', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Noriel', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Bryant Myers', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Juhn', 'latin', 'Cuatro Babys (feat. Trap Capos, Noriel, Bryant Myers & Juhn)', 2016), ('Trap Capos', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Noriel', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Anuel AA', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Baby Rasta', 'latin', 'Diablita (feat. Anuel AA & Baby Rasta)', 2016), ('Bad Gyal', 'latin', 'Fiebre - Prod. King DouDou', 2016), ('C. Tangana', 'latin', 'Antes de Morirme - feat. ROSALÍA', 2016), ('ROSALÍA', 'latin', 'Antes de Morirme - feat. ROSALÍA', 2016), ('Danny Ocean', 'latin', 'Me Rehúso', 2016), ('Chino & Nacho', 'latin', 'Andas En Mi Cabeza', 2016), ('Daddy Yankee', 'latin', 'Andas En Mi Cabeza', 2016), ('Trap Capos', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Noriel', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Gigolo Y La Exce', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Sammy & Falsetto', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Mike Duran', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('Baby Angel', 'latin', 'La Paso Cabrón (feat. Gigolo y La Exce, Falsetto y Sammy, Mike Duran & Baby Angel)', 2016), ('La Mafia del Amor', 'latin', 'Multiorgásmica', 2016), ('Cosculluela', 'latin', 'Manicomio', 2016), ('Anuel AA', 'latin', 'Nacimos Pa Morir (feat. Jory Boy)', 2016), ('Jory Boy', 'latin', 'Nacimos Pa Morir (feat. Jory Boy)', 2016), ('Zion & Lennox', 'latin', 'Otra Vez (feat. J Balvin)', 2016), ('J Balvin', 'latin', 'Otra Vez (feat. J Balvin)', 2016), ('CNCO', 'latin', 'Reggaetón Lento (Bailemos)', 2016), ('Bad Bunny', 'latin', 'Caile', 2016), ('Bryant Myers', 'latin', 'Caile', 2016), ('De La Ghetto', 'latin', 'Caile', 2016), ('Revol', 'latin', 'Caile', 2016), ('Zion', 'latin', 'Caile', 2016), ('Bad Bunny', 'latin', 'Soy Peor', 2016), ('Pepe Quintana', 'latin', 'Ella Y Yo (feat. Farruko, Ozuna, Arcangel, Anuel AA, Bryant Myers, Kevin Roldan, Ñengo Flow, Alexis La Bestia & Ñejo) - Remix', 2016), ('Alexis La Bestia', 'latin', 'Ella Y Yo (feat. Farruko, Ozuna, Arcangel, Anuel AA, Bryant Myers, Kevin Roldan, Ñengo Flow, Alex ...
# --------------------------------------
# Los artistas en Latin son: ['Luigi 21 Plus', 'Pedro Calderon', 'Randy Nota Loca', 'Bryant Myers', 'Rawayana', 'David Otero', 'Danny Ocean', 'Dalmata', 'Cruz Cafuné', 'Chris Viz', 'Chael Produciendo', 'Farruko', 'Soto Asa', 'DJ Snake', 'Los 40', 'Yampi', 'Chema Rivas', 'Alvaro Soler', 'Mambo Kingz', 'Mishelle Master Boys', 'Buuoy', 'Frank Miami', 'Myke Towers', 'La Suprema Corte', 'Carla Morrison', 'Juhn', 'Rocío Dúrcal', 'Fred De Palma', 'Offset', 'Banda MS de Sergio Lizárraga', 'DJ Luian', 'Descemer Bueno', 'Enrique Iglesias', 'MYKKA', 'Opi the Hit Machine', 'El Alfa', 'JHAYCO', 'Guitarricadelafuente', 'Maldy', 'El Conejo', 'Leka el Poeta', 'Joel Santos', 'Yai y Toly', 'Moncho Chavea', 'DELLAFUENTE', 'Sanluis', 'Keko Musik', 'Zion', 'Omar Varela', 'Casper Magico', 'Juan Luis Guerra 4.40', 'Ceky Viciny', 'KHEA', 'ROSALÍA', 'Trap Capos', 'Dasoul', 'La Joaqui', 'Ñengo Flow', 'El Chacal', "Oscar D'León", 'Maluma', 'Anuel AA', 'KEVIN ROLDAN', 'Joaquín Sabina', 'Maka', 'Bad Bunny', 'Rita Payés', 'El Chaval de la Bachata', 'Kaydy Cain', 'Camila Cabello', 'Costa', 'Paloma Mami', 'Los Fantastikos', 'El Guincho', 'Sean Paul', 'Luis Fonsi', 'Tainy', 'Gadiel', 'Shaggy', 'Lunay', 'Morad', 'Wisin & Yandel', 'Nicky Jam', 'DM', 'Buxxi', 'Secreto "El Famoso Biberon"', 'Jantony', 'Victor Cardenas', 'Shakira', 'Pitbull', 'D-Enyel', 'DICC', 'Lito Kirino', 'Ana Mena', 'Galindo Again', 'Yaga & Mackie', 'Ñejo', 'Young Vene', 'Teejayx6', 'Alex Goot', 'Jey Blessing', 'Bomba Estéreo', 'Celia Cruz', 'Danny Paz', 'Trapani', 'Demi Lovato', 'YSY A', 'Feid', 'Luciana', 'Eduarny Morales', 'C.R.O', 'Mozart La Para', 'Nyno Vargas', 'Elvis KNK', 'J Alvarez', 'Anuel', 'Eloy', 'Willy William', 'La Factoria', 'Dalex', 'Kika Edgar', 'Carlos Baute', 'Andy Rivera', 'El Daddy', 'Reik', 'Sky Rompiendo', 'Pharrell Williams', 'El Varon de la bachata', 'Jc La Nevula', 'El Villano', 'Cosculluela', 'Jessi Uribe', 'Dayvi', 'Chiki El De La Vaina', 'Yiyo Sarante', 'Snova', 'Bardero$', 'Pipe Bueno', 'Belinda', 'Unorthodocks', 'Antonio Banderas', 'Yandel', 'Natalia Lafourcade', 'Marcianos Crew', 'Camin', 'Alex Rose', 'Tony Brouzee', 'Jaycob Duque', 'Anne-Marie', 'La Mafia del Amor', 'Juacko', 'Jhonny Rivera', 'Deorro', 'Steve Lean', 'Kola Loka', 'Brray', 'Selena Gomez', 'Kion Studio', 'Mark B.', 'Miranda!', 'Cotorra Music Grup', 'Bandaga', 'Sammy', 'Revol', 'El Super Nuevo', 'Galvan Real', 'DJ Pablito', 'Sammy Baby', 'DeeWunn', 'Mike Duran', 'Beret', 'Tempo', 'Piso 21', 'Bad Gyal', 'Sammy & Falsetto', 'Romeo Santos', 'LOWLIGHT', 'Jorge Drexler', 'Mau y Ricky', 'DJ Nelson', 'AC3', 'Mym', 'Natos y Waor', 'Fernando Burbano', 'Oken', 'Jacob Forever', 'Taxi', 'La Sonora Dinamita', 'Bizarrap', 'Cauty', 'Egbert Rosa aka Haze', 'Marcy Chin', 'Anonimus', 'Ozuna', 'rusowsky', 'La Nueva Escuela', 'Jay Wheeler', 'Super Yei', 'Villanosam', 'Voltio', 'Musicologo The Libro', 'Khaled', 'Nego do Borel', 'Jone Quest', 'Brytiago', 'Eladio Carrion', 'Yeison Jimenez', 'Wolfine', 'Elilluminari', 'Mon Laferte', 'Zacarias Ferreira', 'Lele Pons', 'Juanka', '6ix9ine', 'Kevin Kaarl', 'Henry Mendez', 'Homer El Mero Mero', 'Juanes', 'Mr Eazi', 'Quavo', 'Dayme y El High', 'Los De La Nazza', 'Elisabeth Roma', 'Los Lobos', 'Benny Benni', 'Fakeguido', 'MC Bin Laden', 'Mackie', 'Los Hermanos Dalton', 'Bebe', 'Kelly Ruíz', 'ECKO', 'Ptazeta', 'FlowZeta', 'Haze', 'Prince Royce', 'Shadow Blow', 'Lenny Tavárez', 'Pyllo Cortes', 'Elvis Crespo', 'Karetta el Gucci', 'Duki', 'VI Seconds', 'Boni & Kelly', 'Sech', 'The Secret Panda', 'El Perla', 'Busy Signal', 'Kasher Quon', 'Tapia El Sikario', 'Kenai', 'Sebastian Yatra', 'Jon Z', 'Ele A', 'Yung Beef', 'Alexio La Bruja', 'Princesa Alba', 'Nicki Minaj', 'Jarabe De Palo', 'Felipe Muñiz', 'Upchurch', 'Jada Facer', 'Leoni Torres', 'Guaynaa', 'Lucho SSJ', 'CNCO', 'TIMBALIVE', 'Vicente Garcia', 'Alexio', 'Los 4', 'EZ El Ezeta', 'Mueka', 'Travis Scott', 'Paulo Londra', 'Don Omar', 'Ele A El Dominio', 'Mariah Angeliq', 'Marc Anthony', 'Alexis', 'Rvfv', 'Spiff TV', 'Future', 'Plan ...

# %%
df_latin = pd.DataFrame(lista_latin, columns= ["artist", "genre", "track_name", "year"])

# %%
print(df_latin.head())
# Out:
#        artist  genre track_name  year
# 0   Bad Bunny  latin      Diles  2016
# 1       Ozuna  latin      Diles  2016
# 2     Farruko  latin      Diles  2016
# 3    Arcángel  latin      Diles  2016
# 4  Ñengo Flow  latin      Diles  2016

# %%
df_latin.to_csv("lista_latin.csv", index=False)

# %%
with open("artistas_latin.json", "w", encoding="utf-8") as fichero:
    json.dump(sorted(artistas_latin),                              
        fichero,
        ensure_ascii=False,                                       
        indent=4)

# %%
load_dotenv()
# Out:
# True

# %%
Api_key = os.getenv("API_KEY")

# %%
def info_lastfm(artista):              
    url = "https://ws.audioscrobbler.com/2.0/"            
    
    params = {                              
        "method": "artist.getinfo", 
        "artist": artista,
        "api_key": Api_key,
        "format": "json"
    }
    
    response = requests.get(url, params=params)                  
    if response.status_code != 200:                 
        print(f"Error en la petición")
        return None
    
    data = response.json()                      
    
    artist = data["artist"]                
    
    return (                        
        artista,                 
        artist["bio"]["summary"], 
        artist["stats"]["listeners"],
        artist["stats"]["playcount"],
        artist["similar"]["artist"][0]["name"]
    )          

resultados = []
errores = []

for artista in lista_artistas:      
    try:
        info = info_lastfm(artista)     
        resultados.append(info)
    except Exception as e:                   
        errores.append({
            "artista": artista,
            "error": str(e)
        })
        continue

# %%
print(f"Resultado de la busqueda --> {resultados} \n {"-" * 100} \nLa longitud de los resultados --> {len(resultados)} \n {"-" * 100} \nErrores encontrados --> {errores}")
# Out:
# Resultado de la busqueda --> [('Luigi 21 Plus', 'Hiram David Santos Rojas (San Juan, Puerto Rico, 27 de abril de 1977), conocido como Lui-G 21 Plus o en sus inicios solo como Lui-G, es un cantante de reggaeton puertorriqueño.\n\nHiram Santos nació en Cupey Bajo, Puerto Rico. Se empezó a interesar por la música a los 20 años y se muda a Lynn, Massachusetts, donde descubrió su pasión por improvisar y escribir canciones para el género de música que siguió desde sus comienzos como fanático. <a href="https://www.last.fm/music/Luigi+21+Plus">Read more on Last.fm</a>', '54440', '802298', 'Ñengo Flow'), ('Pedro Calderon', ' <a href="https://www.last.fm/music/Pedro+Calderon">Read more on Last.fm</a>', '6578', '45567', 'el daddy'), ('Randy Nota Loca', ' <a href="https://www.last.fm/music/Randy+Nota+Loca">Read more on Last.fm</a>', '40585', '222304', 'Magnate'), ('Bryant Myers', 'Bryan Robert Rohena Pérez, known professionally as Bryant Myers, is a Puerto Rican Latin trap and reggaeton singer and songwriter. Rohena was born in Loma Alta, Puerto Rico. He began sampling and making his own songs in 2013 and launched them on social media via his SoundCloud, Instagram and YouTube accounts. <a href="https://www.last.fm/music/Bryant+Myers">Read more on Last.fm</a>', '196636', '7093031', 'Anuel AA'), ('Rawayana', 'Rawayana is a band formed in Caracas, Venezuela. Line up: BetoMonte (vocals, guitars). Tony (bass, chorus). Abeja. (guitars, chorus). Ro-ro. (drums, chorus). Toño (latin percussion). It\'s a mix of many genres like reggae, rock and acoustic. And make all the people dance to their music. It\'s made with love and for everybody! <a href="https://www.last.fm/music/Rawayana">Read more on Last.fm</a>', '142746', '4559795', 'Los Mesoneros'), ('David Otero', 'David Otero Martín (Madrid, 17 de abril de 1980) es un cantante, guitarrista y compositor español. Fue miembro del grupo de pop rock El Canto del Loco (1994-2010). Tras iniciar su carrera en solitario al principio firmó sus discos como El Pescao, y en la actualidad con su propio nombre, David Otero. <a href="https://www.last.fm/music/David+Otero">Read more on Last.fm</a>', '21870', '252165', 'Sinsinati'), ('Danny Ocean', 'Daniel Alejandro Morales Reyes (born 5 May 1992), known by his stage name Danny Ocean, is a Venezuelan singer, songwriter and record producer born in Caracas, Venezuela. He began his professional music career in 2009 with the creation of his YouTube channel. Daniel  is best known for his song "Me Rehúso", the first Latin solo artist song to reach 1 billion streams on Spotify, which it did in 2020. <a href="https://www.last.fm/music/Danny+Ocean">Read more on Last.fm</a>', '529938', '13034221', 'Lagos'), ('Dalmata', 'Fernando Mangual Vazquez, artistically known as Dálmata, was born on February 29, 1980. The youngest out of three brothers, Dalmata was raised in the place that has become part of his identity and style: Ponce, Puerto Rico. \nDalmata demonstrated a passion for music at a very young age. He studied music theory and also belonged to the chorus at La Escuela de Ponce. Before being involved in reggaeton, his vision was to have a rock band because it was like the trend at the time. <a href="https://www.last.fm/music/Dalmata">Read more on Last.fm</a>', '131349', '1164815', 'Ñejo & Dalmata'), ('Cruz Cafuné', 'Carlos Bruñas Zamorín (Tenerife, 26 junio de 1993), de nombre artístico Cruz Cafuné, es un cantante y rapero español.\n\nNació en 1993 en la isla de Tenerife, de una madre venezolana, profesora de catequesis, y de un padre canario, quien trabajaba en un banco. De pequeño vivía en el pueblo de Icod de los Vinos.\n\nSu nombre artístico aúna dos temáticas muy presentes en la obra del cantante. Por un lado la religión, a la que hace referencia con el término «Cruz», ya que se considera como creyente cristiano. <a href="https://www.last.fm/music/Cruz+Cafun%C3%A9">Read more on Last.fm</a>', '95719', '9301950', 'DeLaOssa'), ('Chris Viz', ' <a href="https://www.last.fm/ ...
#  ----------------------------------------------------------------------------------------------------
# La longitud de los resultados --> 470
#  ----------------------------------------------------------------------------------------------------
# Errores encontrados --> [{'artista': 'DM', 'error': 'list index out of range'}, {'artista': 'Buxxi', 'error': 'list index out of range'}, {'artista': 'Eduarny Morales', 'error': "'artist'"}, {'artista': 'C.R.O', 'error': 'list index out of range'}, {'artista': 'Elvis KNK', 'error': "'artist'"}, {'artista': 'Egbert Rosa aka Haze', 'error': "'artist'"}, {'artista': 'Fakeguido', 'error': 'list index out of range'}, {'artista': 'Tapia El Sikario', 'error': 'list index out of range'}, {'artista': 'Travis Scott', 'error': 'list index out of range'}, {'artista': 'Bunbury', 'error': 'list index out of range'}, {'artista': 'Alexis La Bestia', 'error': "'artist'"}, {'artista': 'integrityoficial', 'error': 'list index out of range'}, {'artista': "Roberton 'van Van'", 'error': "'artist'"}, {'artista': 'Scarlett Miller', 'error': 'list index out of range'}, {'artista': 'Kevinsito', 'error': 'list index out of range'}, {'artista': 'Rafaga', 'error': 'list index out of range'}, {'artista': 'Beltito', 'error': 'list index out of range'}, {'artista': 'Jochy', 'error': 'list index out of range'}, {'artista': 'Cali Y El Dandee', 'error': 'list index out of range'}]

# %%
df_resultado = pd.DataFrame(resultados, columns= ["artist", "bio", "listeners", "playcount", "similar_artist"])

# %%
df_resultado.sample(5)
# Out:
#                  artist                                                bio  \
# 460             Becky G  Rebbeca Marie Gomez, known professionally as B...
# 322  Musicologo Y Menes   <a href="https://www.last.fm/music/Musicologo...
# 316         Major Lazer  Major Lazer is a Jamaican-American electronic ...
# 214     Dayme y El High   <a href="https://www.last.fm/music/Dayme+y+El...
# 210  Homer El Mero Mero  Lucas Darío Giménez (Born in June 5, 1990) bet...
#
#     listeners playcount   similar_artist
# 460   1417785  24961719    Natti Natasha
# 322     61184    649522        J Alvarez
# 316   2931057  68415415    Calvin Harris
# 214     37139    259309  RONALD EL KILLA
# 210     38777   1266124         Bardero$

# %%
def limpiar_html(texto):         
    if texto:
        soup = BeautifulSoup(texto, "html.parser")      
        return soup.get_text()                        
    return texto                               

df_resultado["bio"] = df_resultado["bio"].apply(limpiar_html)

# %%
print(df_resultado.head())
# Out:
#             artist                                                bio  \
# 0    Luigi 21 Plus  Hiram David Santos Rojas (San Juan, Puerto Ric...
# 1   Pedro Calderon                               Read more on Last.fm
# 2  Randy Nota Loca                               Read more on Last.fm
# 3     Bryant Myers  Bryan Robert Rohena Pérez, known professionall...
# 4         Rawayana  Rawayana is a band formed in Caracas, Venezuel...
#
#   listeners playcount similar_artist
# 0     54440    802298     Ñengo Flow
# 1      6578     45567       el daddy
# 2     40585    222304        Magnate
# 3    196636   7093031       Anuel AA
# 4    142746   4559795  Los Mesoneros

# %%
df_resultado.to_csv("resultado_latin.csv", index=False)

# %%
conexion = mysql.connector.connect(
    host="localhost",
    user="root",
    password="tu_password",
    database="musicstream"
)

cursor = conexion.cursor()

for _, row in df_resultado.iterrows():
    cursor.execute("""
        INSERT INTO artistas_latin (artist, bio, listeners, playcount, similar_artist)
        VALUES (%s, %s, %s, %s, %s)
    """, tuple(row))

conexion.commit()
